# %% [markdown]
# # Imports

# %%
import math
import time
import random
from dataclasses import dataclass
from collections import defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# # Setup & Device

# %%
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    if torch.backends.mps.is_available():
        return torch.device("mps")
    return torch.device("cpu")

DEVICE = get_device()
print("Using device:", DEVICE)
# Out:
# Using device: cuda

# %% [markdown]
# # Configuration

# %%
@dataclass
class Config:
    # task
    sequence_length: int = 4096
    num_tokens_memorize: int = 16
    vocab_size: int = 16  # matches repo

    # model
    d_model: int = 64
    expand_dim: int = 6
    num_layers: int = 3
    dropout: float = 0.1
    ff_mult: int = 2
    enable_ff: bool = False
    kernel_size: int = 0
    norm_type: str = "RMSNorm"
    use_coeff_norm: bool = False
    use_init_hidden_state: bool = True
    forget_bias_init_scale: float = 3.0

    # optimization
    lr: float = 3e-4
    weight_decay: float = 0.05
    clip: float = 1.0

    # training
    train_batch_size: int = 64
    eval_batch_size: int = 64
    accum_iter: int = 2
    num_steps: int = 400000
    print_freq: int = 100
    eval_freq: int = 1000

    # notebook practicality
    scan_cpu_fallback_on_mps: bool = True

CFG = Config()

FAST_DEV_RUN = False

if FAST_DEV_RUN:
    CFG.sequence_length = 128
    CFG.num_tokens_memorize = 8
    CFG.train_batch_size = 64
    CFG.eval_batch_size = 64
    CFG.num_steps = 5000
    CFG.num_layers = 2
    CFG.d_model = 64
    CFG.expand_dim = 4
    CFG.lr = 1e-3
else: # change accordingly for a longer run
    CFG.sequence_length = 1024
    CFG.num_tokens_memorize = 8
    CFG.train_batch_size = 32
    CFG.eval_batch_size = 32
    CFG.accum_iter = 1
    CFG.num_steps = 14000      
    CFG.eval_freq = 250
    CFG.print_freq = 100
    CFG.lr = 6e-4
    CFG.num_layers = 3
    CFG.d_model = 64
    CFG.expand_dim = 4
    CFG.num_tokens_memorize = 8

print(CFG)
# Out:
# Config(sequence_length=1024, num_tokens_memorize=8, vocab_size=16, d_model=64, expand_dim=4, num_layers=3, dropout=0.1, ff_mult=2, enable_ff=False, kernel_size=0, norm_type='RMSNorm', use_coeff_norm=False, use_init_hidden_state=True, forget_bias_init_scale=3.0, lr=0.0006, weight_decay=0.05, clip=1.0, train_batch_size=32, eval_batch_size=32, accum_iter=1, num_steps=14000, print_freq=100, eval_freq=250, scan_cpu_fallback_on_mps=True)

# %% [markdown]
# # Helpers from the minRNN repo

# %%
def exists(x):
    return x is not None

def g(x):
    # from official repo
    return torch.where(x >= 0, x + 0.5, x.sigmoid())

def log_g(x):
    # from official repo
    return torch.where(x >= 0, (F.relu(x) + 0.5).log(), -F.softplus(-x))

def associative_scan_log(log_coeffs, log_values, return_log=False):
    """
    Official repo uses:
        a_star = log_coeffs.cumsum(dim=1)
        log_h0_plus_b_star = (log_values - a_star).logcumsumexp(dim=1)
        log_h = a_star + log_h0_plus_b_star
    """
    a_star = log_coeffs.cumsum(dim=1)
    log_h0_plus_b_star = (log_values - a_star).logcumsumexp(dim=1)
    log_h = a_star + log_h0_plus_b_star
    return log_h if return_log else log_h.exp()

# %% [markdown]
# # Normalization, Feedforward and Conv blocks

# %%
class RMSNorm(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.scale = dim ** 0.5
        self.gamma = nn.Parameter(torch.zeros(dim))

    def forward(self, x):
        return F.normalize(x, dim=-1) * self.scale * (self.gamma + 1.0)

class BatchNorm(nn.Module):
    def __init__(self, dim, momentum=0.9):
        super().__init__()
        self.norm = nn.BatchNorm1d(dim, momentum=momentum)

    def forward(self, x):
        # x: [B, L, D]
        return self.norm(x.permute(0, 2, 1)).permute(0, 2, 1)

class GEGLU(nn.Module):
    def __init__(self, dim, mult_bias=True):
        super().__init__()
        self.mult_bias = nn.Parameter(torch.ones(dim)) if mult_bias else 1.0

    def forward(self, x):
        x, gate = x.chunk(2, dim=-1)
        return F.gelu(gate) * x * self.mult_bias

def FeedForward(dim, mult=4, dropout=0.1):
    dim_inner = int(dim * mult)
    return nn.Sequential(
        nn.Linear(dim, dim_inner * 2),
        GEGLU(dim_inner),
        nn.Linear(dim_inner, dim),
        nn.Dropout(dropout),
    )

class CausalDepthWiseConv1d(nn.Module):
    def __init__(self, dim, kernel_size):
        super().__init__()
        self.kernel_size = kernel_size
        self.net = nn.Sequential(
            nn.Conv1d(dim, dim, kernel_size=kernel_size, groups=dim),
            nn.Conv1d(dim, dim, kernel_size=1),
        )

    def forward(self, x):
        # x: [B, L, D]
        x = x.transpose(1, 2)               # [B, D, L]
        x = F.pad(x, (self.kernel_size - 1, 0), value=0.0)
        x = self.net(x)
        return x.transpose(1, 2)            # [B, L, D]

# %% [markdown]
# # minGRU & minLSTM implementation

# %%
class minGRU(nn.Module):
    def __init__(self, dim, expansion_factor=6, use_init_hidden_state=True,
                 scan_cpu_fallback_on_mps=True, **kwargs):
        super().__init__()
        dim_inner = int(dim * expansion_factor)
        self.to_hidden_and_gate = nn.Linear(dim, dim_inner * 2)
        self.to_out = nn.Linear(dim_inner, dim)
        self.init_hidden_state = (
            nn.Parameter(torch.randn(dim_inner), requires_grad=True)
            if use_init_hidden_state else None
        )
        self.scan_cpu_fallback_on_mps = scan_cpu_fallback_on_mps

    def _scan(self, log_coeffs, log_values):
        # optional CPU fallback for MPS numerical stability
        if (
            log_coeffs.device.type == "mps"
            and self.scan_cpu_fallback_on_mps
        ):
            lc_cpu = log_coeffs.cpu()
            lv_cpu = log_values.cpu()
            out_cpu = associative_scan_log(lc_cpu, lv_cpu, return_log=True)
            return out_cpu.to(log_coeffs.device)
        return associative_scan_log(log_coeffs, log_values, return_log=True)

    def forward(self, x, prev_state=None):
        seq_len = x.shape[1]
        hidden, gate = self.to_hidden_and_gate(x).chunk(2, dim=-1)

        if seq_len == 1:
            tilde_h = g(hidden)
            gate = gate.sigmoid()

            if exists(prev_state):
                prev_hidden, _ = prev_state
                out = (1 - gate) * prev_hidden + gate * tilde_h
            elif exists(self.init_hidden_state):
                prev_hidden = g(self.init_hidden_state)
                out = (1 - gate) * prev_hidden + gate * tilde_h
            else:
                out = gate * tilde_h

            next_hidden = out[:, -1:]
            next_log_hidden = out[:, -1:].clamp_min(1e-12).log()

        else:
            log_coeffs = -F.softplus(gate)
            log_z = -F.softplus(-gate)
            log_tilde_h = log_g(hidden)
            log_values = log_z + log_tilde_h

            if exists(prev_state) or exists(self.init_hidden_state):
                if exists(prev_state):
                    _, prev_log_hidden = prev_state
                else:
                    prev_log_hidden = log_g(self.init_hidden_state)
                    prev_log_hidden = prev_log_hidden.unsqueeze(0).unsqueeze(0)
                    prev_log_hidden = prev_log_hidden.repeat(log_values.shape[0], 1, 1)

                log_values = torch.cat((prev_log_hidden, log_values), dim=1)
                log_coeffs = F.pad(log_coeffs, (0, 0, 1, 0))

            log_out = self._scan(log_coeffs, log_values)
            out = torch.exp(log_out[:, -seq_len:])

            next_hidden = out[:, -1:]
            next_log_hidden = log_out[:, -1:]

        out = self.to_out(out)
        return out, (next_hidden, next_log_hidden)


class minLSTM(nn.Module):
    def __init__(self, dim, expansion_factor=6, forget_bias_init_scale=3.0,
                 use_coeff_norm=False, use_init_hidden_state=True,
                 scan_cpu_fallback_on_mps=True, **kwargs):
        super().__init__()
        dim_inner = int(dim * expansion_factor)
        self.to_hidden_and_gate = nn.Linear(dim, dim_inner * 3)
        self.to_out = nn.Linear(dim_inner, dim)
        self.use_coeff_norm = use_coeff_norm
        self.scan_cpu_fallback_on_mps = scan_cpu_fallback_on_mps

        if exists(forget_bias_init_scale):
            with torch.no_grad():
                to_add = torch.zeros_like(self.to_hidden_and_gate.bias)
                to_add[dim_inner:2 * dim_inner] = forget_bias_init_scale
                self.to_hidden_and_gate.bias += to_add

        self.init_hidden_state = (
            nn.Parameter(torch.randn(dim_inner), requires_grad=True)
            if use_init_hidden_state else None
        )

    def _scan(self, log_coeffs, log_values):
        if (
            log_coeffs.device.type == "mps"
            and self.scan_cpu_fallback_on_mps
        ):
            lc_cpu = log_coeffs.cpu()
            lv_cpu = log_values.cpu()
            out_cpu = associative_scan_log(lc_cpu, lv_cpu, return_log=True)
            return out_cpu.to(log_coeffs.device)
        return associative_scan_log(log_coeffs, log_values, return_log=True)

    def forward(self, x, prev_state=None):
        seq_len = x.shape[1]
        hidden, forget_gate, input_gate = self.to_hidden_and_gate(x).chunk(3, dim=-1)

        if seq_len == 1:
            tilde_h = g(hidden)
            input_gate = input_gate.sigmoid()
            forget_gate = forget_gate.sigmoid()

            if self.use_coeff_norm:
                norm = forget_gate + input_gate + 1e-12
                forget_gate = forget_gate / norm
                input_gate = input_gate / norm

            if exists(prev_state):
                prev_hidden, _ = prev_state
                out = forget_gate * prev_hidden + input_gate * tilde_h
            elif exists(self.init_hidden_state):
                prev_hidden = g(self.init_hidden_state)
                out = forget_gate * prev_hidden + input_gate * tilde_h
            else:
                out = input_gate * tilde_h

            next_hidden = out[:, -1:]
            next_log_hidden = out[:, -1:].clamp_min(1e-12).log()

        else:
            if self.use_coeff_norm:
                diff = F.softplus(-forget_gate) - F.softplus(-input_gate)
                log_coeffs = -F.softplus(diff)
                log_val_coeffs = -F.softplus(-diff)
            else:
                log_coeffs = -F.softplus(-forget_gate)
                log_val_coeffs = -F.softplus(-input_gate)

            log_tilde_h = log_g(hidden)
            log_values = log_val_coeffs + log_tilde_h

            if exists(prev_state) or exists(self.init_hidden_state):
                if exists(prev_state):
                    _, prev_log_hidden = prev_state
                else:
                    prev_log_hidden = log_g(self.init_hidden_state)
                    prev_log_hidden = prev_log_hidden.unsqueeze(0).unsqueeze(0)
                    prev_log_hidden = prev_log_hidden.repeat(log_values.shape[0], 1, 1)

                log_values = torch.cat((prev_log_hidden, log_values), dim=1)
                log_coeffs = F.pad(log_coeffs, (0, 0, 1, 0))

            log_out = self._scan(log_coeffs, log_values)
            out = torch.exp(log_out[:, -seq_len:])

            next_hidden = out[:, -1:]
            next_log_hidden = log_out[:, -1:]

        out = self.to_out(out)
        return out, (next_hidden, next_log_hidden)

# %% [markdown]
# # Sequential GRU & LSTM baselines

# %%
class SequentialGRUBlock(nn.Module):
    def __init__(self, dim, expansion_factor=6, **kwargs):
        super().__init__()
        hidden_size = int(dim * expansion_factor)
        self.rnn = nn.GRU(input_size=dim, hidden_size=hidden_size, batch_first=True)
        self.proj = nn.Linear(hidden_size, dim)

    def forward(self, x, prev_state=None):
        if prev_state is not None:
            h0 = prev_state[0].transpose(0, 1)  # [1, B, H]
        else:
            h0 = None
        out, h_n = self.rnn(x, h0)
        out = self.proj(out)
        next_hidden = h_n.transpose(0, 1)      # [B, 1, H]
        next_log_hidden = torch.log(next_hidden.abs().clamp_min(1e-12))
        return out, (next_hidden, next_log_hidden)

class SequentialLSTMBlock(nn.Module):
    def __init__(self, dim, expansion_factor=6, **kwargs):
        super().__init__()
        hidden_size = int(dim * expansion_factor)
        self.rnn = nn.LSTM(input_size=dim, hidden_size=hidden_size, batch_first=True)
        self.proj = nn.Linear(hidden_size, dim)

    def forward(self, x, prev_state=None):
        if prev_state is not None:
            h0 = prev_state[0].transpose(0, 1)
            c0 = prev_state[0].transpose(0, 1)
            state = (h0, c0)
        else:
            state = None
        out, (h_n, c_n) = self.rnn(x, state)
        out = self.proj(out)
        next_hidden = h_n.transpose(0, 1)
        next_log_hidden = torch.log(next_hidden.abs().clamp_min(1e-12))
        return out, (next_hidden, next_log_hidden)

# %% [markdown]
# # Full model wrapper

# %%
class ReplicationModel(nn.Module):
    def __init__(self, module_name: str, cfg: Config):
        super().__init__()
        self.module_name = module_name

        self.token_emb = nn.Embedding(cfg.vocab_size, cfg.d_model)

        norm_cls = RMSNorm if cfg.norm_type == "RMSNorm" else BatchNorm

        block_map = {
            "minGRU": lambda: minGRU(
                dim=cfg.d_model,
                expansion_factor=cfg.expand_dim,
                use_init_hidden_state=cfg.use_init_hidden_state,
                scan_cpu_fallback_on_mps=cfg.scan_cpu_fallback_on_mps,
            ),
            "minLSTM": lambda: minLSTM(
                dim=cfg.d_model,
                expansion_factor=cfg.expand_dim,
                forget_bias_init_scale=cfg.forget_bias_init_scale,
                use_coeff_norm=cfg.use_coeff_norm,
                use_init_hidden_state=cfg.use_init_hidden_state,
                scan_cpu_fallback_on_mps=cfg.scan_cpu_fallback_on_mps,
            ),
            "GRU": lambda: SequentialGRUBlock(
                dim=cfg.d_model,
                expansion_factor=cfg.expand_dim,
            ),
            "LSTM": lambda: SequentialLSTMBlock(
                dim=cfg.d_model,
                expansion_factor=cfg.expand_dim,
            ),
        }

        self.layers = nn.ModuleList()
        for _ in range(cfg.num_layers):
            conv = CausalDepthWiseConv1d(cfg.d_model, cfg.kernel_size) if cfg.kernel_size not in [None, 0] else None
            self.layers.append(nn.ModuleList([
                conv,
                norm_cls(cfg.d_model),
                block_map[module_name](),
                norm_cls(cfg.d_model),
                FeedForward(cfg.d_model, mult=cfg.ff_mult, dropout=cfg.dropout) if cfg.enable_ff else None,
            ]))

        self.final_norm = norm_cls(cfg.d_model)
        self.to_out = nn.Linear(cfg.d_model, cfg.vocab_size, bias=False)

    def forward(self, x, return_states=False, prev_states=None):
        x = self.token_emb(x)

        if prev_states is None:
            prev_states = [None for _ in range(len(self.layers))]

        next_prev_states = []
        for (conv, norm1, rnn_block, norm2, ff), prev_state in zip(self.layers, prev_states):
            if conv is not None:
                x = x + conv(x)

            out, next_state = rnn_block(norm1(x), prev_state=prev_state)
            x = x + out
            next_prev_states.append(next_state)

            if ff is not None:
                x = x + ff(norm2(x))

        logits = self.to_out(self.final_norm(x))
        return (logits, next_prev_states) if return_states else logits

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# # Selective Copy Task sampler

# %%
VOCAB_SIZE = CFG.vocab_size
EMPTY = VOCAB_SIZE - 1
PRED = 0

class SelectiveCopyTaskSampler:
    def __init__(self, sequence_length, num_tokens_memorize, seed=None):
        self.sequence_length = sequence_length
        self.num_tokens_memorize = num_tokens_memorize
        if seed is not None:
            set_seed(seed)

    def sample(self, batch_size=16, device="cpu"):
        # tokens to remember: values 1..VOCAB_SIZE-2
        tokens = torch.randint(
            low=1,
            high=VOCAB_SIZE - 1,
            size=(batch_size, self.num_tokens_memorize),
            device=device
        )

        inds = torch.stack([
            torch.randperm(self.sequence_length, device=device)[:self.num_tokens_memorize]
            for _ in range(batch_size)
        ], dim=0)
        inds, _ = inds.sort(dim=-1)

        sequence = EMPTY * torch.ones((batch_size, self.sequence_length), dtype=torch.long, device=device)
        sequence.scatter_(-1, inds, tokens)

        markers = PRED * torch.ones((batch_size, self.num_tokens_memorize), dtype=torch.long, device=device)

        x = torch.cat((sequence, markers), dim=1)  # [B, L + M]
        y = tokens                                  # [B, M]
        return {"x": x, "y": y}

# %% [markdown]
# # Loss function and metrics

# %%
def selective_copy_loss_and_acc(logits, batch, cfg: Config):
    # logits: [B, L+M, V]
    # only last M positions matter
    logits = logits[:, -cfg.num_tokens_memorize:]   # [B, M, V]
    target = batch["y"]                             # [B, M]

    loss = F.cross_entropy(
        logits.reshape(-1, logits.size(-1)),
        target.reshape(-1)
    )
    acc = (logits.argmax(dim=-1) == target).float().mean()
    return loss, acc

# %% [markdown]
# # Train & Evaluation

# %%
@torch.no_grad()
def evaluate_model(model, cfg: Config, seed=0, num_batches=100, sequence_length=None):
    was_training = model.training
    model.eval()

    seq_len = sequence_length if sequence_length is not None else cfg.sequence_length
    sampler = SelectiveCopyTaskSampler(
        sequence_length=seq_len,
        num_tokens_memorize=cfg.num_tokens_memorize,
        seed=seed
    )

    losses = []
    accs = []

    for _ in range(num_batches):
        batch = sampler.sample(batch_size=cfg.eval_batch_size, device=DEVICE)
        logits = model(batch["x"])
        loss, acc = selective_copy_loss_and_acc(logits, batch, cfg)
        losses.append(loss.item())
        accs.append(acc.item())

    if was_training:
        model.train()

    return {
        "loss": float(np.mean(losses)),
        "acc": float(np.mean(accs)),
    }


def train_model(model_name: str, cfg: Config, seed=42, verbose=True):
    set_seed(seed)

    model = ReplicationModel(model_name, cfg).to(DEVICE)
    sampler = SelectiveCopyTaskSampler(
        sequence_length=cfg.sequence_length,
        num_tokens_memorize=cfg.num_tokens_memorize,
        seed=seed
    )

    params_with_decay = []
    params_without_decay = []

    for name, param in model.named_parameters():
        if "to_hidden_and_gate" in name:
            params_without_decay.append(param)
        else:
            params_with_decay.append(param)

    optimizer = torch.optim.AdamW(
        [
            {"params": params_with_decay, "weight_decay": cfg.weight_decay},
            {"params": params_without_decay, "weight_decay": 0.0},
        ],
        lr=cfg.lr,
    )

    history = {
        "step": [],
        "train_loss": [],
        "train_acc": [],
        "val_loss": [],
        "val_acc": [],
    }

    best_val_acc = -1.0
    best_state = None
    start = time.time()

    model.train()
    optimizer.zero_grad()

    running_loss = []
    running_acc = []

    for step in range(1, cfg.num_steps + 1):
        for _ in range(cfg.accum_iter):
            batch = sampler.sample(batch_size=cfg.train_batch_size // cfg.accum_iter, device=DEVICE)
            logits = model(batch["x"])
            loss, acc = selective_copy_loss_and_acc(logits, batch, cfg)
            (loss / cfg.accum_iter).backward()

            running_loss.append(loss.item())
            running_acc.append(acc.item())

        if cfg.clip is not None:
            torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.clip)

        optimizer.step()
        optimizer.zero_grad()

        if step % cfg.print_freq == 0:
            mean_train_loss = float(np.mean(running_loss[-cfg.print_freq:]))
            mean_train_acc = float(np.mean(running_acc[-cfg.print_freq:]))

            if verbose:
                print(
                    f"[{model_name}] step={step:6d} "
                    f"train_loss={mean_train_loss:.4f} "
                    f"train_acc={mean_train_acc:.4f}"
                )

        if step % cfg.eval_freq == 0 or step == cfg.num_steps:
            val_metrics = evaluate_model(model, cfg, seed=0, num_batches=50)

            model.train()

            history["step"].append(step)
            history["train_loss"].append(float(np.mean(running_loss[-cfg.eval_freq:])))
            history["train_acc"].append(float(np.mean(running_acc[-cfg.eval_freq:])))
            history["val_loss"].append(val_metrics["loss"])
            history["val_acc"].append(val_metrics["acc"])

            if verbose:
                print(
                    f"   -> val_loss={val_metrics['loss']:.4f} "
                    f"val_acc={val_metrics['acc']:.4f}"
                )

            if val_metrics["acc"] >= best_val_acc:
                best_val_acc = val_metrics["acc"]
                best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    total_time = time.time() - start

    if best_state is not None:
        model.load_state_dict(best_state)

    test_metrics = evaluate_model(model, cfg, seed=1, num_batches=100)

    result = {
        "model_name": model_name,
        "seed": seed,
        "params": count_parameters(model),
        "best_val_acc": best_val_acc,
        "test_loss": test_metrics["loss"],
        "test_acc": test_metrics["acc"],
        "train_time_sec": total_time,
        "history": history,
        "model": model,
    }

    return result

# %% [markdown]
# # Sanity check on one batch

# %%
set_seed(42)

sampler = SelectiveCopyTaskSampler(CFG.sequence_length, CFG.num_tokens_memorize, seed=42)
batch = sampler.sample(batch_size=2, device=DEVICE)

print("x shape:", batch["x"].shape)
print("y shape:", batch["y"].shape)
print("example x[0, :40]:", batch["x"][0, :40])
print("target y[0]:", batch["y"][0])

test_model = ReplicationModel("minGRU", CFG).to(DEVICE)
with torch.no_grad():
    logits = test_model(batch["x"])
print("logits shape:", logits.shape)
# Out:
# x shape: torch.Size([2, 1032])
# y shape: torch.Size([2, 8])
# example x[0, :40]: tensor([15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#         15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#         15, 15, 15, 15], device='cuda:0')
# target y[0]: tensor([ 2,  6, 13,  7,  6, 10, 11, 11], device='cuda:0')
# logits shape: torch.Size([2, 1032, 16])

# %% [markdown]
# # Train 1 model

# %%
FAST_DEV_RUN = False
single_result = train_model("minGRU", CFG, seed=42, verbose=True)
print({
    "params": single_result["params"],
    "best_val_acc": single_result["best_val_acc"],
    "test_acc": single_result["test_acc"],
    "test_loss": single_result["test_loss"],
    "train_time_sec": single_result["train_time_sec"],
})
# Out:
# [minGRU] step=   100 train_loss=2.6603 train_acc=0.0714
# [minGRU] step=   200 train_loss=2.6476 train_acc=0.0707
#    -> val_loss=2.6443 val_acc=0.0699
# [minGRU] step=   300 train_loss=2.6442 train_acc=0.0723
# [minGRU] step=   400 train_loss=2.6444 train_acc=0.0726
# [minGRU] step=   500 train_loss=2.6434 train_acc=0.0686
#    -> val_loss=2.6470 val_acc=0.0723
# [minGRU] step=   600 train_loss=2.6441 train_acc=0.0732
# [minGRU] step=   700 train_loss=2.6432 train_acc=0.0704
#    -> val_loss=2.6452 val_acc=0.0723
# [minGRU] step=   800 train_loss=2.6424 train_acc=0.0721
# [minGRU] step=   900 train_loss=2.6165 train_acc=0.1039
# [minGRU] step=  1000 train_loss=2.5798 train_acc=0.1160
#    -> val_loss=2.5677 val_acc=0.1230
# [minGRU] step=  1100 train_loss=2.5112 train_acc=0.1512
# [minGRU] step=  1200 train_loss=2.4544 train_acc=0.1640
#    -> val_loss=2.4485 val_acc=0.1620
# [minGRU] step=  1300 train_loss=2.4433 train_acc=0.1680
# [minGRU] step=  1400 train_loss=2.4358 train_acc=0.1756
# [minGRU] step=  1500 train_loss=2.4126 train_acc=0.1860
#    -> val_loss=2.3911 val_acc=0.1979
# [minGRU] step=  1600 train_loss=2.3317 train_acc=0.2184
# [minGRU] step=  1700 train_loss=2.2402 train_acc=0.2468
#    -> val_loss=2.1418 val_acc=0.2756
# [minGRU] step=  1800 train_loss=2.1472 train_acc=0.2706
# [minGRU] step=  1900 train_loss=2.0781 train_acc=0.2955
# [minGRU] step=  2000 train_loss=2.0252 train_acc=0.3104
#    -> val_loss=1.9824 val_acc=0.3185
# [minGRU] step=  2100 train_loss=1.9568 train_acc=0.3305
# [minGRU] step=  2200 train_loss=1.8840 train_acc=0.3527
#    -> val_loss=1.8098 val_acc=0.3728
# [minGRU] step=  2300 train_loss=1.8096 train_acc=0.3800
# [minGRU] step=  2400 train_loss=1.7392 train_acc=0.3984
# [minGRU] step=  2500 train_loss=1.6825 train_acc=0.4189
#    -> val_loss=1.6558 val_acc=0.4273
# [minGRU] step=  2600 train_loss=1.6279 train_acc=0.4372
# [minGRU] step=  2700 train_loss=1.5732 train_acc=0.4530
#    -> val_loss=1.5425 val_acc=0.4677
# [minGRU] step=  2800 train_loss=1.5339 train_acc=0.4708
# [minGRU] step=  2900 train_loss=1.4749 train_acc=0.4883
# [minGRU] step=  3000 train_loss=1.4139 train_acc=0.5078
#    -> val_loss=1.3848 val_acc=0.5111
# [minGRU] step= 10200 train_loss=0.1480 train_acc=0.9445
#    -> val_loss=0.1849 val_acc=0.9330
# [minGRU] step= 10300 train_loss=0.1405 train_acc=0.9484
# [minGRU] step= 10400 train_loss=0.1403 train_acc=0.9488
# [minGRU] step= 10500 train_loss=0.1335 train_acc=0.9515
#    -> val_loss=0.1695 val_acc=0.9395
# [minGRU] step= 10600 train_loss=0.1323 train_acc=0.9521
# [minGRU] step= 10700 train_loss=0.1311 train_acc=0.9513
#    -> val_loss=0.1488 val_acc=0.9452
# [minGRU] step= 10800 train_loss=0.1290 train_acc=0.9522
# [minGRU] step= 10900 train_loss=0.1162 train_acc=0.9581
# [minGRU] step= 11000 train_loss=0.1182 train_acc=0.9566
#    -> val_loss=0.1692 val_acc=0.9390
# [minGRU] step= 11100 train_loss=0.1278 train_acc=0.9536
# [minGRU] step= 11200 train_loss=0.1283 train_acc=0.9538
#    -> val_loss=0.1877 val_acc=0.9290
# [minGRU] step= 11300 train_loss=0.1479 train_acc=0.9475
# [minGRU] step= 11400 train_loss=0.1132 train_acc=0.9588
# [minGRU] step= 11500 train_loss=0.1128 train_acc=0.9584
#    -> val_loss=0.1524 val_acc=0.9433
# [minGRU] step= 11600 train_loss=0.1044 train_acc=0.9608
# [minGRU] step= 11700 train_loss=0.1011 train_acc=0.9628
#    -> val_loss=0.1506 val_acc=0.9450
# [minGRU] step= 11800 train_loss=0.1038 train_acc=0.9620
# [minGRU] step= 11900 train_loss=0.0894 train_acc=0.9680
# [minGRU] step= 12000 train_loss=0.0965 train_acc=0.9646
#    -> val_loss=0.1247 val_acc=0.9547
# [minGRU] step= 12100 train_loss=0.0861 train_acc=0.9687
# [minGRU] step= 12200 train_loss=0.0944 train_acc=0.9655
#    -> val_loss=0.1095 val_acc=0.9599
# [minGRU] step= 12300 train_loss=0.0877 train_acc=0.9686
# [minGRU] step= 12400 train_loss=0.0818 train_acc=0.9713
# [minGRU] step= 12500 train_loss=0.0845 train_acc=0.9700
#    -> val_loss=0.1013 val_acc=0.9628
# [minGRU] step= 12600 train_loss=0.0818 train_acc=0.9709
# [minGRU] step= 12700 train_loss=0.0761 train_acc=0.9738
#    -> val_loss=0.1247 val_acc=0.9573
# [minGRU] step= 12800 train_loss=0.0798 train_acc=0.9721
# [minGRU] step= 12900 train_loss=0.0760 train_acc=0.9724
# [minGRU] step= 13000 train_loss=0.0797 train_acc=0.9707
#    -> val_loss=0.0913 val_acc=0.9670
# [minGRU] step= 13100 train_loss=0.0745 train_acc=0.9730
# [minGRU] step= 13200 train_loss=0.0702 train_acc=0.9755
#    -> val_loss=0.1577 val_acc=0.9434
# [minGRU] step= 13300 train_loss=0.1005 train_acc=0.9640
# [minGRU] step= 13400 train_loss=0.0694 train_acc=0.9747
# [minGRU] step= 13500 train_loss=0.0665 train_acc=0.9766
#    -> val_loss=0.1027 val_acc=0.9630
# [minGRU] step= 13600 train_loss=0.0617 train_acc=0.9789
# [minGRU] step= 13700 train_loss=0.0642 train_acc=0.9774
#    -> val_loss=0.0791 val_acc=0.9725
# [minGRU] step= 13800 train_loss=0.0625 train_acc=0.9778
# [minGRU] step= 13900 train_loss=0.0625 train_acc=0.9777
# [minGRU] step= 14000 train_loss=0.0643 train_acc=0.9776
#    -> val_loss=0.0728 val_acc=0.9754
# {'params': 152448, 'best_val_acc': 0.975390625, 'test_acc': 0.9752734375, 'test_loss': 0.07203896010294557, 'train_time_sec': 654.6338851451874}

# %% [markdown]
# # Plot training curve for 1 model

# %%
hist = pd.DataFrame(single_result["history"])

plt.figure(figsize=(8, 5))
plt.plot(hist["step"], hist["train_acc"], label="train acc")
plt.plot(hist["step"], hist["val_acc"], label="val acc")
plt.xlabel("step")
plt.ylabel("accuracy")
plt.title("Selective Copy: minGRU training curve")
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(hist["step"], hist["train_loss"], label="train loss")
plt.plot(hist["step"], hist["val_loss"], label="val loss")
plt.xlabel("step")
plt.ylabel("cross-entropy loss")
plt.title("Selective Copy: minGRU loss curve")
plt.legend()
plt.show()

# %% [markdown]
# # Compare across all models and seeds

# %%
MODELS = ["minGRU", "minLSTM", "GRU", "LSTM"]
SEEDS = [42, 43, 44]   # increase to 5 if have time

all_results = []

for model_name in MODELS:
    for seed in SEEDS:
        print(f"\n===== Training {model_name}, seed={seed} =====")
        result = train_model(model_name, CFG, seed=seed, verbose=True)
        all_results.append(result)
# Out:
# ===== Training minGRU, seed=42 =====
# [minGRU] step=   100 train_loss=2.6603 train_acc=0.0714
# [minGRU] step=   200 train_loss=2.6476 train_acc=0.0707
#    -> val_loss=2.6443 val_acc=0.0699
# [minGRU] step=   300 train_loss=2.6442 train_acc=0.0723
# [minGRU] step=   400 train_loss=2.6444 train_acc=0.0726
# [minGRU] step=   500 train_loss=2.6434 train_acc=0.0686
#    -> val_loss=2.6470 val_acc=0.0723
# [minGRU] step=   600 train_loss=2.6441 train_acc=0.0732
# [minGRU] step=   700 train_loss=2.6432 train_acc=0.0704
#    -> val_loss=2.6452 val_acc=0.0723
# [minGRU] step=   800 train_loss=2.6424 train_acc=0.0721
# [minGRU] step=   900 train_loss=2.6165 train_acc=0.1039
# [minGRU] step=  1000 train_loss=2.5798 train_acc=0.1160
#    -> val_loss=2.5677 val_acc=0.1230
# [minGRU] step=  1100 train_loss=2.5112 train_acc=0.1512
# [minGRU] step=  1200 train_loss=2.4544 train_acc=0.1640
#    -> val_loss=2.4485 val_acc=0.1620
# [minGRU] step=  1300 train_loss=2.4433 train_acc=0.1680
# [minGRU] step=  1400 train_loss=2.4358 train_acc=0.1756
# [minGRU] step=  1500 train_loss=2.4126 train_acc=0.1860
#    -> val_loss=2.3911 val_acc=0.1979
# [minGRU] step=  1600 train_loss=2.3317 train_acc=0.2184
# [minGRU] step=  1700 train_loss=2.2402 train_acc=0.2468
#    -> val_loss=2.1418 val_acc=0.2756
# [minGRU] step=  1800 train_loss=2.1472 train_acc=0.2706
# [minGRU] step=  1900 train_loss=2.0781 train_acc=0.2955
# [minGRU] step=  2000 train_loss=2.0252 train_acc=0.3104
# [minGRU] step=  9200 train_loss=0.1818 train_acc=0.9319
#    -> val_loss=0.1941 val_acc=0.9265
# [minGRU] step=  9300 train_loss=0.1813 train_acc=0.9311
# [minGRU] step=  9400 train_loss=0.1853 train_acc=0.9307
# [minGRU] step=  9500 train_loss=0.1847 train_acc=0.9294
#    -> val_loss=0.2008 val_acc=0.9241
# [minGRU] step=  9600 train_loss=0.1878 train_acc=0.9303
# [minGRU] step=  9700 train_loss=0.1666 train_acc=0.9386
#    -> val_loss=0.2246 val_acc=0.9181
# [minGRU] step=  9800 train_loss=0.1666 train_acc=0.9367
# [minGRU] step=  9900 train_loss=0.1579 train_acc=0.9413
# [minGRU] step= 10000 train_loss=0.1511 train_acc=0.9437
#    -> val_loss=0.1993 val_acc=0.9288
# [minGRU] step= 10100 train_loss=0.1429 train_acc=0.9478
# [minGRU] step= 10200 train_loss=0.1480 train_acc=0.9445
#    -> val_loss=0.1849 val_acc=0.9330
# [minGRU] step= 10300 train_loss=0.1405 train_acc=0.9484
# [minGRU] step= 10400 train_loss=0.1403 train_acc=0.9488
# [minGRU] step= 10500 train_loss=0.1335 train_acc=0.9515
#    -> val_loss=0.1695 val_acc=0.9395
# [minGRU] step= 10600 train_loss=0.1323 train_acc=0.9521
# [minGRU] step= 10700 train_loss=0.1311 train_acc=0.9513
#    -> val_loss=0.1488 val_acc=0.9452
# [minGRU] step= 10800 train_loss=0.1290 train_acc=0.9522
# [minGRU] step= 10900 train_loss=0.1162 train_acc=0.9581
# [minGRU] step= 11000 train_loss=0.1182 train_acc=0.9566
#    -> val_loss=0.1692 val_acc=0.9390
# [minGRU] step= 11100 train_loss=0.1278 train_acc=0.9536
# [minGRU] step= 11200 train_loss=0.1283 train_acc=0.9538
#    -> val_loss=0.1877 val_acc=0.9290
# [minGRU] step= 11300 train_loss=0.1479 train_acc=0.9475
# [minGRU] step= 11400 train_loss=0.1132 train_acc=0.9588
# [minGRU] step= 11500 train_loss=0.1128 train_acc=0.9584
#    -> val_loss=0.1524 val_acc=0.9433
# [minGRU] step= 11600 train_loss=0.1044 train_acc=0.9608
# [minGRU] step= 11700 train_loss=0.1011 train_acc=0.9628
#    -> val_loss=0.1506 val_acc=0.9450
# [minGRU] step= 11800 train_loss=0.1038 train_acc=0.9620
# [minGRU] step= 11900 train_loss=0.0894 train_acc=0.9680
# [minGRU] step= 12000 train_loss=0.0965 train_acc=0.9646
#    -> val_loss=0.1247 val_acc=0.9547
# [minGRU] step= 12100 train_loss=0.0861 train_acc=0.9687
# [minGRU] step= 12200 train_loss=0.0944 train_acc=0.9655
#    -> val_loss=0.1095 val_acc=0.9599
# [minGRU] step= 12300 train_loss=0.0877 train_acc=0.9686
# [minGRU] step= 12400 train_loss=0.0818 train_acc=0.9713
# [minGRU] step= 12500 train_loss=0.0845 train_acc=0.9700
#    -> val_loss=0.1013 val_acc=0.9628
# [minGRU] step= 12600 train_loss=0.0818 train_acc=0.9709
# [minGRU] step= 12700 train_loss=0.0761 train_acc=0.9738
#    -> val_loss=0.1247 val_acc=0.9573
# [minGRU] step= 12800 train_loss=0.0798 train_acc=0.9721
# [minGRU] step= 12900 train_loss=0.0760 train_acc=0.9724
# [minGRU] step= 13000 train_loss=0.0797 train_acc=0.9707
#    -> val_loss=0.0913 val_acc=0.9670
# [minGRU] step= 13100 train_loss=0.0745 train_acc=0.9730
# [minGRU] step= 13200 train_loss=0.0702 train_acc=0.9755
#    -> val_loss=0.1577 val_acc=0.9434
# [minGRU] step= 13300 train_loss=0.1005 train_acc=0.9640
# [minGRU] step= 13400 train_loss=0.0694 train_acc=0.9747
# [minGRU] step= 13500 train_loss=0.0665 train_acc=0.9766
#    -> val_loss=0.1027 val_acc=0.9630
# [minGRU] step= 13600 train_loss=0.0617 train_acc=0.9789
# [minGRU] step= 13700 train_loss=0.0642 train_acc=0.9774
#    -> val_loss=0.0791 val_acc=0.9725
# [minGRU] step= 13800 train_loss=0.0625 train_acc=0.9778
# [minGRU] step= 13900 train_loss=0.0625 train_acc=0.9777
# [minGRU] step= 14000 train_loss=0.0643 train_acc=0.9776
#    -> val_loss=0.0728 val_acc=0.9754
#
# ===== Training minGRU, seed=43 =====
# [minGRU] step=   100 train_loss=2.6629 train_acc=0.0722
# [minGRU] step=   200 train_loss=2.6470 train_acc=0.0664
#    -> val_loss=2.6461 val_acc=0.0683
# [minGRU] step=   300 train_loss=2.6460 train_acc=0.0698
# [minGRU] step=   400 train_loss=2.6447 train_acc=0.0726
# [minGRU] step=   500 train_loss=2.6435 train_acc=0.0687
#    -> val_loss=2.6466 val_acc=0.0723
# [minGRU] step=   600 train_loss=2.6442 train_acc=0.0721
# [minGRU] step=   700 train_loss=2.6432 train_acc=0.0700
#    -> val_loss=2.6459 val_acc=0.0716
# [minGRU] step=   800 train_loss=2.6432 train_acc=0.0701
# [minGRU] step=   900 train_loss=2.6418 train_acc=0.0738
# [minGRU] step=  1000 train_loss=2.6198 train_acc=0.0966
#    -> val_loss=2.5841 val_acc=0.1052
# [minGRU] step=  1100 train_loss=2.5329 train_acc=0.1312
# [minGRU] step=  1200 train_loss=2.4575 train_acc=0.1565
#    -> val_loss=2.4017 val_acc=0.1702
# [minGRU] step=  1300 train_loss=2.4036 train_acc=0.1694
# [minGRU] step=  1400 train_loss=2.3324 train_acc=0.1997
# [minGRU] step=  1500 train_loss=2.1977 train_acc=0.2378
#    -> val_loss=2.1359 val_acc=0.2555
# [minGRU] step=  1600 train_loss=2.1081 train_acc=0.2619
# [minGRU] step=  1700 train_loss=2.0502 train_acc=0.2843
#    -> val_loss=2.0006 val_acc=0.3073
# [minGRU] step=  1800 train_loss=1.9843 train_acc=0.3078
# [minGRU] step=  1900 train_loss=1.8957 train_acc=0.3254
# [minGRU] step=  2000 train_loss=1.8340 train_acc=0.3438
#    -> val_loss=1.8647 val_acc=0.3312
# [minGRU] step=  2100 train_loss=1.8142 train_acc=0.3498
# [minGRU] step=  2200 train_loss=1.7748 train_acc=0.3571
# [minGRU] step=  9400 train_loss=1.0212 train_acc=0.5853
# [minGRU] step=  9500 train_loss=1.0637 train_acc=0.5711
#    -> val_loss=1.0882 val_acc=0.5627
# [minGRU] step=  9600 train_loss=0.9969 train_acc=0.5948
# [minGRU] step=  9700 train_loss=1.0586 train_acc=0.5730
#    -> val_loss=0.9987 val_acc=0.5951
# [minGRU] step=  9800 train_loss=0.9749 train_acc=0.6054
# [minGRU] step=  9900 train_loss=0.9535 train_acc=0.6122
# [minGRU] step= 10000 train_loss=0.9740 train_acc=0.6078
#    -> val_loss=0.9956 val_acc=0.5975
# [minGRU] step= 10100 train_loss=1.0213 train_acc=0.5908
# [minGRU] step= 10200 train_loss=0.9724 train_acc=0.6058
#    -> val_loss=1.0729 val_acc=0.5714
# [minGRU] step= 10300 train_loss=0.9907 train_acc=0.5990
# [minGRU] step= 10400 train_loss=0.9319 train_acc=0.6243
# [minGRU] step= 10500 train_loss=0.9292 train_acc=0.6252
#    -> val_loss=0.9543 val_acc=0.6209
# [minGRU] step= 10600 train_loss=0.8868 train_acc=0.6414
# [minGRU] step= 10700 train_loss=0.8749 train_acc=0.6480
#    -> val_loss=0.8970 val_acc=0.6423
# [minGRU] step= 10800 train_loss=0.8389 train_acc=0.6629
# [minGRU] step= 10900 train_loss=0.8264 train_acc=0.6670
# [minGRU] step= 11000 train_loss=0.8318 train_acc=0.6681
#    -> val_loss=0.8991 val_acc=0.6385
# [minGRU] step= 11100 train_loss=0.8306 train_acc=0.6651
# [minGRU] step= 11200 train_loss=0.8034 train_acc=0.6748
#    -> val_loss=0.8318 val_acc=0.6699
# [minGRU] step= 11300 train_loss=0.7923 train_acc=0.6813
# [minGRU] step= 11400 train_loss=0.7758 train_acc=0.6860
# [minGRU] step= 11500 train_loss=0.7522 train_acc=0.6990
#    -> val_loss=0.8154 val_acc=0.6711
# [minGRU] step= 11600 train_loss=0.7572 train_acc=0.6971
# [minGRU] step= 11700 train_loss=0.7220 train_acc=0.7120
#    -> val_loss=0.7216 val_acc=0.7069
# [minGRU] step= 11800 train_loss=0.6850 train_acc=0.7238
# [minGRU] step= 11900 train_loss=0.7123 train_acc=0.7164
# [minGRU] step= 12000 train_loss=0.7087 train_acc=0.7186
#    -> val_loss=0.7916 val_acc=0.6830
# [minGRU] step= 12100 train_loss=0.7039 train_acc=0.7192
# [minGRU] step= 12200 train_loss=0.6921 train_acc=0.7224
#    -> val_loss=0.6924 val_acc=0.7251
# [minGRU] step= 12300 train_loss=0.6654 train_acc=0.7373
# [minGRU] step= 12400 train_loss=0.6654 train_acc=0.7357
# [minGRU] step= 12500 train_loss=0.6451 train_acc=0.7413
#    -> val_loss=0.6574 val_acc=0.7384
# [minGRU] step= 12600 train_loss=0.6207 train_acc=0.7509
# [minGRU] step= 12700 train_loss=0.6141 train_acc=0.7531
#    -> val_loss=0.6698 val_acc=0.7313
# [minGRU] step= 12800 train_loss=0.6155 train_acc=0.7527
# [minGRU] step= 12900 train_loss=0.5910 train_acc=0.7642
# [minGRU] step= 13000 train_loss=0.6143 train_acc=0.7545
#    -> val_loss=0.6338 val_acc=0.7472
# [minGRU] step= 13100 train_loss=0.5816 train_acc=0.7649
# [minGRU] step= 13200 train_loss=0.6272 train_acc=0.7526
#    -> val_loss=0.6256 val_acc=0.7531
# [minGRU] step= 13300 train_loss=0.5871 train_acc=0.7658
# [minGRU] step= 13400 train_loss=0.5708 train_acc=0.7696
# [minGRU] step= 13500 train_loss=0.5599 train_acc=0.7720
#    -> val_loss=0.6020 val_acc=0.7605
# [minGRU] step= 13600 train_loss=0.6028 train_acc=0.7595
# [minGRU] step= 13700 train_loss=0.5603 train_acc=0.7752
#    -> val_loss=0.5896 val_acc=0.7663
# [minGRU] step= 13800 train_loss=0.5375 train_acc=0.7854
# [minGRU] step= 13900 train_loss=0.5432 train_acc=0.7810
# [minGRU] step= 14000 train_loss=0.5329 train_acc=0.7857
#    -> val_loss=0.5576 val_acc=0.7795
#
# ===== Training minGRU, seed=44 =====
# [minGRU] step=   100 train_loss=2.6579 train_acc=0.0698
# [minGRU] step=   200 train_loss=2.6459 train_acc=0.0703
#    -> val_loss=2.6478 val_acc=0.0727
# [minGRU] step=   300 train_loss=2.6451 train_acc=0.0710
# [minGRU] step=   400 train_loss=2.6441 train_acc=0.0727
# [minGRU] step=   500 train_loss=2.6436 train_acc=0.0704
#    -> val_loss=2.6475 val_acc=0.0723
# [minGRU] step=   600 train_loss=2.6439 train_acc=0.0700
# [minGRU] step=   700 train_loss=2.6268 train_acc=0.0924
#    -> val_loss=2.5849 val_acc=0.1145
# [minGRU] step=   800 train_loss=2.5854 train_acc=0.1140
# [minGRU] step=   900 train_loss=2.5791 train_acc=0.1123
# [minGRU] step=  1000 train_loss=2.5709 train_acc=0.1196
#    -> val_loss=2.5611 val_acc=0.1304
# [minGRU] step=  1100 train_loss=2.5367 train_acc=0.1422
# [minGRU] step=  1200 train_loss=2.4467 train_acc=0.1803
#    -> val_loss=2.2757 val_acc=0.2322
# [minGRU] step=  1300 train_loss=2.2875 train_acc=0.2333
# [minGRU] step=  1400 train_loss=2.2105 train_acc=0.2519
# [minGRU] step=  1500 train_loss=2.1159 train_acc=0.2734
#    -> val_loss=2.1095 val_acc=0.2784
# [minGRU] step=  1600 train_loss=2.0387 train_acc=0.2964
# [minGRU] step=  1700 train_loss=1.9887 train_acc=0.3063
#    -> val_loss=1.9538 val_acc=0.3178
# [minGRU] step=  1800 train_loss=1.9403 train_acc=0.3243
# [minGRU] step=  1900 train_loss=1.9168 train_acc=0.3277
# [minGRU] step=  2000 train_loss=1.8430 train_acc=0.3479
#    -> val_loss=1.8504 val_acc=0.3422
# [minGRU] step=  2100 train_loss=1.8233 train_acc=0.3549
# [minGRU] step=  2200 train_loss=1.7656 train_acc=0.3672
#    -> val_loss=1.7394 val_acc=0.3702
# [minGRU] step=  2300 train_loss=1.7208 train_acc=0.3788
# [minGRU] step=  2400 train_loss=1.7171 train_acc=0.3766
# [minGRU] step=  2500 train_loss=1.7229 train_acc=0.3761
# [minGRU] step=  9700 train_loss=0.3397 train_acc=0.8712
#    -> val_loss=0.3648 val_acc=0.8593
# [minGRU] step=  9800 train_loss=0.3111 train_acc=0.8820
# [minGRU] step=  9900 train_loss=0.3080 train_acc=0.8830
# [minGRU] step= 10000 train_loss=0.2940 train_acc=0.8871
#    -> val_loss=0.3536 val_acc=0.8676
# [minGRU] step= 10100 train_loss=0.2891 train_acc=0.8886
# [minGRU] step= 10200 train_loss=0.3014 train_acc=0.8845
#    -> val_loss=0.3412 val_acc=0.8705
# [minGRU] step= 10300 train_loss=0.2750 train_acc=0.8941
# [minGRU] step= 10400 train_loss=0.2874 train_acc=0.8907
# [minGRU] step= 10500 train_loss=0.2682 train_acc=0.8994
#    -> val_loss=0.3141 val_acc=0.8828
# [minGRU] step= 10600 train_loss=0.2578 train_acc=0.9009
# [minGRU] step= 10700 train_loss=0.2715 train_acc=0.8956
#    -> val_loss=0.3373 val_acc=0.8746
# [minGRU] step= 10800 train_loss=0.2649 train_acc=0.8988
# [minGRU] step= 10900 train_loss=0.2632 train_acc=0.8979
# [minGRU] step= 11000 train_loss=0.3507 train_acc=0.8673
#    -> val_loss=0.3613 val_acc=0.8629
# [minGRU] step= 11100 train_loss=0.2913 train_acc=0.8889
# [minGRU] step= 11200 train_loss=0.2926 train_acc=0.8853
#    -> val_loss=0.3063 val_acc=0.8816
# [minGRU] step= 11300 train_loss=0.2466 train_acc=0.9065
# [minGRU] step= 11400 train_loss=0.2405 train_acc=0.9083
# [minGRU] step= 11500 train_loss=0.2472 train_acc=0.9064
#    -> val_loss=0.3066 val_acc=0.8857
# [minGRU] step= 11600 train_loss=0.2352 train_acc=0.9089
# [minGRU] step= 11700 train_loss=0.2425 train_acc=0.9092
#    -> val_loss=0.2805 val_acc=0.8934
# [minGRU] step= 11800 train_loss=0.2239 train_acc=0.9147
# [minGRU] step= 11900 train_loss=0.2419 train_acc=0.9049
# [minGRU] step= 12000 train_loss=0.2288 train_acc=0.9135
#    -> val_loss=0.2932 val_acc=0.8948
# [minGRU] step= 12100 train_loss=0.2341 train_acc=0.9104
# [minGRU] step= 12200 train_loss=0.2510 train_acc=0.9045
#    -> val_loss=0.2575 val_acc=0.9002
# [minGRU] step= 12300 train_loss=0.2165 train_acc=0.9177
# [minGRU] step= 12400 train_loss=0.2112 train_acc=0.9187
# [minGRU] step= 12500 train_loss=0.2028 train_acc=0.9214
#    -> val_loss=0.2307 val_acc=0.9130
# [minGRU] step= 12600 train_loss=0.1882 train_acc=0.9297
# [minGRU] step= 12700 train_loss=0.1992 train_acc=0.9252
#    -> val_loss=0.2349 val_acc=0.9129
# [minGRU] step= 12800 train_loss=0.1808 train_acc=0.9308
# [minGRU] step= 12900 train_loss=0.1964 train_acc=0.9242
# [minGRU] step= 13000 train_loss=0.1774 train_acc=0.9316
#    -> val_loss=0.2471 val_acc=0.9048
# [minGRU] step= 13100 train_loss=0.1767 train_acc=0.9337
# [minGRU] step= 13200 train_loss=0.2107 train_acc=0.9171
#    -> val_loss=0.2337 val_acc=0.9131
# [minGRU] step= 13300 train_loss=0.1778 train_acc=0.9323
# [minGRU] step= 13400 train_loss=0.2079 train_acc=0.9216
# [minGRU] step= 13500 train_loss=0.1690 train_acc=0.9355
#    -> val_loss=0.2456 val_acc=0.9074
# [minGRU] step= 13600 train_loss=0.1655 train_acc=0.9373
# [minGRU] step= 13700 train_loss=0.1699 train_acc=0.9336
#    -> val_loss=0.2200 val_acc=0.9187
# [minGRU] step= 13800 train_loss=0.1514 train_acc=0.9434
# [minGRU] step= 13900 train_loss=0.1715 train_acc=0.9329
# [minGRU] step= 14000 train_loss=0.1565 train_acc=0.9407
#    -> val_loss=0.2665 val_acc=0.9047
#
# ===== Training minLSTM, seed=42 =====
# [minLSTM] step=   100 train_loss=2.6584 train_acc=0.0718
# [minLSTM] step=   200 train_loss=2.6482 train_acc=0.0712
#    -> val_loss=2.6433 val_acc=0.0699
# [minLSTM] step=   300 train_loss=2.6441 train_acc=0.0725
# [minLSTM] step=   400 train_loss=2.6441 train_acc=0.0723
# [minLSTM] step=   500 train_loss=2.6433 train_acc=0.0689
#    -> val_loss=2.6450 val_acc=0.0723
# [minLSTM] step=   600 train_loss=2.6438 train_acc=0.0723
# [minLSTM] step=   700 train_loss=2.6426 train_acc=0.0713
#    -> val_loss=2.6285 val_acc=0.0841
# [minLSTM] step=   800 train_loss=2.6128 train_acc=0.0983
# [minLSTM] step=   900 train_loss=2.5005 train_acc=0.1516
# [minLSTM] step=  1000 train_loss=2.4343 train_acc=0.1676
#    -> val_loss=2.4268 val_acc=0.1680
# [minLSTM] step=  1100 train_loss=2.4029 train_acc=0.1789
# [minLSTM] step=  1200 train_loss=2.3896 train_acc=0.1830
#    -> val_loss=2.3858 val_acc=0.1779
# [minLSTM] step=  1300 train_loss=2.3777 train_acc=0.1850
# [minLSTM] step=  1400 train_loss=2.3477 train_acc=0.1915
# [minLSTM] step=  1500 train_loss=2.3302 train_acc=0.1933
#    -> val_loss=2.3237 val_acc=0.1949
# [minLSTM] step=  1600 train_loss=2.2956 train_acc=0.2060
# [minLSTM] step=  1700 train_loss=2.2565 train_acc=0.2250
#    -> val_loss=2.2121 val_acc=0.2448
# [minLSTM] step=  1800 train_loss=2.2089 train_acc=0.2487
# [minLSTM] step=  1900 train_loss=2.1773 train_acc=0.2589
# [minLSTM] step=  2000 train_loss=2.1374 train_acc=0.2696
#    -> val_loss=2.1090 val_acc=0.2803
# [minLSTM] step=  2100 train_loss=2.0803 train_acc=0.2851
# [minLSTM] step=  2200 train_loss=2.0467 train_acc=0.2912
#    -> val_loss=2.0129 val_acc=0.3041
# [minLSTM] step=  2300 train_loss=2.0026 train_acc=0.3056
# [minLSTM] step=  2400 train_loss=1.9639 train_acc=0.3143
# [minLSTM] step=  2500 train_loss=1.9273 train_acc=0.3217
#    -> val_loss=1.9277 val_acc=0.3224
# [minLSTM] step=  2600 train_loss=1.8943 train_acc=0.3309
# [minLSTM] step=  2700 train_loss=1.8683 train_acc=0.3332
#    -> val_loss=1.8462 val_acc=0.3397
# [minLSTM] step=  2800 train_loss=1.8326 train_acc=0.3453
# [minLSTM] step=  2900 train_loss=1.7998 train_acc=0.3514
# [minLSTM] step=  3000 train_loss=1.7733 train_acc=0.3576
#    -> val_loss=1.7641 val_acc=0.3607
# [minLSTM] step=  3100 train_loss=1.7456 train_acc=0.3670
# [minLSTM] step=  3200 train_loss=1.7197 train_acc=0.3685
#    -> val_loss=1.6969 val_acc=0.3759
# [minLSTM] step=  3300 train_loss=1.6903 train_acc=0.3778
# [minLSTM] step=  3400 train_loss=1.6572 train_acc=0.3855
# [minLSTM] step=  3500 train_loss=1.6242 train_acc=0.3884
#    -> val_loss=1.6211 val_acc=0.3906
# [minLSTM] step=  3600 train_loss=1.5860 train_acc=0.4016
# [minLSTM] step=  3700 train_loss=1.5568 train_acc=0.4064
#    -> val_loss=1.5344 val_acc=0.4122
# [minLSTM] step=  3800 train_loss=1.5235 train_acc=0.4125
# [minLSTM] step=  3900 train_loss=1.4878 train_acc=0.4242
# [minLSTM] step=  4000 train_loss=1.4642 train_acc=0.4278
#    -> val_loss=1.4544 val_acc=0.4281
# [minLSTM] step=  4100 train_loss=1.4319 train_acc=0.4383
# [minLSTM] step=  4200 train_loss=1.4079 train_acc=0.4417
#    -> val_loss=1.3848 val_acc=0.4460
# [minLSTM] step=  4300 train_loss=1.3830 train_acc=0.4470
# [minLSTM] step=  4400 train_loss=1.3536 train_acc=0.4554
# [minLSTM] step=  4500 train_loss=1.3360 train_acc=0.4617
#    -> val_loss=1.3339 val_acc=0.4613
# [minLSTM] step=  4600 train_loss=1.3036 train_acc=0.4699
# [minLSTM] step=  4700 train_loss=1.2821 train_acc=0.4722
#    -> val_loss=1.2830 val_acc=0.4808
# [minLSTM] step=  4800 train_loss=1.2617 train_acc=0.4793
# [minLSTM] step=  4900 train_loss=1.2349 train_acc=0.4868
# [minLSTM] step=  5000 train_loss=1.2243 train_acc=0.4914
#    -> val_loss=1.2337 val_acc=0.4976
# [minLSTM] step=  5100 train_loss=1.1956 train_acc=0.5018
# [minLSTM] step=  5200 train_loss=1.1781 train_acc=0.5091
#    -> val_loss=1.1826 val_acc=0.5169
# [minLSTM] step=  5300 train_loss=1.1582 train_acc=0.5134
# [minLSTM] step=  5400 train_loss=1.1338 train_acc=0.5233
# [minLSTM] step=  5500 train_loss=1.1264 train_acc=0.5298
#    -> val_loss=1.1418 val_acc=0.5340
# [minLSTM] step=  5600 train_loss=1.0990 train_acc=0.5361
# [minLSTM] step=  5700 train_loss=1.0815 train_acc=0.5461
#    -> val_loss=1.1021 val_acc=0.5445
# [minLSTM] step=  5800 train_loss=1.0645 train_acc=0.5466
# [minLSTM] step=  5900 train_loss=1.0397 train_acc=0.5592
# [minLSTM] step=  6000 train_loss=1.0300 train_acc=0.5625
#    -> val_loss=1.0595 val_acc=0.5583
# [minLSTM] step=  6100 train_loss=1.0068 train_acc=0.5720
# [minLSTM] step=  6200 train_loss=0.9890 train_acc=0.5823
#    -> val_loss=1.0064 val_acc=0.5783
# [minLSTM] step=  6300 train_loss=0.9659 train_acc=0.5867
# [minLSTM] step=  6400 train_loss=0.9410 train_acc=0.5990
# [minLSTM] step=  6500 train_loss=0.9342 train_acc=0.6039
#    -> val_loss=0.9526 val_acc=0.5979
# [minLSTM] step=  6600 train_loss=0.9055 train_acc=0.6124
# [minLSTM] step=  6700 train_loss=0.8904 train_acc=0.6223
#    -> val_loss=0.9107 val_acc=0.6185
# [minLSTM] step=  6800 train_loss=0.8781 train_acc=0.6270
# [minLSTM] step=  6900 train_loss=0.8832 train_acc=0.6241
# [minLSTM] step=  7000 train_loss=0.9351 train_acc=0.6020
#    -> val_loss=0.9348 val_acc=0.6044
# [minLSTM] step=  7100 train_loss=0.9797 train_acc=0.5848
# [minLSTM] step=  7200 train_loss=0.9337 train_acc=0.6020
#    -> val_loss=1.0638 val_acc=0.5478
# [minLSTM] step=  7300 train_loss=0.9192 train_acc=0.6069
# [minLSTM] step=  7400 train_loss=0.9675 train_acc=0.5920
# [minLSTM] step=  7500 train_loss=1.0721 train_acc=0.5467
#    -> val_loss=0.9804 val_acc=0.5893
# [minLSTM] step=  7600 train_loss=0.9434 train_acc=0.6025
# [minLSTM] step=  7700 train_loss=0.9746 train_acc=0.5913
#    -> val_loss=1.0780 val_acc=0.5494
# [minLSTM] step=  7800 train_loss=0.9481 train_acc=0.6036
# [minLSTM] step=  7900 train_loss=0.9278 train_acc=0.6064
# [minLSTM] step=  8000 train_loss=0.9401 train_acc=0.6027
#    -> val_loss=1.1022 val_acc=0.5273
# [minLSTM] step=  8100 train_loss=0.9702 train_acc=0.5950
# [minLSTM] step=  8200 train_loss=0.9766 train_acc=0.5895
#    -> val_loss=1.1320 val_acc=0.5393
# [minLSTM] step=  8300 train_loss=1.0312 train_acc=0.5686
# [minLSTM] step=  8400 train_loss=1.0450 train_acc=0.5684
# [minLSTM] step=  8500 train_loss=1.0123 train_acc=0.5783
#    -> val_loss=1.1451 val_acc=0.5201
# [minLSTM] step=  8600 train_loss=0.9928 train_acc=0.5871
# [minLSTM] step=  8700 train_loss=1.6784 train_acc=0.4207
#    -> val_loss=1.1120 val_acc=0.5321
# [minLSTM] step=  8800 train_loss=1.1681 train_acc=0.5262
# [minLSTM] step=  8900 train_loss=1.0148 train_acc=0.5770
# [minLSTM] step=  9000 train_loss=1.0333 train_acc=0.5688
#    -> val_loss=1.0511 val_acc=0.5702
# [minLSTM] step=  9100 train_loss=0.9782 train_acc=0.5889
# [minLSTM] step=  9200 train_loss=1.0755 train_acc=0.5745
#    -> val_loss=1.0495 val_acc=0.5587
# [minLSTM] step=  9300 train_loss=1.1441 train_acc=0.5376
# [minLSTM] step=  9400 train_loss=0.9648 train_acc=0.5968
# [minLSTM] step=  9500 train_loss=0.9813 train_acc=0.5900
#    -> val_loss=0.9729 val_acc=0.5957
# [minLSTM] step=  9600 train_loss=0.9798 train_acc=0.5925
# [minLSTM] step=  9700 train_loss=0.9763 train_acc=0.5919
#    -> val_loss=0.9609 val_acc=0.5952
# [minLSTM] step=  9800 train_loss=0.9454 train_acc=0.6071
# [minLSTM] step=  9900 train_loss=0.9424 train_acc=0.6013
# [minLSTM] step= 10000 train_loss=0.9236 train_acc=0.6126
#    -> val_loss=0.9250 val_acc=0.6098
# [minLSTM] step= 10100 train_loss=0.9198 train_acc=0.6124
# [minLSTM] step= 10200 train_loss=0.9154 train_acc=0.6141
#    -> val_loss=0.8908 val_acc=0.6252
# [minLSTM] step= 10300 train_loss=0.8700 train_acc=0.6360
# [minLSTM] step= 10400 train_loss=0.8683 train_acc=0.6341
# [minLSTM] step= 10500 train_loss=0.8598 train_acc=0.6364
#    -> val_loss=0.8392 val_acc=0.6449
# [minLSTM] step= 10600 train_loss=0.8803 train_acc=0.6357
# [minLSTM] step= 10700 train_loss=0.8241 train_acc=0.6508
#    -> val_loss=0.8304 val_acc=0.6464
# [minLSTM] step= 10800 train_loss=0.8173 train_acc=0.6571
# [minLSTM] step= 10900 train_loss=0.8051 train_acc=0.6631
# [minLSTM] step= 11000 train_loss=0.7945 train_acc=0.6645
#    -> val_loss=0.8222 val_acc=0.6427
# [minLSTM] step= 11100 train_loss=0.8812 train_acc=0.6385
# [minLSTM] step= 11200 train_loss=0.9195 train_acc=0.6310
#    -> val_loss=0.7563 val_acc=0.6809
# [minLSTM] step= 11300 train_loss=0.7753 train_acc=0.6758
# [minLSTM] step= 11400 train_loss=0.9375 train_acc=0.6216
# [minLSTM] step= 11500 train_loss=0.7780 train_acc=0.6731
#    -> val_loss=0.9653 val_acc=0.5990
# [minLSTM] step= 11600 train_loss=0.7798 train_acc=0.6754
# [minLSTM] step= 11700 train_loss=0.7396 train_acc=0.6905
#    -> val_loss=0.7617 val_acc=0.6787
# [minLSTM] step= 11800 train_loss=0.7439 train_acc=0.6906
# [minLSTM] step= 11900 train_loss=0.8145 train_acc=0.6619
# [minLSTM] step= 12000 train_loss=0.9591 train_acc=0.6151
#    -> val_loss=0.8183 val_acc=0.6601
# [minLSTM] step= 12100 train_loss=0.7639 train_acc=0.6826
# [minLSTM] step= 12200 train_loss=0.7809 train_acc=0.6773
#    -> val_loss=0.7429 val_acc=0.6974
# [minLSTM] step= 12300 train_loss=0.7401 train_acc=0.6899
# [minLSTM] step= 12400 train_loss=0.8748 train_acc=0.6449
# [minLSTM] step= 12500 train_loss=0.7359 train_acc=0.6952
#    -> val_loss=0.7308 val_acc=0.6999
# [minLSTM] step= 12600 train_loss=0.7787 train_acc=0.6800
# [minLSTM] step= 12700 train_loss=0.7310 train_acc=0.6971
#    -> val_loss=0.7033 val_acc=0.7093
# [minLSTM] step= 12800 train_loss=0.6947 train_acc=0.7083
# [minLSTM] step= 12900 train_loss=0.6944 train_acc=0.7140
# [minLSTM] step= 13000 train_loss=0.6666 train_acc=0.7234
#    -> val_loss=0.6693 val_acc=0.7271
# [minLSTM] step= 13100 train_loss=0.7041 train_acc=0.7154
# [minLSTM] step= 13200 train_loss=0.6825 train_acc=0.7185
#    -> val_loss=0.6610 val_acc=0.7362
# [minLSTM] step= 13300 train_loss=0.6415 train_acc=0.7360
# [minLSTM] step= 13400 train_loss=0.6214 train_acc=0.7471
# [minLSTM] step= 13500 train_loss=0.5955 train_acc=0.7571
#    -> val_loss=0.6171 val_acc=0.7563
# [minLSTM] step= 13600 train_loss=0.6008 train_acc=0.7548
# [minLSTM] step= 13700 train_loss=0.6178 train_acc=0.7499
#    -> val_loss=0.6072 val_acc=0.7600
# [minLSTM] step= 13800 train_loss=0.5964 train_acc=0.7596
# [minLSTM] step= 13900 train_loss=0.5986 train_acc=0.7585
# [minLSTM] step= 14000 train_loss=0.5649 train_acc=0.7735
#    -> val_loss=0.6399 val_acc=0.7409
#
# ===== Training minLSTM, seed=43 =====
# [minLSTM] step=   100 train_loss=2.6625 train_acc=0.0722
# [minLSTM] step=   200 train_loss=2.6468 train_acc=0.0692
#    -> val_loss=2.6454 val_acc=0.0725
# [minLSTM] step=   300 train_loss=2.6450 train_acc=0.0709
# [minLSTM] step=   400 train_loss=2.6439 train_acc=0.0719
# [minLSTM] step=   500 train_loss=2.6286 train_acc=0.0852
#    -> val_loss=2.6084 val_acc=0.1037
# [minLSTM] step=   600 train_loss=2.5672 train_acc=0.1276
# [minLSTM] step=   700 train_loss=2.4731 train_acc=0.1673
#    -> val_loss=2.4198 val_acc=0.1819
# [minLSTM] step=   800 train_loss=2.4140 train_acc=0.1798
# [minLSTM] step=   900 train_loss=2.3751 train_acc=0.1896
# [minLSTM] step=  1000 train_loss=2.3442 train_acc=0.1966
#    -> val_loss=2.3373 val_acc=0.2001
# [minLSTM] step=  1100 train_loss=2.3192 train_acc=0.2031
# [minLSTM] step=  1200 train_loss=2.2922 train_acc=0.2082
#    -> val_loss=2.2781 val_acc=0.2149
# [minLSTM] step=  1300 train_loss=2.2657 train_acc=0.2141
# [minLSTM] step=  1400 train_loss=2.1905 train_acc=0.2421
# [minLSTM] step=  1500 train_loss=2.1113 train_acc=0.2691
#    -> val_loss=2.0884 val_acc=0.2773
# [minLSTM] step=  1600 train_loss=2.0576 train_acc=0.2833
# [minLSTM] step=  1700 train_loss=2.0189 train_acc=0.2948
#    -> val_loss=1.9926 val_acc=0.2994
# [minLSTM] step=  1800 train_loss=1.9930 train_acc=0.2993
# [minLSTM] step=  1900 train_loss=1.9596 train_acc=0.3081
# [minLSTM] step=  2000 train_loss=1.9388 train_acc=0.3122
#    -> val_loss=1.9449 val_acc=0.3071
# [minLSTM] step=  2100 train_loss=1.9253 train_acc=0.3154
# [minLSTM] step=  2200 train_loss=1.8990 train_acc=0.3181
#    -> val_loss=1.8976 val_acc=0.3170
# [minLSTM] step=  2300 train_loss=1.8830 train_acc=0.3245
# [minLSTM] step=  2400 train_loss=1.8579 train_acc=0.3275
# [minLSTM] step=  2500 train_loss=1.8342 train_acc=0.3330
#    -> val_loss=1.8571 val_acc=0.3278
# [minLSTM] step=  2600 train_loss=1.8098 train_acc=0.3419
# [minLSTM] step=  2700 train_loss=1.7911 train_acc=0.3406
#    -> val_loss=1.8028 val_acc=0.3399
# [minLSTM] step=  2800 train_loss=1.7676 train_acc=0.3501
# [minLSTM] step=  2900 train_loss=1.7426 train_acc=0.3532
# [minLSTM] step=  3000 train_loss=1.7286 train_acc=0.3585
#    -> val_loss=1.7509 val_acc=0.3525
# [minLSTM] step=  3100 train_loss=1.7011 train_acc=0.3621
# [minLSTM] step=  3200 train_loss=1.6905 train_acc=0.3639
#    -> val_loss=1.7088 val_acc=0.3661
# [minLSTM] step=  3300 train_loss=1.6710 train_acc=0.3719
# [minLSTM] step=  3400 train_loss=1.6513 train_acc=0.3717
# [minLSTM] step=  3500 train_loss=1.6381 train_acc=0.3800
#    -> val_loss=1.6529 val_acc=0.3745
# [minLSTM] step=  3600 train_loss=1.6167 train_acc=0.3836
# [minLSTM] step=  3700 train_loss=1.5963 train_acc=0.3877
#    -> val_loss=1.5870 val_acc=0.3908
# [minLSTM] step=  3800 train_loss=1.5800 train_acc=0.3923
# [minLSTM] step=  3900 train_loss=1.5541 train_acc=0.3976
# [minLSTM] step=  4000 train_loss=1.5375 train_acc=0.4023
#    -> val_loss=1.5361 val_acc=0.3984
# [minLSTM] step=  4100 train_loss=1.5183 train_acc=0.4036
# [minLSTM] step=  4200 train_loss=1.4909 train_acc=0.4089
#    -> val_loss=1.5001 val_acc=0.4020
# [minLSTM] step=  4300 train_loss=1.4778 train_acc=0.4146
# [minLSTM] step=  4400 train_loss=1.4452 train_acc=0.4216
# [minLSTM] step=  4500 train_loss=1.4356 train_acc=0.4237
#    -> val_loss=1.4468 val_acc=0.4188
# [minLSTM] step=  4600 train_loss=1.4149 train_acc=0.4254
# [minLSTM] step=  4700 train_loss=1.3976 train_acc=0.4282
#    -> val_loss=1.4373 val_acc=0.4249
# [minLSTM] step=  4800 train_loss=1.3846 train_acc=0.4366
# [minLSTM] step=  4900 train_loss=1.3625 train_acc=0.4396
# [minLSTM] step=  5000 train_loss=1.3643 train_acc=0.4377
#    -> val_loss=1.3611 val_acc=0.4412
# [minLSTM] step=  5100 train_loss=1.3407 train_acc=0.4448
# [minLSTM] step=  5200 train_loss=1.3262 train_acc=0.4453
#    -> val_loss=1.3354 val_acc=0.4477
# [minLSTM] step=  5300 train_loss=1.3139 train_acc=0.4550
# [minLSTM] step=  5400 train_loss=1.2983 train_acc=0.4587
# [minLSTM] step=  5500 train_loss=1.2965 train_acc=0.4559
#    -> val_loss=1.3187 val_acc=0.4530
# [minLSTM] step=  5600 train_loss=1.2764 train_acc=0.4659
# [minLSTM] step=  5700 train_loss=1.2626 train_acc=0.4682
#    -> val_loss=1.2778 val_acc=0.4654
# [minLSTM] step=  5800 train_loss=1.2533 train_acc=0.4742
# [minLSTM] step=  5900 train_loss=1.2378 train_acc=0.4806
# [minLSTM] step=  6000 train_loss=1.2287 train_acc=0.4802
#    -> val_loss=1.2448 val_acc=0.4766
# [minLSTM] step=  6100 train_loss=1.2111 train_acc=0.4861
# [minLSTM] step=  6200 train_loss=1.1939 train_acc=0.4929
#    -> val_loss=1.2191 val_acc=0.4806
# [minLSTM] step=  6300 train_loss=1.1859 train_acc=0.4961
# [minLSTM] step=  6400 train_loss=1.1674 train_acc=0.4998
# [minLSTM] step=  6500 train_loss=1.1604 train_acc=0.5031
#    -> val_loss=1.1762 val_acc=0.4952
# [minLSTM] step=  6600 train_loss=1.1422 train_acc=0.5095
# [minLSTM] step=  6700 train_loss=1.1274 train_acc=0.5146
#    -> val_loss=1.1532 val_acc=0.5009
# [minLSTM] step=  6800 train_loss=1.1152 train_acc=0.5196
# [minLSTM] step=  6900 train_loss=1.1018 train_acc=0.5212
# [minLSTM] step=  7000 train_loss=1.0989 train_acc=0.5239
#    -> val_loss=1.1171 val_acc=0.5124
# [minLSTM] step=  7100 train_loss=1.0728 train_acc=0.5329
# [minLSTM] step=  7200 train_loss=1.0701 train_acc=0.5329
#    -> val_loss=1.0798 val_acc=0.5284
# [minLSTM] step=  7300 train_loss=1.0480 train_acc=0.5408
# [minLSTM] step=  7400 train_loss=1.0401 train_acc=0.5472
# [minLSTM] step=  7500 train_loss=1.0326 train_acc=0.5476
#    -> val_loss=1.0502 val_acc=0.5436
# [minLSTM] step=  7600 train_loss=1.0118 train_acc=0.5603
# [minLSTM] step=  7700 train_loss=1.0060 train_acc=0.5622
#    -> val_loss=1.0195 val_acc=0.5514
# [minLSTM] step=  7800 train_loss=0.9839 train_acc=0.5699
# [minLSTM] step=  7900 train_loss=0.9763 train_acc=0.5748
# [minLSTM] step=  8000 train_loss=0.9682 train_acc=0.5771
#    -> val_loss=0.9902 val_acc=0.5634
# [minLSTM] step=  8100 train_loss=0.9496 train_acc=0.5853
# [minLSTM] step=  8200 train_loss=0.9410 train_acc=0.5906
#    -> val_loss=0.9649 val_acc=0.5757
# [minLSTM] step=  8300 train_loss=0.9251 train_acc=0.5967
# [minLSTM] step=  8400 train_loss=0.9087 train_acc=0.6017
# [minLSTM] step=  8500 train_loss=0.9114 train_acc=0.6000
#    -> val_loss=0.9609 val_acc=0.5873
# [minLSTM] step=  8600 train_loss=0.8898 train_acc=0.6133
# [minLSTM] step=  8700 train_loss=0.8863 train_acc=0.6138
#    -> val_loss=0.9502 val_acc=0.5995
# [minLSTM] step=  8800 train_loss=0.8650 train_acc=0.6267
# [minLSTM] step=  8900 train_loss=0.8475 train_acc=0.6343
# [minLSTM] step=  9000 train_loss=0.8483 train_acc=0.6315
#    -> val_loss=0.9126 val_acc=0.6147
# [minLSTM] step=  9100 train_loss=0.8231 train_acc=0.6458
# [minLSTM] step=  9200 train_loss=0.8161 train_acc=0.6487
#    -> val_loss=0.8814 val_acc=0.6299
# [minLSTM] step=  9300 train_loss=0.8006 train_acc=0.6533
# [minLSTM] step=  9400 train_loss=0.7818 train_acc=0.6641
# [minLSTM] step=  9500 train_loss=0.7786 train_acc=0.6663
#    -> val_loss=0.8460 val_acc=0.6438
# [minLSTM] step=  9600 train_loss=0.7549 train_acc=0.6773
# [minLSTM] step=  9700 train_loss=0.7505 train_acc=0.6805
#    -> val_loss=0.8195 val_acc=0.6570
# [minLSTM] step=  9800 train_loss=0.7396 train_acc=0.6836
# [minLSTM] step=  9900 train_loss=0.7140 train_acc=0.6986
# [minLSTM] step= 10000 train_loss=0.7152 train_acc=0.6988
#    -> val_loss=0.7918 val_acc=0.6698
# [minLSTM] step= 10100 train_loss=0.6911 train_acc=0.7086
# [minLSTM] step= 10200 train_loss=0.6924 train_acc=0.7080
#    -> val_loss=0.7530 val_acc=0.6895
# [minLSTM] step= 10300 train_loss=0.6762 train_acc=0.7171
# [minLSTM] step= 10400 train_loss=0.6568 train_acc=0.7258
# [minLSTM] step= 10500 train_loss=0.6508 train_acc=0.7317
#    -> val_loss=0.7136 val_acc=0.7066
# [minLSTM] step= 10600 train_loss=0.6290 train_acc=0.7413
# [minLSTM] step= 10700 train_loss=0.6225 train_acc=0.7439
#    -> val_loss=0.6921 val_acc=0.7095
# [minLSTM] step= 10800 train_loss=0.6077 train_acc=0.7508
# [minLSTM] step= 10900 train_loss=0.5810 train_acc=0.7618
# [minLSTM] step= 11000 train_loss=0.5768 train_acc=0.7645
#    -> val_loss=0.6521 val_acc=0.7290
# [minLSTM] step= 11100 train_loss=0.5520 train_acc=0.7764
# [minLSTM] step= 11200 train_loss=0.5461 train_acc=0.7801
# ...
# [LSTM] step=  5000 train_loss=2.6405 train_acc=0.0709
#    -> val_loss=2.6415 val_acc=0.0743
# [LSTM] step=  5100 train_loss=2.6407 train_acc=0.0716
# [LSTM] step=  5200 train_loss=2.6407 train_acc=0.0734
#    -> val_loss=2.6415 val_acc=0.0743
# [LSTM] step=  5300 train_loss=2.6405 train_acc=0.0718
# [LSTM] step=  5400 train_loss=2.6405 train_acc=0.0747
# [LSTM] step=  5500 train_loss=2.6404 train_acc=0.0714
#    -> val_loss=2.6414 val_acc=0.0743
# [LSTM] step=  5600 train_loss=2.6406 train_acc=0.0721
# [LSTM] step=  5700 train_loss=2.6406 train_acc=0.0736
#    -> val_loss=2.6413 val_acc=0.0743
# [LSTM] step=  5800 train_loss=2.6404 train_acc=0.0733
# [LSTM] step=  5900 train_loss=2.6398 train_acc=0.0756
# [LSTM] step=  6000 train_loss=2.6350 train_acc=0.0791
#    -> val_loss=2.6277 val_acc=0.0905
# [LSTM] step=  6100 train_loss=2.5953 train_acc=0.0928
# [LSTM] step=  6200 train_loss=2.5673 train_acc=0.1011
#    -> val_loss=2.5076 val_acc=0.1142
# [LSTM] step=  6300 train_loss=2.5268 train_acc=0.1043
# [LSTM] step=  6400 train_loss=2.5137 train_acc=0.1023
# [LSTM] step=  6500 train_loss=2.4476 train_acc=0.1104
#    -> val_loss=2.4713 val_acc=0.1097
# [LSTM] step=  6600 train_loss=2.4591 train_acc=0.1086
# [LSTM] step=  6700 train_loss=2.4432 train_acc=0.1092
#    -> val_loss=2.4146 val_acc=0.1174
# [LSTM] step= 10400 train_loss=2.2712 train_acc=0.1779
# [LSTM] step= 10500 train_loss=2.2459 train_acc=0.1815
#    -> val_loss=2.2571 val_acc=0.1747
# [LSTM] step= 10600 train_loss=2.2648 train_acc=0.1794
# [LSTM] step= 10700 train_loss=2.2874 train_acc=0.1746
#    -> val_loss=2.2478 val_acc=0.1773
# [LSTM] step= 10800 train_loss=2.2526 train_acc=0.1783
# [LSTM] step= 10900 train_loss=2.2607 train_acc=0.1777
# [LSTM] step= 11000 train_loss=2.2137 train_acc=0.1842
#    -> val_loss=2.2304 val_acc=0.1799
# [LSTM] step= 11100 train_loss=2.2293 train_acc=0.1846
# [LSTM] step= 11200 train_loss=2.2289 train_acc=0.1844
#    -> val_loss=2.2306 val_acc=0.1808
# [LSTM] step= 11300 train_loss=2.2098 train_acc=0.1895
# [LSTM] step= 11400 train_loss=2.2203 train_acc=0.1888
# [LSTM] step= 11500 train_loss=2.2038 train_acc=0.1919
#    -> val_loss=2.2046 val_acc=0.1902
# [LSTM] step= 11600 train_loss=2.2161 train_acc=0.1918
# [LSTM] step= 11700 train_loss=2.2039 train_acc=0.1928
#    -> val_loss=2.1945 val_acc=0.1967
# [LSTM] step= 11800 train_loss=2.2092 train_acc=0.1972
# [LSTM] step= 11900 train_loss=2.1925 train_acc=0.2019
# [LSTM] step= 12000 train_loss=2.1869 train_acc=0.2050
#    -> val_loss=2.2038 val_acc=0.1930
# [LSTM] step= 12100 train_loss=2.1717 train_acc=0.2054
# [LSTM] step= 12200 train_loss=2.1858 train_acc=0.2051
#    -> val_loss=2.1848 val_acc=0.1981
# [LSTM] step= 12300 train_loss=2.1746 train_acc=0.2080
# [LSTM] step= 12400 train_loss=2.1768 train_acc=0.2095
# [LSTM] step= 12500 train_loss=2.1598 train_acc=0.2159
#    -> val_loss=2.1803 val_acc=0.2034
# [LSTM] step= 12600 train_loss=2.1613 train_acc=0.2145
# [LSTM] step= 12700 train_loss=2.1707 train_acc=0.2130
#    -> val_loss=2.1802 val_acc=0.2057
# [LSTM] step= 12800 train_loss=2.1572 train_acc=0.2157
# [LSTM] step= 12900 train_loss=2.1686 train_acc=0.2124
# [LSTM] step= 13000 train_loss=2.1663 train_acc=0.2135
#    -> val_loss=2.1721 val_acc=0.2027
# [LSTM] step= 13100 train_loss=2.1640 train_acc=0.2143
# [LSTM] step= 13200 train_loss=2.1559 train_acc=0.2154
#    -> val_loss=2.1579 val_acc=0.2075
# [LSTM] step= 13300 train_loss=2.1533 train_acc=0.2180
# [LSTM] step= 13400 train_loss=2.1616 train_acc=0.2153
# [LSTM] step= 13500 train_loss=2.1542 train_acc=0.2176
#    -> val_loss=2.1520 val_acc=0.2162
# [LSTM] step= 13600 train_loss=2.1807 train_acc=0.2119
# [LSTM] step= 13700 train_loss=2.1991 train_acc=0.2077
#    -> val_loss=2.1893 val_acc=0.1979
# [LSTM] step= 13800 train_loss=2.1697 train_acc=0.2138
# [LSTM] step= 13900 train_loss=2.1605 train_acc=0.2161
# [LSTM] step= 10600 train_loss=2.3280 train_acc=0.1627
# [LSTM] step= 10700 train_loss=2.3528 train_acc=0.1558
#    -> val_loss=2.3143 val_acc=0.1629
# [LSTM] step= 10800 train_loss=2.3285 train_acc=0.1620
# [LSTM] step= 10900 train_loss=2.3376 train_acc=0.1638
# [LSTM] step= 11000 train_loss=2.3477 train_acc=0.1574
#    -> val_loss=2.3119 val_acc=0.1638
# [LSTM] step= 11100 train_loss=2.3365 train_acc=0.1611
# [LSTM] step= 11200 train_loss=2.3274 train_acc=0.1644
#    -> val_loss=2.3420 val_acc=0.1554
# [LSTM] step= 11300 train_loss=2.3360 train_acc=0.1638
# [LSTM] step= 11400 train_loss=2.3246 train_acc=0.1644
# [LSTM] step= 11500 train_loss=2.3165 train_acc=0.1654
#    -> val_loss=2.3154 val_acc=0.1608
# [LSTM] step= 11600 train_loss=2.3183 train_acc=0.1642
# [LSTM] step= 11700 train_loss=2.3297 train_acc=0.1651
#    -> val_loss=2.3012 val_acc=0.1650
# [LSTM] step= 11800 train_loss=2.3108 train_acc=0.1663
# [LSTM] step= 11900 train_loss=2.3177 train_acc=0.1639
# [LSTM] step= 12000 train_loss=2.3059 train_acc=0.1660
#    -> val_loss=2.3036 val_acc=0.1637
# [LSTM] step= 12100 train_loss=2.3058 train_acc=0.1684
# [LSTM] step= 12200 train_loss=2.3311 train_acc=0.1625
#    -> val_loss=2.2981 val_acc=0.1670
# [LSTM] step= 12300 train_loss=2.3203 train_acc=0.1665
# [LSTM] step= 12400 train_loss=2.3124 train_acc=0.1677
# [LSTM] step= 12500 train_loss=2.3309 train_acc=0.1673
#    -> val_loss=2.3368 val_acc=0.1548
# [LSTM] step= 12600 train_loss=2.3054 train_acc=0.1729
# [LSTM] step= 12700 train_loss=2.3285 train_acc=0.1711
#    -> val_loss=2.2790 val_acc=0.1784
# [LSTM] step= 12800 train_loss=2.2810 train_acc=0.1792
# [LSTM] step= 12900 train_loss=2.2847 train_acc=0.1757
# [LSTM] step= 13000 train_loss=2.2676 train_acc=0.1812
#    -> val_loss=2.2637 val_acc=0.1812
# [LSTM] step= 13100 train_loss=2.2541 train_acc=0.1822
# [LSTM] step= 13200 train_loss=2.2443 train_acc=0.1867
#    -> val_loss=2.2346 val_acc=0.1897
# [LSTM] step= 13300 train_loss=2.2376 train_acc=0.1830
# [LSTM] step= 13400 train_loss=2.2407 train_acc=0.1854
# [LSTM] step= 13500 train_loss=2.2205 train_acc=0.1889
#    -> val_loss=2.2229 val_acc=0.1861
# [LSTM] step= 13600 train_loss=2.2218 train_acc=0.1861
# [LSTM] step= 13700 train_loss=2.2143 train_acc=0.1890
#    -> val_loss=2.1951 val_acc=0.1938
# [LSTM] step= 13800 train_loss=2.2160 train_acc=0.1881
# [LSTM] step= 13900 train_loss=2.2046 train_acc=0.1942
# [LSTM] step= 14000 train_loss=2.2045 train_acc=0.1925
#    -> val_loss=2.1991 val_acc=0.1975

# %% [markdown]
# # Aggregate results

# %%
rows = []
for r in all_results:
    rows.append({
        "model": r["model_name"],
        "seed": r["seed"],
        "params": r["params"],
        "best_val_acc": r["best_val_acc"],
        "test_acc": r["test_acc"],
        "test_loss": r["test_loss"],
        "train_time_sec": r["train_time_sec"],
    })

results_df = pd.DataFrame(rows)
results_df.sort_values(["model", "seed"])
# Out:
#       model  seed   params  best_val_acc  test_acc  test_loss  train_time_sec
# 6       GRU    42   793728      0.993437  0.992969   0.023107     1063.256791
# 7       GRU    43   793728      0.996250  0.996133   0.012991     1058.194899
# 8       GRU    44   793728      0.999922  0.999570   0.002212     1056.125666
# 9      LSTM    42  1041024      0.280469  0.277187   1.931652     1080.863763
# 10     LSTM    43  1041024      0.216172  0.215000   2.149783     1079.447839
# 11     LSTM    44  1041024      0.197500  0.194102   2.197167     1082.306868
# 0    minGRU    42   152448      0.975391  0.975273   0.072039      652.721120
# 1    minGRU    43   152448      0.779531  0.777852   0.554934      652.598932
# 2    minGRU    44   152448      0.918672  0.914648   0.228499      652.792835
# 3   minLSTM    42   202368      0.760000  0.760859   0.599838      679.132807
# 4   minLSTM    43   202368      0.738906  0.741875   0.641291      679.241629
# 5   minLSTM    44   202368      0.841641  0.832734   0.438300      679.057058

# %% [markdown]
# # Summary Table

# %%
summary_df = (
    results_df.groupby("model")
    .agg(
        params=("params", "mean"),
        test_acc_mean=("test_acc", "mean"),
        test_acc_std=("test_acc", "std"),
        test_loss_mean=("test_loss", "mean"),
        test_loss_std=("test_loss", "std"),
        train_time_mean_sec=("train_time_sec", "mean"),
    )
    .reset_index()
)

summary_df["test_acc_mean_std"] = summary_df.apply(
    lambda r: f"{100*r['test_acc_mean']:.2f} ± {100*(0 if pd.isna(r['test_acc_std']) else r['test_acc_std']):.2f}",
    axis=1
)

summary_df["test_loss_mean_std"] = summary_df.apply(
    lambda r: f"{r['test_loss_mean']:.4f} ± {(0 if pd.isna(r['test_loss_std']) else r['test_loss_std']):.4f}",
    axis=1
)

summary_df[["model", "params", "test_acc_mean_std", "test_loss_mean_std", "train_time_mean_sec"]]
# Out:
#      model     params test_acc_mean_std test_loss_mean_std  \
# 0      GRU   793728.0      99.62 ± 0.33    0.0128 ± 0.0104
# 1     LSTM  1041024.0      22.88 ± 4.32    2.0929 ± 0.1416
# 2   minGRU   152448.0     88.93 ± 10.11    0.2852 ± 0.2464
# 3  minLSTM   202368.0      77.85 ± 4.79    0.5598 ± 0.1073
#
#    train_time_mean_sec
# 0          1059.192452
# 1          1080.872824
# 2           652.704295
# 3           679.143831

# %% [markdown]
# # Plot accuracy comparison

# %%
plot_df = summary_df.copy()

plt.figure(figsize=(8, 5))
plt.bar(plot_df["model"], 100 * plot_df["test_acc_mean"])
plt.ylabel("test accuracy (%)")
plt.title("Selective Copy replication: final accuracy")
plt.show()

plt.figure(figsize=(8, 5))
plt.bar(plot_df["model"], plot_df["train_time_mean_sec"])
plt.ylabel("mean train time (sec)")
plt.title("Selective Copy replication: mean training time")
plt.show()

# %% [markdown]
# # Extension: Generalization to longer sequences

# %%
# pick the best seed per model
best_model_objects = {}
for model_name in MODELS:
    subset = [r for r in all_results if r["model_name"] == model_name]
    best_r = max(subset, key=lambda x: x["test_acc"])
    best_model_objects[model_name] = best_r["model"]

lengths = [CFG.sequence_length, CFG.sequence_length * 2, CFG.sequence_length * 4]
generalization_rows = []

for model_name, model in best_model_objects.items():
    for L in lengths:
        metrics = evaluate_model(model, CFG, seed=1, num_batches=50, sequence_length=L)
        generalization_rows.append({
            "model": model_name,
            "sequence_length": L,
            "test_acc": metrics["acc"],
            "test_loss": metrics["loss"],
        })

generalization_df = pd.DataFrame(generalization_rows)
generalization_df
# Out:
#       model  sequence_length  test_acc  test_loss
# 0    minGRU             1024  0.975234   0.071143
# 1    minGRU             2048  0.974219   0.074902
# 2    minGRU             4096  0.965859   0.103668
# 3   minLSTM             1024  0.832422   0.442773
# 4   minLSTM             2048  0.398125   2.696678
# 5   minLSTM             4096  0.116641   4.730482
# 6       GRU             1024  0.999844   0.000395
# 7       GRU             2048  0.985391   0.154276
# 8       GRU             4096  0.763828   2.612722
# 9      LSTM             1024  0.278359   1.926262
# 10     LSTM             2048  0.278750   1.934235
# 11     LSTM             4096  0.251250   2.088857

# %% [markdown]
# # Plot length generalization

# %%
plt.figure(figsize=(8, 5))
for model_name in generalization_df["model"].unique():
    sub = generalization_df[generalization_df["model"] == model_name]
    plt.plot(sub["sequence_length"], 100 * sub["test_acc"], marker="o", label=model_name)

plt.xlabel("evaluation sequence length")
plt.ylabel("test accuracy (%)")
plt.title("Generalization to longer Selective Copy sequences")
plt.legend()
plt.xscale("log", base=2)
plt.show()

# %% [markdown]
# # Compare with original work's reported numbers

# %%
""" paper_df = pd.DataFrame([
    {"model": "minGRU", "paper_selective_copy_acc_mean": 99.5, "paper_selective_copy_acc_std": 0.2},
    {"model": "minLSTM", "paper_selective_copy_acc_mean": 96.0, "paper_selective_copy_acc_std": 2.8},
])

compare_df = summary_df.merge(paper_df, on="model", how="left")
compare_df["ours_acc_mean_pct"] = 100 * compare_df["test_acc_mean"]
compare_df["support_gap_pct_points"] = compare_df["ours_acc_mean_pct"] - compare_df["paper_selective_copy_acc_mean"]

compare_df[[
    "model",
    "params",
    "ours_acc_mean_pct",
    "paper_selective_copy_acc_mean",
    "paper_selective_copy_acc_std",
    "support_gap_pct_points",
]] """
# Out:
# ' paper_df = pd.DataFrame([\n    {"model": "minGRU", "paper_selective_copy_acc_mean": 99.5, "paper_selective_copy_acc_std": 0.2},\n    {"model": "minLSTM", "paper_selective_copy_acc_mean": 96.0, "paper_selective_copy_acc_std": 2.8},\n])\n\ncompare_df = summary_df.merge(paper_df, on="model", how="left")\ncompare_df["ours_acc_mean_pct"] = 100 * compare_df["test_acc_mean"]\ncompare_df["support_gap_pct_points"] = compare_df["ours_acc_mean_pct"] - compare_df["paper_selective_copy_acc_mean"]\n\ncompare_df[[\n    "model",\n    "params",\n    "ours_acc_mean_pct",\n    "paper_selective_copy_acc_mean",\n    "paper_selective_copy_acc_std",\n    "support_gap_pct_points",\n]] '
