# %% [markdown]
# # Imports

# %%
import math
import time
import random
from dataclasses import dataclass
from collections import defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# # Setup & Device

# %%
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    if torch.backends.mps.is_available():
        return torch.device("mps")
    return torch.device("cpu")

DEVICE = get_device()
print("Using device:", DEVICE)
# Out:
# Using device: cuda

# %% [markdown]
# # Configuration

# %%
@dataclass
class Config:
    # task
    sequence_length: int = 4096
    num_tokens_memorize: int = 16
    vocab_size: int = 16  # matches repo

    # model
    d_model: int = 64
    expand_dim: int = 6
    num_layers: int = 3
    dropout: float = 0.1
    ff_mult: int = 2
    enable_ff: bool = False
    kernel_size: int = 0
    norm_type: str = "RMSNorm"
    use_coeff_norm: bool = False
    use_init_hidden_state: bool = True
    forget_bias_init_scale: float = 3.0

    # optimization
    lr: float = 3e-4
    weight_decay: float = 0.05
    clip: float = 1.0

    # training
    train_batch_size: int = 64
    eval_batch_size: int = 64
    accum_iter: int = 2
    num_steps: int = 400000
    print_freq: int = 100
    eval_freq: int = 1000

    # notebook practicality
    scan_cpu_fallback_on_mps: bool = True

CFG = Config()

FAST_DEV_RUN = False

if FAST_DEV_RUN:
    CFG.sequence_length = 128
    CFG.num_tokens_memorize = 8
    CFG.train_batch_size = 64
    CFG.eval_batch_size = 64
    CFG.num_steps = 5000
    CFG.num_layers = 2
    CFG.d_model = 64
    CFG.expand_dim = 4
    CFG.lr = 1e-3
else: # change accordingly for a longer run
    CFG.sequence_length = 512
    CFG.num_tokens_memorize = 8
    CFG.train_batch_size = 64
    CFG.eval_batch_size = 64
    CFG.accum_iter = 1
    CFG.num_steps = 8000      
    CFG.eval_freq = 250
    CFG.print_freq = 100
    CFG.lr = 8e-4
    CFG.num_layers = 3
    CFG.d_model = 64
    CFG.expand_dim = 4
    CFG.num_tokens_memorize = 8

print(CFG)
# Out:
# Config(sequence_length=512, num_tokens_memorize=8, vocab_size=16, d_model=64, expand_dim=4, num_layers=3, dropout=0.1, ff_mult=2, enable_ff=False, kernel_size=0, norm_type='RMSNorm', use_coeff_norm=False, use_init_hidden_state=True, forget_bias_init_scale=3.0, lr=0.0008, weight_decay=0.05, clip=1.0, train_batch_size=64, eval_batch_size=64, accum_iter=1, num_steps=8000, print_freq=100, eval_freq=250, scan_cpu_fallback_on_mps=True)

# %% [markdown]
# # Helpers from the minRNN repo

# %%
def exists(x):
    return x is not None

def g(x):
    # from official repo
    return torch.where(x >= 0, x + 0.5, x.sigmoid())

def log_g(x):
    # from official repo
    return torch.where(x >= 0, (F.relu(x) + 0.5).log(), -F.softplus(-x))

def associative_scan_log(log_coeffs, log_values, return_log=False):
    """
    Official repo uses:
        a_star = log_coeffs.cumsum(dim=1)
        log_h0_plus_b_star = (log_values - a_star).logcumsumexp(dim=1)
        log_h = a_star + log_h0_plus_b_star
    """
    a_star = log_coeffs.cumsum(dim=1)
    log_h0_plus_b_star = (log_values - a_star).logcumsumexp(dim=1)
    log_h = a_star + log_h0_plus_b_star
    return log_h if return_log else log_h.exp()

# %% [markdown]
# # Normalization, Feedforward and Conv blocks

# %%
class RMSNorm(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.scale = dim ** 0.5
        self.gamma = nn.Parameter(torch.zeros(dim))

    def forward(self, x):
        return F.normalize(x, dim=-1) * self.scale * (self.gamma + 1.0)

class BatchNorm(nn.Module):
    def __init__(self, dim, momentum=0.9):
        super().__init__()
        self.norm = nn.BatchNorm1d(dim, momentum=momentum)

    def forward(self, x):
        # x: [B, L, D]
        return self.norm(x.permute(0, 2, 1)).permute(0, 2, 1)

class GEGLU(nn.Module):
    def __init__(self, dim, mult_bias=True):
        super().__init__()
        self.mult_bias = nn.Parameter(torch.ones(dim)) if mult_bias else 1.0

    def forward(self, x):
        x, gate = x.chunk(2, dim=-1)
        return F.gelu(gate) * x * self.mult_bias

def FeedForward(dim, mult=4, dropout=0.1):
    dim_inner = int(dim * mult)
    return nn.Sequential(
        nn.Linear(dim, dim_inner * 2),
        GEGLU(dim_inner),
        nn.Linear(dim_inner, dim),
        nn.Dropout(dropout),
    )

class CausalDepthWiseConv1d(nn.Module):
    def __init__(self, dim, kernel_size):
        super().__init__()
        self.kernel_size = kernel_size
        self.net = nn.Sequential(
            nn.Conv1d(dim, dim, kernel_size=kernel_size, groups=dim),
            nn.Conv1d(dim, dim, kernel_size=1),
        )

    def forward(self, x):
        # x: [B, L, D]
        x = x.transpose(1, 2)               # [B, D, L]
        x = F.pad(x, (self.kernel_size - 1, 0), value=0.0)
        x = self.net(x)
        return x.transpose(1, 2)            # [B, L, D]

# %% [markdown]
# # minGRU & minLSTM implementation

# %%
class minGRU(nn.Module):
    def __init__(self, dim, expansion_factor=6, use_init_hidden_state=True,
                 scan_cpu_fallback_on_mps=True, **kwargs):
        super().__init__()
        dim_inner = int(dim * expansion_factor)
        self.to_hidden_and_gate = nn.Linear(dim, dim_inner * 2)
        self.to_out = nn.Linear(dim_inner, dim)
        self.init_hidden_state = (
            nn.Parameter(torch.randn(dim_inner), requires_grad=True)
            if use_init_hidden_state else None
        )
        self.scan_cpu_fallback_on_mps = scan_cpu_fallback_on_mps

    def _scan(self, log_coeffs, log_values):
        # optional CPU fallback for MPS numerical stability
        if (
            log_coeffs.device.type == "mps"
            and self.scan_cpu_fallback_on_mps
        ):
            lc_cpu = log_coeffs.cpu()
            lv_cpu = log_values.cpu()
            out_cpu = associative_scan_log(lc_cpu, lv_cpu, return_log=True)
            return out_cpu.to(log_coeffs.device)
        return associative_scan_log(log_coeffs, log_values, return_log=True)

    def forward(self, x, prev_state=None):
        seq_len = x.shape[1]
        hidden, gate = self.to_hidden_and_gate(x).chunk(2, dim=-1)

        if seq_len == 1:
            tilde_h = g(hidden)
            gate = gate.sigmoid()

            if exists(prev_state):
                prev_hidden, _ = prev_state
                out = (1 - gate) * prev_hidden + gate * tilde_h
            elif exists(self.init_hidden_state):
                prev_hidden = g(self.init_hidden_state)
                out = (1 - gate) * prev_hidden + gate * tilde_h
            else:
                out = gate * tilde_h

            next_hidden = out[:, -1:]
            next_log_hidden = out[:, -1:].clamp_min(1e-12).log()

        else:
            log_coeffs = -F.softplus(gate)
            log_z = -F.softplus(-gate)
            log_tilde_h = log_g(hidden)
            log_values = log_z + log_tilde_h

            if exists(prev_state) or exists(self.init_hidden_state):
                if exists(prev_state):
                    _, prev_log_hidden = prev_state
                else:
                    prev_log_hidden = log_g(self.init_hidden_state)
                    prev_log_hidden = prev_log_hidden.unsqueeze(0).unsqueeze(0)
                    prev_log_hidden = prev_log_hidden.repeat(log_values.shape[0], 1, 1)

                log_values = torch.cat((prev_log_hidden, log_values), dim=1)
                log_coeffs = F.pad(log_coeffs, (0, 0, 1, 0))

            log_out = self._scan(log_coeffs, log_values)
            out = torch.exp(log_out[:, -seq_len:])

            next_hidden = out[:, -1:]
            next_log_hidden = log_out[:, -1:]

        out = self.to_out(out)
        return out, (next_hidden, next_log_hidden)


class minLSTM(nn.Module):
    def __init__(self, dim, expansion_factor=6, forget_bias_init_scale=3.0,
                 use_coeff_norm=False, use_init_hidden_state=True,
                 scan_cpu_fallback_on_mps=True, **kwargs):
        super().__init__()
        dim_inner = int(dim * expansion_factor)
        self.to_hidden_and_gate = nn.Linear(dim, dim_inner * 3)
        self.to_out = nn.Linear(dim_inner, dim)
        self.use_coeff_norm = use_coeff_norm
        self.scan_cpu_fallback_on_mps = scan_cpu_fallback_on_mps

        if exists(forget_bias_init_scale):
            with torch.no_grad():
                to_add = torch.zeros_like(self.to_hidden_and_gate.bias)
                to_add[dim_inner:2 * dim_inner] = forget_bias_init_scale
                self.to_hidden_and_gate.bias += to_add

        self.init_hidden_state = (
            nn.Parameter(torch.randn(dim_inner), requires_grad=True)
            if use_init_hidden_state else None
        )

    def _scan(self, log_coeffs, log_values):
        if (
            log_coeffs.device.type == "mps"
            and self.scan_cpu_fallback_on_mps
        ):
            lc_cpu = log_coeffs.cpu()
            lv_cpu = log_values.cpu()
            out_cpu = associative_scan_log(lc_cpu, lv_cpu, return_log=True)
            return out_cpu.to(log_coeffs.device)
        return associative_scan_log(log_coeffs, log_values, return_log=True)

    def forward(self, x, prev_state=None):
        seq_len = x.shape[1]
        hidden, forget_gate, input_gate = self.to_hidden_and_gate(x).chunk(3, dim=-1)

        if seq_len == 1:
            tilde_h = g(hidden)
            input_gate = input_gate.sigmoid()
            forget_gate = forget_gate.sigmoid()

            if self.use_coeff_norm:
                norm = forget_gate + input_gate + 1e-12
                forget_gate = forget_gate / norm
                input_gate = input_gate / norm

            if exists(prev_state):
                prev_hidden, _ = prev_state
                out = forget_gate * prev_hidden + input_gate * tilde_h
            elif exists(self.init_hidden_state):
                prev_hidden = g(self.init_hidden_state)
                out = forget_gate * prev_hidden + input_gate * tilde_h
            else:
                out = input_gate * tilde_h

            next_hidden = out[:, -1:]
            next_log_hidden = out[:, -1:].clamp_min(1e-12).log()

        else:
            if self.use_coeff_norm:
                diff = F.softplus(-forget_gate) - F.softplus(-input_gate)
                log_coeffs = -F.softplus(diff)
                log_val_coeffs = -F.softplus(-diff)
            else:
                log_coeffs = -F.softplus(-forget_gate)
                log_val_coeffs = -F.softplus(-input_gate)

            log_tilde_h = log_g(hidden)
            log_values = log_val_coeffs + log_tilde_h

            if exists(prev_state) or exists(self.init_hidden_state):
                if exists(prev_state):
                    _, prev_log_hidden = prev_state
                else:
                    prev_log_hidden = log_g(self.init_hidden_state)
                    prev_log_hidden = prev_log_hidden.unsqueeze(0).unsqueeze(0)
                    prev_log_hidden = prev_log_hidden.repeat(log_values.shape[0], 1, 1)

                log_values = torch.cat((prev_log_hidden, log_values), dim=1)
                log_coeffs = F.pad(log_coeffs, (0, 0, 1, 0))

            log_out = self._scan(log_coeffs, log_values)
            out = torch.exp(log_out[:, -seq_len:])

            next_hidden = out[:, -1:]
            next_log_hidden = log_out[:, -1:]

        out = self.to_out(out)
        return out, (next_hidden, next_log_hidden)

# %% [markdown]
# # Sequential GRU & LSTM baselines

# %%
class SequentialGRUBlock(nn.Module):
    def __init__(self, dim, expansion_factor=6, **kwargs):
        super().__init__()
        hidden_size = int(dim * expansion_factor)
        self.rnn = nn.GRU(input_size=dim, hidden_size=hidden_size, batch_first=True)
        self.proj = nn.Linear(hidden_size, dim)

    def forward(self, x, prev_state=None):
        if prev_state is not None:
            h0 = prev_state[0].transpose(0, 1)  # [1, B, H]
        else:
            h0 = None
        out, h_n = self.rnn(x, h0)
        out = self.proj(out)
        next_hidden = h_n.transpose(0, 1)      # [B, 1, H]
        next_log_hidden = torch.log(next_hidden.abs().clamp_min(1e-12))
        return out, (next_hidden, next_log_hidden)

class SequentialLSTMBlock(nn.Module):
    def __init__(self, dim, expansion_factor=6, **kwargs):
        super().__init__()
        hidden_size = int(dim * expansion_factor)
        self.rnn = nn.LSTM(input_size=dim, hidden_size=hidden_size, batch_first=True)
        self.proj = nn.Linear(hidden_size, dim)

    def forward(self, x, prev_state=None):
        if prev_state is not None:
            h0 = prev_state[0].transpose(0, 1)
            c0 = prev_state[0].transpose(0, 1)
            state = (h0, c0)
        else:
            state = None
        out, (h_n, c_n) = self.rnn(x, state)
        out = self.proj(out)
        next_hidden = h_n.transpose(0, 1)
        next_log_hidden = torch.log(next_hidden.abs().clamp_min(1e-12))
        return out, (next_hidden, next_log_hidden)

# %% [markdown]
# # Full model wrapper

# %%
class ReplicationModel(nn.Module):
    def __init__(self, module_name: str, cfg: Config):
        super().__init__()
        self.module_name = module_name

        self.token_emb = nn.Embedding(cfg.vocab_size, cfg.d_model)

        norm_cls = RMSNorm if cfg.norm_type == "RMSNorm" else BatchNorm

        block_map = {
            "minGRU": lambda: minGRU(
                dim=cfg.d_model,
                expansion_factor=cfg.expand_dim,
                use_init_hidden_state=cfg.use_init_hidden_state,
                scan_cpu_fallback_on_mps=cfg.scan_cpu_fallback_on_mps,
            ),
            "minLSTM": lambda: minLSTM(
                dim=cfg.d_model,
                expansion_factor=cfg.expand_dim,
                forget_bias_init_scale=cfg.forget_bias_init_scale,
                use_coeff_norm=cfg.use_coeff_norm,
                use_init_hidden_state=cfg.use_init_hidden_state,
                scan_cpu_fallback_on_mps=cfg.scan_cpu_fallback_on_mps,
            ),
            "GRU": lambda: SequentialGRUBlock(
                dim=cfg.d_model,
                expansion_factor=cfg.expand_dim,
            ),
            "LSTM": lambda: SequentialLSTMBlock(
                dim=cfg.d_model,
                expansion_factor=cfg.expand_dim,
            ),
        }

        self.layers = nn.ModuleList()
        for _ in range(cfg.num_layers):
            conv = CausalDepthWiseConv1d(cfg.d_model, cfg.kernel_size) if cfg.kernel_size not in [None, 0] else None
            self.layers.append(nn.ModuleList([
                conv,
                norm_cls(cfg.d_model),
                block_map[module_name](),
                norm_cls(cfg.d_model),
                FeedForward(cfg.d_model, mult=cfg.ff_mult, dropout=cfg.dropout) if cfg.enable_ff else None,
            ]))

        self.final_norm = norm_cls(cfg.d_model)
        self.to_out = nn.Linear(cfg.d_model, cfg.vocab_size, bias=False)

    def forward(self, x, return_states=False, prev_states=None):
        x = self.token_emb(x)

        if prev_states is None:
            prev_states = [None for _ in range(len(self.layers))]

        next_prev_states = []
        for (conv, norm1, rnn_block, norm2, ff), prev_state in zip(self.layers, prev_states):
            if conv is not None:
                x = x + conv(x)

            out, next_state = rnn_block(norm1(x), prev_state=prev_state)
            x = x + out
            next_prev_states.append(next_state)

            if ff is not None:
                x = x + ff(norm2(x))

        logits = self.to_out(self.final_norm(x))
        return (logits, next_prev_states) if return_states else logits

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# # Selective Copy Task sampler

# %%
VOCAB_SIZE = CFG.vocab_size
EMPTY = VOCAB_SIZE - 1
PRED = 0

class SelectiveCopyTaskSampler:
    def __init__(self, sequence_length, num_tokens_memorize, seed=None):
        self.sequence_length = sequence_length
        self.num_tokens_memorize = num_tokens_memorize
        if seed is not None:
            set_seed(seed)

    def sample(self, batch_size=16, device="cpu"):
        # tokens to remember: values 1..VOCAB_SIZE-2
        tokens = torch.randint(
            low=1,
            high=VOCAB_SIZE - 1,
            size=(batch_size, self.num_tokens_memorize),
            device=device
        )

        inds = torch.stack([
            torch.randperm(self.sequence_length, device=device)[:self.num_tokens_memorize]
            for _ in range(batch_size)
        ], dim=0)
        inds, _ = inds.sort(dim=-1)

        sequence = EMPTY * torch.ones((batch_size, self.sequence_length), dtype=torch.long, device=device)
        sequence.scatter_(-1, inds, tokens)

        markers = PRED * torch.ones((batch_size, self.num_tokens_memorize), dtype=torch.long, device=device)

        x = torch.cat((sequence, markers), dim=1)  # [B, L + M]
        y = tokens                                  # [B, M]
        return {"x": x, "y": y}

# %% [markdown]
# # Loss function and metrics

# %%
def selective_copy_loss_and_acc(logits, batch, cfg: Config):
    # logits: [B, L+M, V]
    # only last M positions matter
    logits = logits[:, -cfg.num_tokens_memorize:]   # [B, M, V]
    target = batch["y"]                             # [B, M]

    loss = F.cross_entropy(
        logits.reshape(-1, logits.size(-1)),
        target.reshape(-1)
    )
    acc = (logits.argmax(dim=-1) == target).float().mean()
    return loss, acc

# %% [markdown]
# # Train & Evaluation

# %%
@torch.no_grad()
def evaluate_model(model, cfg: Config, seed=0, num_batches=100, sequence_length=None):
    was_training = model.training
    model.eval()

    seq_len = sequence_length if sequence_length is not None else cfg.sequence_length
    sampler = SelectiveCopyTaskSampler(
        sequence_length=seq_len,
        num_tokens_memorize=cfg.num_tokens_memorize,
        seed=seed
    )

    losses = []
    accs = []

    for _ in range(num_batches):
        batch = sampler.sample(batch_size=cfg.eval_batch_size, device=DEVICE)
        logits = model(batch["x"])
        loss, acc = selective_copy_loss_and_acc(logits, batch, cfg)
        losses.append(loss.item())
        accs.append(acc.item())

    if was_training:
        model.train()

    return {
        "loss": float(np.mean(losses)),
        "acc": float(np.mean(accs)),
    }


def train_model(model_name: str, cfg: Config, seed=42, verbose=True):
    set_seed(seed)

    model = ReplicationModel(model_name, cfg).to(DEVICE)
    sampler = SelectiveCopyTaskSampler(
        sequence_length=cfg.sequence_length,
        num_tokens_memorize=cfg.num_tokens_memorize,
        seed=seed
    )

    params_with_decay = []
    params_without_decay = []

    for name, param in model.named_parameters():
        if "to_hidden_and_gate" in name:
            params_without_decay.append(param)
        else:
            params_with_decay.append(param)

    optimizer = torch.optim.AdamW(
        [
            {"params": params_with_decay, "weight_decay": cfg.weight_decay},
            {"params": params_without_decay, "weight_decay": 0.0},
        ],
        lr=cfg.lr,
    )

    history = {
        "step": [],
        "train_loss": [],
        "train_acc": [],
        "val_loss": [],
        "val_acc": [],
    }

    best_val_acc = -1.0
    best_state = None
    start = time.time()

    model.train()
    optimizer.zero_grad()

    running_loss = []
    running_acc = []

    for step in range(1, cfg.num_steps + 1):
        for _ in range(cfg.accum_iter):
            batch = sampler.sample(batch_size=cfg.train_batch_size // cfg.accum_iter, device=DEVICE)
            logits = model(batch["x"])
            loss, acc = selective_copy_loss_and_acc(logits, batch, cfg)
            (loss / cfg.accum_iter).backward()

            running_loss.append(loss.item())
            running_acc.append(acc.item())

        if cfg.clip is not None:
            torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.clip)

        optimizer.step()
        optimizer.zero_grad()

        if step % cfg.print_freq == 0:
            mean_train_loss = float(np.mean(running_loss[-cfg.print_freq:]))
            mean_train_acc = float(np.mean(running_acc[-cfg.print_freq:]))

            if verbose:
                print(
                    f"[{model_name}] step={step:6d} "
                    f"train_loss={mean_train_loss:.4f} "
                    f"train_acc={mean_train_acc:.4f}"
                )

        if step % cfg.eval_freq == 0 or step == cfg.num_steps:
            val_metrics = evaluate_model(model, cfg, seed=0, num_batches=50)

            model.train()

            history["step"].append(step)
            history["train_loss"].append(float(np.mean(running_loss[-cfg.eval_freq:])))
            history["train_acc"].append(float(np.mean(running_acc[-cfg.eval_freq:])))
            history["val_loss"].append(val_metrics["loss"])
            history["val_acc"].append(val_metrics["acc"])

            if verbose:
                print(
                    f"   -> val_loss={val_metrics['loss']:.4f} "
                    f"val_acc={val_metrics['acc']:.4f}"
                )

            if val_metrics["acc"] >= best_val_acc:
                best_val_acc = val_metrics["acc"]
                best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    total_time = time.time() - start

    if best_state is not None:
        model.load_state_dict(best_state)

    test_metrics = evaluate_model(model, cfg, seed=1, num_batches=100)

    result = {
        "model_name": model_name,
        "seed": seed,
        "params": count_parameters(model),
        "best_val_acc": best_val_acc,
        "test_loss": test_metrics["loss"],
        "test_acc": test_metrics["acc"],
        "train_time_sec": total_time,
        "history": history,
        "model": model,
    }

    return result

# %% [markdown]
# # Sanity check on one batch

# %%
set_seed(42)

sampler = SelectiveCopyTaskSampler(CFG.sequence_length, CFG.num_tokens_memorize, seed=42)
batch = sampler.sample(batch_size=2, device=DEVICE)

print("x shape:", batch["x"].shape)
print("y shape:", batch["y"].shape)
print("example x[0, :40]:", batch["x"][0, :40])
print("target y[0]:", batch["y"][0])

test_model = ReplicationModel("minGRU", CFG).to(DEVICE)
with torch.no_grad():
    logits = test_model(batch["x"])
print("logits shape:", logits.shape)
# Out:
# x shape: torch.Size([2, 520])
# y shape: torch.Size([2, 8])
# example x[0, :40]: tensor([15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#         15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#         15, 15, 15, 15], device='cuda:0')
# target y[0]: tensor([ 2,  6, 13,  7,  6, 10, 11, 11], device='cuda:0')
# logits shape: torch.Size([2, 520, 16])

# %% [markdown]
# # Train 1 model

# %%
FAST_DEV_RUN = False
single_result = train_model("minGRU", CFG, seed=42, verbose=True)
print({
    "params": single_result["params"],
    "best_val_acc": single_result["best_val_acc"],
    "test_acc": single_result["test_acc"],
    "test_loss": single_result["test_loss"],
    "train_time_sec": single_result["train_time_sec"],
})
# Out:
# [minGRU] step=   100 train_loss=2.6572 train_acc=0.0711
# [minGRU] step=   200 train_loss=2.6447 train_acc=0.0736
#    -> val_loss=2.6444 val_acc=0.0694
# [minGRU] step=   300 train_loss=2.6438 train_acc=0.0709
# [minGRU] step=   400 train_loss=2.6424 train_acc=0.0736
# [minGRU] step=   500 train_loss=2.6415 train_acc=0.0733
#    -> val_loss=2.6334 val_acc=0.1012
# [minGRU] step=   600 train_loss=2.5961 train_acc=0.1122
# [minGRU] step=   700 train_loss=2.5312 train_acc=0.1400
#    -> val_loss=2.3051 val_acc=0.2050
# [minGRU] step=   800 train_loss=2.3086 train_acc=0.2029
# [minGRU] step=   900 train_loss=2.1161 train_acc=0.2637
# [minGRU] step=  1000 train_loss=2.0122 train_acc=0.3039
#    -> val_loss=1.9483 val_acc=0.3256
# [minGRU] step=  1100 train_loss=1.8735 train_acc=0.3491
# [minGRU] step=  1200 train_loss=1.6999 train_acc=0.3986
#    -> val_loss=1.5191 val_acc=0.4391
# [minGRU] step=  1300 train_loss=1.5312 train_acc=0.4407
# [minGRU] step=  1400 train_loss=1.3875 train_acc=0.4771
# [minGRU] step=  1500 train_loss=1.2682 train_acc=0.5103
#    -> val_loss=1.2048 val_acc=0.5275
# [minGRU] step=  1600 train_loss=1.1599 train_acc=0.5478
# [minGRU] step=  1700 train_loss=1.0768 train_acc=0.5775
#    -> val_loss=0.9726 val_acc=0.6210
# [minGRU] step=  1800 train_loss=0.9841 train_acc=0.6141
# [minGRU] step=  1900 train_loss=0.9142 train_acc=0.6408
# [minGRU] step=  2000 train_loss=0.8203 train_acc=0.6769
#    -> val_loss=0.7902 val_acc=0.6915
# [minGRU] step=  2100 train_loss=0.7438 train_acc=0.7087
# [minGRU] step=  2200 train_loss=0.6884 train_acc=0.7275
#    -> val_loss=0.6135 val_acc=0.7589
# [minGRU] step=  2300 train_loss=0.6261 train_acc=0.7555
# [minGRU] step=  2400 train_loss=0.5801 train_acc=0.7743
# [minGRU] step=  2500 train_loss=0.5175 train_acc=0.7970
#    -> val_loss=0.4987 val_acc=0.8027
# [minGRU] step=  2600 train_loss=0.4780 train_acc=0.8131
# [minGRU] step=  2700 train_loss=0.4279 train_acc=0.8347
#    -> val_loss=0.4413 val_acc=0.8300
# [minGRU] step=  2800 train_loss=0.3903 train_acc=0.8504
# [minGRU] step=  2900 train_loss=0.3525 train_acc=0.8660
# [minGRU] step=  3000 train_loss=0.3149 train_acc=0.8816
#    -> val_loss=0.3175 val_acc=0.8792
# [minGRU] step=  3100 train_loss=0.2914 train_acc=0.8897
# [minGRU] step=  3200 train_loss=0.2567 train_acc=0.9040
#    -> val_loss=0.2415 val_acc=0.9091
# [minGRU] step=  3300 train_loss=0.2367 train_acc=0.9121
# [minGRU] step=  3400 train_loss=0.2131 train_acc=0.9200
# [minGRU] step=  3500 train_loss=0.2025 train_acc=0.9248
#    -> val_loss=0.2348 val_acc=0.9094
# [minGRU] step=  3600 train_loss=0.1860 train_acc=0.9314
# [minGRU] step=  3700 train_loss=0.1732 train_acc=0.9354
#    -> val_loss=0.1586 val_acc=0.9418
# [minGRU] step=  3800 train_loss=0.1611 train_acc=0.9401
# [minGRU] step=  3900 train_loss=0.1520 train_acc=0.9441
# [minGRU] step=  4000 train_loss=0.1421 train_acc=0.9488
#    -> val_loss=0.1520 val_acc=0.9437
# [minGRU] step=  4100 train_loss=0.1321 train_acc=0.9527
# [minGRU] step=  4200 train_loss=0.1178 train_acc=0.9577
#    -> val_loss=0.1291 val_acc=0.9532
# [minGRU] step=  4300 train_loss=0.1124 train_acc=0.9598
# [minGRU] step=  4400 train_loss=0.1066 train_acc=0.9622
# [minGRU] step=  4500 train_loss=0.1078 train_acc=0.9609
#    -> val_loss=0.1307 val_acc=0.9515
# [minGRU] step=  4600 train_loss=0.1020 train_acc=0.9632
# [minGRU] step=  4700 train_loss=0.0983 train_acc=0.9651
#    -> val_loss=0.1191 val_acc=0.9587
# [minGRU] step=  4800 train_loss=0.0926 train_acc=0.9671
# [minGRU] step=  4900 train_loss=0.0815 train_acc=0.9708
# [minGRU] step=  5000 train_loss=0.0870 train_acc=0.9688
#    -> val_loss=0.1093 val_acc=0.9618
# [minGRU] step=  5100 train_loss=0.0808 train_acc=0.9707
# [minGRU] step=  5200 train_loss=0.0722 train_acc=0.9746
#    -> val_loss=0.1118 val_acc=0.9628
# [minGRU] step=  5300 train_loss=0.0766 train_acc=0.9728
# [minGRU] step=  5400 train_loss=0.0669 train_acc=0.9758
# [minGRU] step=  5500 train_loss=0.0710 train_acc=0.9746
#    -> val_loss=0.0777 val_acc=0.9733
# [minGRU] step=  5600 train_loss=0.0631 train_acc=0.9772
# [minGRU] step=  5700 train_loss=0.0560 train_acc=0.9806
#    -> val_loss=0.0630 val_acc=0.9771
# [minGRU] step=  5800 train_loss=0.0563 train_acc=0.9803
# [minGRU] step=  5900 train_loss=0.0523 train_acc=0.9819
# [minGRU] step=  6000 train_loss=0.0523 train_acc=0.9815
#    -> val_loss=0.0650 val_acc=0.9776
# [minGRU] step=  6100 train_loss=0.0533 train_acc=0.9817
# [minGRU] step=  6200 train_loss=0.0446 train_acc=0.9842
#    -> val_loss=0.0457 val_acc=0.9840
# [minGRU] step=  6300 train_loss=0.0460 train_acc=0.9844
# [minGRU] step=  6400 train_loss=0.0440 train_acc=0.9845
# [minGRU] step=  6500 train_loss=0.0429 train_acc=0.9851
#    -> val_loss=0.0411 val_acc=0.9860
# [minGRU] step=  6600 train_loss=0.0406 train_acc=0.9865
# [minGRU] step=  6700 train_loss=0.0363 train_acc=0.9873
#    -> val_loss=0.0385 val_acc=0.9870
# [minGRU] step=  6800 train_loss=0.0353 train_acc=0.9879
# [minGRU] step=  6900 train_loss=0.0334 train_acc=0.9886
# [minGRU] step=  7000 train_loss=0.0300 train_acc=0.9894
#    -> val_loss=0.0307 val_acc=0.9896
# [minGRU] step=  7100 train_loss=0.0311 train_acc=0.9896
# [minGRU] step=  7200 train_loss=0.0282 train_acc=0.9904
#    -> val_loss=0.0590 val_acc=0.9801
# [minGRU] step=  7300 train_loss=0.0270 train_acc=0.9908
# [minGRU] step=  7400 train_loss=0.0279 train_acc=0.9905
# [minGRU] step=  7500 train_loss=0.0260 train_acc=0.9913
#    -> val_loss=0.0262 val_acc=0.9914
# [minGRU] step=  7600 train_loss=0.0259 train_acc=0.9913
# [minGRU] step=  7700 train_loss=0.0270 train_acc=0.9909
#    -> val_loss=0.0664 val_acc=0.9775
# [minGRU] step=  7800 train_loss=0.0278 train_acc=0.9908
# [minGRU] step=  7900 train_loss=0.0231 train_acc=0.9922
# [minGRU] step=  8000 train_loss=0.0243 train_acc=0.9917
#    -> val_loss=0.0205 val_acc=0.9927
# {'params': 152448, 'best_val_acc': 0.99265625, 'test_acc': 0.99248046875, 'test_loss': 0.022170254797674715, 'train_time_sec': 368.72520208358765}

# %% [markdown]
# # Plot training curve for 1 model

# %%
hist = pd.DataFrame(single_result["history"])

plt.figure(figsize=(8, 5))
plt.plot(hist["step"], hist["train_acc"], label="train acc")
plt.plot(hist["step"], hist["val_acc"], label="val acc")
plt.xlabel("step")
plt.ylabel("accuracy")
plt.title("Selective Copy: minGRU training curve")
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(hist["step"], hist["train_loss"], label="train loss")
plt.plot(hist["step"], hist["val_loss"], label="val loss")
plt.xlabel("step")
plt.ylabel("cross-entropy loss")
plt.title("Selective Copy: minGRU loss curve")
plt.legend()
plt.show()

# %% [markdown]
# # Compare across all models and seeds

# %%
MODELS = ["minGRU", "minLSTM", "GRU", "LSTM"]
SEEDS = [42, 43, 44]   # increase to 5 if have time

all_results = []

for model_name in MODELS:
    for seed in SEEDS:
        print(f"\n===== Training {model_name}, seed={seed} =====")
        result = train_model(model_name, CFG, seed=seed, verbose=True)
        all_results.append(result)
# Out:
# ===== Training minGRU, seed=42 =====
# [minGRU] step=   100 train_loss=2.6572 train_acc=0.0711
# [minGRU] step=   200 train_loss=2.6447 train_acc=0.0736
#    -> val_loss=2.6444 val_acc=0.0694
# [minGRU] step=   300 train_loss=2.6438 train_acc=0.0709
# [minGRU] step=   400 train_loss=2.6424 train_acc=0.0736
# [minGRU] step=   500 train_loss=2.6415 train_acc=0.0733
#    -> val_loss=2.6334 val_acc=0.1012
# [minGRU] step=   600 train_loss=2.5961 train_acc=0.1122
# [minGRU] step=   700 train_loss=2.5312 train_acc=0.1400
#    -> val_loss=2.3051 val_acc=0.2050
# [minGRU] step=   800 train_loss=2.3086 train_acc=0.2029
# [minGRU] step=   900 train_loss=2.1161 train_acc=0.2637
# [minGRU] step=  1000 train_loss=2.0122 train_acc=0.3039
#    -> val_loss=1.9483 val_acc=0.3256
# [minGRU] step=  1100 train_loss=1.8735 train_acc=0.3491
# [minGRU] step=  1200 train_loss=1.6999 train_acc=0.3986
#    -> val_loss=1.5191 val_acc=0.4391
# [minGRU] step=  1300 train_loss=1.5312 train_acc=0.4407
# [minGRU] step=  1400 train_loss=1.3875 train_acc=0.4771
# [minGRU] step=  1500 train_loss=1.2682 train_acc=0.5103
#    -> val_loss=1.2048 val_acc=0.5275
# [minGRU] step=  1600 train_loss=1.1599 train_acc=0.5478
# [minGRU] step=  1700 train_loss=1.0768 train_acc=0.5775
#    -> val_loss=0.9726 val_acc=0.6210
# [minGRU] step=  1800 train_loss=0.9841 train_acc=0.6141
# [minGRU] step=  1900 train_loss=0.9142 train_acc=0.6408
# [minGRU] step=  2000 train_loss=0.8203 train_acc=0.6769
#    -> val_loss=0.7902 val_acc=0.6915
# [minGRU] step=  2100 train_loss=0.7438 train_acc=0.7087
# [minGRU] step=  2200 train_loss=0.6884 train_acc=0.7275
#    -> val_loss=0.6135 val_acc=0.7589
# [minGRU] step=  2300 train_loss=0.6261 train_acc=0.7555
# [minGRU] step=  2400 train_loss=0.5801 train_acc=0.7743
# [minGRU] step=  2500 train_loss=0.5175 train_acc=0.7970
#    -> val_loss=0.4987 val_acc=0.8027
# [minGRU] step=  2600 train_loss=0.4780 train_acc=0.8131
# [minGRU] step=  2700 train_loss=0.4279 train_acc=0.8347
#    -> val_loss=0.4413 val_acc=0.8300
# [minGRU] step=  2800 train_loss=0.3903 train_acc=0.8504
# [minGRU] step=  2900 train_loss=0.3525 train_acc=0.8660
# [minGRU] step=  3000 train_loss=0.3149 train_acc=0.8816
#    -> val_loss=0.3175 val_acc=0.8792
# [minGRU] step=  3100 train_loss=0.2914 train_acc=0.8897
# [minGRU] step=  3200 train_loss=0.2567 train_acc=0.9040
#    -> val_loss=0.2415 val_acc=0.9091
# [minGRU] step=  3300 train_loss=0.2367 train_acc=0.9121
# [minGRU] step=  3400 train_loss=0.2131 train_acc=0.9200
# [minGRU] step=  3500 train_loss=0.2025 train_acc=0.9248
#    -> val_loss=0.2348 val_acc=0.9094
# [minGRU] step=  3600 train_loss=0.1860 train_acc=0.9314
# [minGRU] step=  3700 train_loss=0.1732 train_acc=0.9354
#    -> val_loss=0.1586 val_acc=0.9418
# [minGRU] step=  3800 train_loss=0.1611 train_acc=0.9401
# [minGRU] step=  3900 train_loss=0.1520 train_acc=0.9441
# [minGRU] step=  4000 train_loss=0.1421 train_acc=0.9488
#    -> val_loss=0.1520 val_acc=0.9437
# [minGRU] step=  4100 train_loss=0.1321 train_acc=0.9527
# [minGRU] step=  4200 train_loss=0.1178 train_acc=0.9577
#    -> val_loss=0.1291 val_acc=0.9532
# [minGRU] step=  4300 train_loss=0.1124 train_acc=0.9598
# [minGRU] step=  4400 train_loss=0.1066 train_acc=0.9622
# [minGRU] step=  4500 train_loss=0.1078 train_acc=0.9609
#    -> val_loss=0.1307 val_acc=0.9515
# [minGRU] step=  4600 train_loss=0.1020 train_acc=0.9632
# [minGRU] step=  4700 train_loss=0.0983 train_acc=0.9651
#    -> val_loss=0.1191 val_acc=0.9587
# [minGRU] step=  4800 train_loss=0.0926 train_acc=0.9671
# [minGRU] step=  4900 train_loss=0.0815 train_acc=0.9708
# [minGRU] step=  5000 train_loss=0.0870 train_acc=0.9688
#    -> val_loss=0.1093 val_acc=0.9618
# [minGRU] step=  5100 train_loss=0.0808 train_acc=0.9707
# [minGRU] step=  5200 train_loss=0.0722 train_acc=0.9746
#    -> val_loss=0.1118 val_acc=0.9628
# [minGRU] step=  5300 train_loss=0.0766 train_acc=0.9728
# [minGRU] step=  5400 train_loss=0.0669 train_acc=0.9758
# [minGRU] step=  5500 train_loss=0.0710 train_acc=0.9746
#    -> val_loss=0.0777 val_acc=0.9733
# [minGRU] step=  5600 train_loss=0.0631 train_acc=0.9772
# [minGRU] step=  5700 train_loss=0.0560 train_acc=0.9806
#    -> val_loss=0.0630 val_acc=0.9771
# [minGRU] step=  5800 train_loss=0.0563 train_acc=0.9803
# [minGRU] step=  5900 train_loss=0.0523 train_acc=0.9819
# [minGRU] step=  6000 train_loss=0.0523 train_acc=0.9815
#    -> val_loss=0.0650 val_acc=0.9776
# [minGRU] step=  6100 train_loss=0.0533 train_acc=0.9817
# [minGRU] step=  6200 train_loss=0.0446 train_acc=0.9842
#    -> val_loss=0.0457 val_acc=0.9840
# [minGRU] step=  6300 train_loss=0.0460 train_acc=0.9844
# [minGRU] step=  6400 train_loss=0.0440 train_acc=0.9845
# [minGRU] step=  6500 train_loss=0.0429 train_acc=0.9851
#    -> val_loss=0.0411 val_acc=0.9860
# [minGRU] step=  6600 train_loss=0.0406 train_acc=0.9865
# [minGRU] step=  6700 train_loss=0.0363 train_acc=0.9873
#    -> val_loss=0.0385 val_acc=0.9870
# [minGRU] step=  6800 train_loss=0.0353 train_acc=0.9879
# [minGRU] step=  6900 train_loss=0.0334 train_acc=0.9886
# [minGRU] step=  7000 train_loss=0.0300 train_acc=0.9894
#    -> val_loss=0.0307 val_acc=0.9896
# [minGRU] step=  7100 train_loss=0.0311 train_acc=0.9896
# [minGRU] step=  7200 train_loss=0.0282 train_acc=0.9904
#    -> val_loss=0.0590 val_acc=0.9801
# [minGRU] step=  7300 train_loss=0.0270 train_acc=0.9908
# [minGRU] step=  7400 train_loss=0.0279 train_acc=0.9905
# [minGRU] step=  7500 train_loss=0.0260 train_acc=0.9913
#    -> val_loss=0.0262 val_acc=0.9914
# [minGRU] step=  7600 train_loss=0.0259 train_acc=0.9913
# [minGRU] step=  7700 train_loss=0.0270 train_acc=0.9909
#    -> val_loss=0.0664 val_acc=0.9775
# [minGRU] step=  7800 train_loss=0.0278 train_acc=0.9908
# [minGRU] step=  7900 train_loss=0.0231 train_acc=0.9922
# [minGRU] step=  8000 train_loss=0.0243 train_acc=0.9917
#    -> val_loss=0.0205 val_acc=0.9927
#
# ===== Training minGRU, seed=43 =====
# [minGRU] step=   100 train_loss=2.6577 train_acc=0.0714
# [minGRU] step=   200 train_loss=2.6461 train_acc=0.0730
#    -> val_loss=2.6433 val_acc=0.0695
# [minGRU] step=   300 train_loss=2.6431 train_acc=0.0709
# [minGRU] step=   400 train_loss=2.6424 train_acc=0.0721
# [minGRU] step=   500 train_loss=2.6179 train_acc=0.0974
#    -> val_loss=2.5553 val_acc=0.1266
# [minGRU] step=   600 train_loss=2.5030 train_acc=0.1423
# [minGRU] step=   700 train_loss=2.3651 train_acc=0.1806
#    -> val_loss=2.1683 val_acc=0.2312
# [minGRU] step=   800 train_loss=2.1783 train_acc=0.2318
# [minGRU] step=   900 train_loss=1.9860 train_acc=0.2919
# [minGRU] step=  1000 train_loss=1.8014 train_acc=0.3423
#    -> val_loss=1.7073 val_acc=0.3638
# [minGRU] step=  1100 train_loss=1.6399 train_acc=0.3876
# [minGRU] step=  1200 train_loss=1.5157 train_acc=0.4282
#    -> val_loss=1.3744 val_acc=0.4732
# [minGRU] step=  1300 train_loss=1.3797 train_acc=0.4690
# [minGRU] step=  1400 train_loss=1.2405 train_acc=0.5127
# [minGRU] step=  1500 train_loss=1.1121 train_acc=0.5591
#    -> val_loss=1.0585 val_acc=0.5791
# [minGRU] step=  1600 train_loss=1.0147 train_acc=0.5962
# [minGRU] step=  1700 train_loss=0.9328 train_acc=0.6292
#    -> val_loss=0.8528 val_acc=0.6575
# [minGRU] step=  1800 train_loss=0.8688 train_acc=0.6527
# [minGRU] step=  1900 train_loss=0.8072 train_acc=0.6791
# [minGRU] step=  2000 train_loss=0.7542 train_acc=0.6989
#    -> val_loss=0.7319 val_acc=0.7118
# [minGRU] step=  2100 train_loss=0.7069 train_acc=0.7175
# [minGRU] step=  2200 train_loss=0.6501 train_acc=0.7426
#    -> val_loss=0.6282 val_acc=0.7525
# [minGRU] step=  2300 train_loss=0.6132 train_acc=0.7543
# [minGRU] step=  2400 train_loss=0.5586 train_acc=0.7805
# [minGRU] step=  2500 train_loss=0.5169 train_acc=0.7984
#    -> val_loss=0.5224 val_acc=0.7976
# [minGRU] step=  2600 train_loss=0.4791 train_acc=0.8149
# [minGRU] step=  2700 train_loss=0.4327 train_acc=0.8344
#    -> val_loss=0.4061 val_acc=0.8466
# [minGRU] step=  2800 train_loss=0.3959 train_acc=0.8500
# [minGRU] step=  2900 train_loss=0.3427 train_acc=0.8727
# [minGRU] step=  3000 train_loss=0.3188 train_acc=0.8812
#    -> val_loss=0.3122 val_acc=0.8850
# [minGRU] step=  3100 train_loss=0.2829 train_acc=0.8976
# [minGRU] step=  3200 train_loss=0.2692 train_acc=0.9008
#    -> val_loss=0.2203 val_acc=0.9237
# [minGRU] step=  3300 train_loss=0.2399 train_acc=0.9130
# [minGRU] step=  3400 train_loss=0.2159 train_acc=0.9237
# [minGRU] step=  3500 train_loss=0.1985 train_acc=0.9283
#    -> val_loss=0.2020 val_acc=0.9312
# [minGRU] step=  3600 train_loss=0.1754 train_acc=0.9375
# [minGRU] step=  3700 train_loss=0.1594 train_acc=0.9429
#    -> val_loss=0.1493 val_acc=0.9471
# [minGRU] step=  3800 train_loss=0.1472 train_acc=0.9480
# [minGRU] step=  3900 train_loss=0.1213 train_acc=0.9583
# [minGRU] step=  4000 train_loss=0.1108 train_acc=0.9622
#    -> val_loss=0.1236 val_acc=0.9571
# [minGRU] step=  4100 train_loss=0.1042 train_acc=0.9641
# [minGRU] step=  4200 train_loss=0.0862 train_acc=0.9719
#    -> val_loss=0.0921 val_acc=0.9688
# [minGRU] step=  4300 train_loss=0.0896 train_acc=0.9690
# [minGRU] step=  4400 train_loss=0.0775 train_acc=0.9738
# [minGRU] step=  4500 train_loss=0.0685 train_acc=0.9775
#    -> val_loss=0.0861 val_acc=0.9716
# [minGRU] step=  4600 train_loss=0.0659 train_acc=0.9781
# [minGRU] step=  4700 train_loss=0.0614 train_acc=0.9795
#    -> val_loss=0.0638 val_acc=0.9792
# [minGRU] step=  4800 train_loss=0.0887 train_acc=0.9704
# [minGRU] step=  4900 train_loss=0.0630 train_acc=0.9794
# [minGRU] step=  5000 train_loss=0.0537 train_acc=0.9822
#    -> val_loss=0.0508 val_acc=0.9833
# [minGRU] step=  5100 train_loss=0.0471 train_acc=0.9844
# [minGRU] step=  5200 train_loss=0.0463 train_acc=0.9853
#    -> val_loss=0.0832 val_acc=0.9728
# [minGRU] step=  5300 train_loss=0.0457 train_acc=0.9849
# [minGRU] step=  5400 train_loss=0.0480 train_acc=0.9845
# [minGRU] step=  5500 train_loss=0.0403 train_acc=0.9866
#    -> val_loss=0.0453 val_acc=0.9852
# [minGRU] step=  5600 train_loss=0.0492 train_acc=0.9838
# [minGRU] step=  5700 train_loss=0.0343 train_acc=0.9891
#    -> val_loss=0.0378 val_acc=0.9889
# [minGRU] step=  5800 train_loss=0.0361 train_acc=0.9888
# [minGRU] step=  5900 train_loss=0.0335 train_acc=0.9896
# [minGRU] step=  6000 train_loss=0.0321 train_acc=0.9896
#    -> val_loss=0.0309 val_acc=0.9897
# [minGRU] step=  6100 train_loss=0.0309 train_acc=0.9903
# [minGRU] step=  6200 train_loss=0.0455 train_acc=0.9858
#    -> val_loss=0.0283 val_acc=0.9918
# [minGRU] step=  6300 train_loss=0.0316 train_acc=0.9896
# [minGRU] step=  6400 train_loss=0.0374 train_acc=0.9881
# [minGRU] step=  6500 train_loss=0.0267 train_acc=0.9916
#    -> val_loss=0.0219 val_acc=0.9935
# [minGRU] step=  6600 train_loss=0.0279 train_acc=0.9914
# [minGRU] step=  6700 train_loss=0.0499 train_acc=0.9858
#    -> val_loss=0.0371 val_acc=0.9887
# [minGRU] step=  6800 train_loss=0.0250 train_acc=0.9922
# [minGRU] step=  6900 train_loss=0.0274 train_acc=0.9918
# [minGRU] step=  7000 train_loss=0.0297 train_acc=0.9907
#    -> val_loss=0.0626 val_acc=0.9827
# [minGRU] step=  7100 train_loss=0.0340 train_acc=0.9900
# [minGRU] step=  7200 train_loss=0.0281 train_acc=0.9914
#    -> val_loss=0.0148 val_acc=0.9960
# [minGRU] step=  7300 train_loss=0.0249 train_acc=0.9924
# [minGRU] step=  7400 train_loss=0.0257 train_acc=0.9923
# [minGRU] step=  7500 train_loss=0.0251 train_acc=0.9928
#    -> val_loss=0.0244 val_acc=0.9919
# [minGRU] step=  7600 train_loss=0.0420 train_acc=0.9878
# [minGRU] step=  7700 train_loss=0.0533 train_acc=0.9849
#    -> val_loss=0.0428 val_acc=0.9862
# [minGRU] step=  7800 train_loss=0.0751 train_acc=0.9794
# [minGRU] step=  7900 train_loss=0.0520 train_acc=0.9846
# [minGRU] step=  8000 train_loss=0.0328 train_acc=0.9908
#    -> val_loss=0.0736 val_acc=0.9824
#
# ===== Training minGRU, seed=44 =====
# [minGRU] step=   100 train_loss=2.6546 train_acc=0.0704
# [minGRU] step=   200 train_loss=2.6440 train_acc=0.0711
#    -> val_loss=2.6405 val_acc=0.0730
# [minGRU] step=   300 train_loss=2.6389 train_acc=0.0809
# [minGRU] step=   400 train_loss=2.5788 train_acc=0.1194
# [minGRU] step=   500 train_loss=2.4804 train_acc=0.1570
#    -> val_loss=2.3872 val_acc=0.1845
# [minGRU] step=   600 train_loss=2.2788 train_acc=0.2162
# [minGRU] step=   700 train_loss=2.1400 train_acc=0.2478
#    -> val_loss=1.9355 val_acc=0.2907
# [minGRU] step=   800 train_loss=1.9422 train_acc=0.2963
# [minGRU] step=   900 train_loss=1.8250 train_acc=0.3295
# [minGRU] step=  1000 train_loss=1.7326 train_acc=0.3543
#    -> val_loss=1.7015 val_acc=0.3651
# [minGRU] step=  1100 train_loss=1.6544 train_acc=0.3742
# [minGRU] step=  1200 train_loss=1.5563 train_acc=0.3928
#    -> val_loss=1.4787 val_acc=0.4062
# [minGRU] step=  1300 train_loss=1.4705 train_acc=0.4124
# [minGRU] step=  1400 train_loss=1.3962 train_acc=0.4283
# [minGRU] step=  1500 train_loss=1.3224 train_acc=0.4525
#    -> val_loss=1.2958 val_acc=0.4597
# [minGRU] step=  1600 train_loss=1.2629 train_acc=0.4704
# [minGRU] step=  1700 train_loss=1.2046 train_acc=0.4909
#    -> val_loss=1.1665 val_acc=0.5058
# [minGRU] step=  1800 train_loss=1.1574 train_acc=0.5116
# [minGRU] step=  1900 train_loss=1.1091 train_acc=0.5292
# [minGRU] step=  2000 train_loss=1.0576 train_acc=0.5495
#    -> val_loss=1.0525 val_acc=0.5462
# [minGRU] step=  2100 train_loss=1.0038 train_acc=0.5714
# [minGRU] step=  2200 train_loss=0.9578 train_acc=0.5905
#    -> val_loss=0.8979 val_acc=0.6164
# [minGRU] step=  2300 train_loss=0.9076 train_acc=0.6128
# [minGRU] step=  2400 train_loss=0.8538 train_acc=0.6438
# [minGRU] step=  2500 train_loss=0.8038 train_acc=0.6642
#    -> val_loss=0.7983 val_acc=0.6676
# [minGRU] step=  2600 train_loss=0.7449 train_acc=0.6958
# [minGRU] step=  2700 train_loss=0.6868 train_acc=0.7260
#    -> val_loss=0.6585 val_acc=0.7400
# [minGRU] step=  2800 train_loss=0.6395 train_acc=0.7462
# [minGRU] step=  2900 train_loss=0.5743 train_acc=0.7784
# [minGRU] step=  3000 train_loss=0.5403 train_acc=0.7932
#    -> val_loss=0.5121 val_acc=0.8061
# [minGRU] step=  3100 train_loss=0.4899 train_acc=0.8144
# [minGRU] step=  3200 train_loss=0.4599 train_acc=0.8263
#    -> val_loss=0.4054 val_acc=0.8498
# [minGRU] step=  3300 train_loss=0.4189 train_acc=0.8437
# [minGRU] step=  3400 train_loss=0.3975 train_acc=0.8524
# [minGRU] step=  3500 train_loss=0.3719 train_acc=0.8622
#    -> val_loss=0.3564 val_acc=0.8638
# [minGRU] step=  3600 train_loss=0.3247 train_acc=0.8816
# [minGRU] step=  3700 train_loss=0.3061 train_acc=0.8877
#    -> val_loss=0.3238 val_acc=0.8814
# [minGRU] step=  3800 train_loss=0.2740 train_acc=0.9020
# [minGRU] step=  3900 train_loss=0.2533 train_acc=0.9092
# [minGRU] step=  4000 train_loss=0.2468 train_acc=0.9122
#    -> val_loss=0.2381 val_acc=0.9144
# [minGRU] step=  4100 train_loss=0.2062 train_acc=0.9279
# [minGRU] step=  4200 train_loss=0.1911 train_acc=0.9336
#    -> val_loss=0.1865 val_acc=0.9353
# [minGRU] step=  4300 train_loss=0.1908 train_acc=0.9311
# [minGRU] step=  4400 train_loss=0.1684 train_acc=0.9403
# [minGRU] step=  4500 train_loss=0.1545 train_acc=0.9465
#    -> val_loss=0.1405 val_acc=0.9522
# [minGRU] step=  4600 train_loss=0.1484 train_acc=0.9488
# [minGRU] step=  4700 train_loss=0.1375 train_acc=0.9534
#    -> val_loss=0.3316 val_acc=0.8859
# [minGRU] step=  4800 train_loss=0.1569 train_acc=0.9457
# [minGRU] step=  4900 train_loss=0.1326 train_acc=0.9524
# [minGRU] step=  5000 train_loss=0.1182 train_acc=0.9584
#    -> val_loss=0.1378 val_acc=0.9528
# [minGRU] step=  5100 train_loss=0.1143 train_acc=0.9599
# [minGRU] step=  5200 train_loss=0.1065 train_acc=0.9637
#    -> val_loss=0.1300 val_acc=0.9541
# [minGRU] step=  5300 train_loss=0.0964 train_acc=0.9677
# [minGRU] step=  5400 train_loss=0.0861 train_acc=0.9703
# [minGRU] step=  5500 train_loss=0.0864 train_acc=0.9701
#    -> val_loss=0.0815 val_acc=0.9729
# [minGRU] step=  5600 train_loss=0.0827 train_acc=0.9723
# [minGRU] step=  5700 train_loss=0.0852 train_acc=0.9707
#    -> val_loss=0.0549 val_acc=0.9822
# [minGRU] step=  5800 train_loss=0.0651 train_acc=0.9782
# [minGRU] step=  5900 train_loss=0.0613 train_acc=0.9800
# [minGRU] step=  6000 train_loss=0.0622 train_acc=0.9795
#    -> val_loss=0.0506 val_acc=0.9829
# [minGRU] step=  6100 train_loss=0.0503 train_acc=0.9838
# [minGRU] step=  6200 train_loss=0.0546 train_acc=0.9816
#    -> val_loss=0.0467 val_acc=0.9845
# [minGRU] step=  6300 train_loss=0.0580 train_acc=0.9803
# [minGRU] step=  6400 train_loss=0.0553 train_acc=0.9814
# [minGRU] step=  6500 train_loss=0.0595 train_acc=0.9802
#    -> val_loss=0.0608 val_acc=0.9790
# [minGRU] step=  6600 train_loss=0.0469 train_acc=0.9846
# [minGRU] step=  6700 train_loss=0.0484 train_acc=0.9841
#    -> val_loss=0.0491 val_acc=0.9832
# [minGRU] step=  6800 train_loss=0.0462 train_acc=0.9848
# [minGRU] step=  6900 train_loss=0.0400 train_acc=0.9871
# [minGRU] step=  7000 train_loss=0.0469 train_acc=0.9840
#    -> val_loss=0.0435 val_acc=0.9862
# [minGRU] step=  7100 train_loss=0.0473 train_acc=0.9853
# [minGRU] step=  7200 train_loss=0.0465 train_acc=0.9857
#    -> val_loss=0.0318 val_acc=0.9896
# [minGRU] step=  7300 train_loss=0.0390 train_acc=0.9872
# [minGRU] step=  7400 train_loss=0.0356 train_acc=0.9888
# [minGRU] step=  7500 train_loss=0.0453 train_acc=0.9856
#    -> val_loss=0.0407 val_acc=0.9860
# [minGRU] step=  7600 train_loss=0.0350 train_acc=0.9888
# [minGRU] step=  7700 train_loss=0.0281 train_acc=0.9908
#    -> val_loss=0.0409 val_acc=0.9860
# [minGRU] step=  7800 train_loss=0.0360 train_acc=0.9883
# [minGRU] step=  7900 train_loss=0.0250 train_acc=0.9915
# [minGRU] step=  8000 train_loss=0.0245 train_acc=0.9921
#    -> val_loss=0.0289 val_acc=0.9895
#
# ===== Training minLSTM, seed=42 =====
# [minLSTM] step=   100 train_loss=2.6550 train_acc=0.0726
# [minLSTM] step=   200 train_loss=2.6436 train_acc=0.0727
#    -> val_loss=2.5989 val_acc=0.0988
# [minLSTM] step=   300 train_loss=2.5945 train_acc=0.1046
# [minLSTM] step=   400 train_loss=2.4033 train_acc=0.1732
# [minLSTM] step=   500 train_loss=2.2634 train_acc=0.2018
#    -> val_loss=2.1681 val_acc=0.2281
# [minLSTM] step=   600 train_loss=2.0706 train_acc=0.2603
# [minLSTM] step=   700 train_loss=1.9418 train_acc=0.2980
#    -> val_loss=1.8606 val_acc=0.3146
# [minLSTM] step=   800 train_loss=1.8583 train_acc=0.3177
# [minLSTM] step=   900 train_loss=1.8032 train_acc=0.3286
# [minLSTM] step=  1000 train_loss=1.7221 train_acc=0.3438
#    -> val_loss=1.6930 val_acc=0.3505
# [minLSTM] step=  1100 train_loss=1.6521 train_acc=0.3566
# [minLSTM] step=  1200 train_loss=1.6004 train_acc=0.3694
#    -> val_loss=1.5426 val_acc=0.3847
# [minLSTM] step=  1300 train_loss=1.5456 train_acc=0.3800
# [minLSTM] step=  1400 train_loss=1.5015 train_acc=0.3899
# [minLSTM] step=  1500 train_loss=1.4556 train_acc=0.3986
#    -> val_loss=1.4368 val_acc=0.4027
# [minLSTM] step=  1600 train_loss=1.4181 train_acc=0.4104
# [minLSTM] step=  1700 train_loss=1.3871 train_acc=0.4183
#    -> val_loss=1.3414 val_acc=0.4348
# [minLSTM] step=  1800 train_loss=1.3521 train_acc=0.4282
# [minLSTM] step=  1900 train_loss=1.3214 train_acc=0.4389
# [minLSTM] step=  2000 train_loss=1.2972 train_acc=0.4471
#    -> val_loss=1.2702 val_acc=0.4599
# [minLSTM] step=  2100 train_loss=1.2709 train_acc=0.4565
# [minLSTM] step=  2200 train_loss=1.2516 train_acc=0.4632
#    -> val_loss=1.2079 val_acc=0.4755
# [minLSTM] step=  2300 train_loss=1.2298 train_acc=0.4690
# [minLSTM] step=  2400 train_loss=1.2016 train_acc=0.4768
# [minLSTM] step=  2500 train_loss=1.1825 train_acc=0.4856
#    -> val_loss=1.1545 val_acc=0.4943
# [minLSTM] step=  2600 train_loss=1.1617 train_acc=0.4931
# [minLSTM] step=  2700 train_loss=1.1400 train_acc=0.4977
#    -> val_loss=1.1282 val_acc=0.5048
# [minLSTM] step=  2800 train_loss=1.1282 train_acc=0.5015
# [minLSTM] step=  2900 train_loss=1.1060 train_acc=0.5112
# [minLSTM] step=  3000 train_loss=1.0899 train_acc=0.5162
#    -> val_loss=1.0735 val_acc=0.5214
# [minLSTM] step=  3100 train_loss=1.0744 train_acc=0.5255
# [minLSTM] step=  3200 train_loss=1.0626 train_acc=0.5277
#    -> val_loss=1.0463 val_acc=0.5335
# [minLSTM] step=  3300 train_loss=1.0464 train_acc=0.5345
# [minLSTM] step=  3400 train_loss=1.0236 train_acc=0.5443
# [minLSTM] step=  3500 train_loss=1.0148 train_acc=0.5484
#    -> val_loss=1.0238 val_acc=0.5499
# [minLSTM] step=  3600 train_loss=0.9988 train_acc=0.5581
# [minLSTM] step=  3700 train_loss=0.9835 train_acc=0.5613
#    -> val_loss=0.9729 val_acc=0.5660
# [minLSTM] step=  3800 train_loss=0.9709 train_acc=0.5669
# [minLSTM] step=  3900 train_loss=0.9468 train_acc=0.5789
# [minLSTM] step=  4000 train_loss=0.9354 train_acc=0.5841
#    -> val_loss=0.9236 val_acc=0.5920
# [minLSTM] step=  4100 train_loss=0.9102 train_acc=0.5986
# [minLSTM] step=  4200 train_loss=0.9059 train_acc=0.5976
#    -> val_loss=0.9079 val_acc=0.5947
# [minLSTM] step=  4300 train_loss=0.8973 train_acc=0.6029
# [minLSTM] step=  4400 train_loss=0.8608 train_acc=0.6231
# [minLSTM] step=  4500 train_loss=0.8483 train_acc=0.6281
#    -> val_loss=0.8348 val_acc=0.6312
# [minLSTM] step=  4600 train_loss=0.8298 train_acc=0.6404
# [minLSTM] step=  4700 train_loss=0.8100 train_acc=0.6459
#    -> val_loss=0.8036 val_acc=0.6508
# [minLSTM] step=  4800 train_loss=0.7999 train_acc=0.6521
# [minLSTM] step=  4900 train_loss=0.7671 train_acc=0.6702
# [minLSTM] step=  5000 train_loss=0.7540 train_acc=0.6741
#    -> val_loss=0.7469 val_acc=0.6750
# [minLSTM] step=  5100 train_loss=0.7293 train_acc=0.6881
# [minLSTM] step=  5200 train_loss=0.7108 train_acc=0.6949
#    -> val_loss=0.6969 val_acc=0.6995
# [minLSTM] step=  5300 train_loss=0.6983 train_acc=0.7012
# [minLSTM] step=  5400 train_loss=0.6648 train_acc=0.7182
# [minLSTM] step=  5500 train_loss=0.6570 train_acc=0.7206
#    -> val_loss=0.6509 val_acc=0.7207
# [minLSTM] step=  5600 train_loss=0.6244 train_acc=0.7371
# [minLSTM] step=  5700 train_loss=0.6095 train_acc=0.7429
#    -> val_loss=0.6136 val_acc=0.7380
# [minLSTM] step=  5800 train_loss=0.5892 train_acc=0.7507
# [minLSTM] step=  5900 train_loss=0.5662 train_acc=0.7620
# [minLSTM] step=  6000 train_loss=0.5416 train_acc=0.7755
#    -> val_loss=0.5748 val_acc=0.7622
# [minLSTM] step=  6100 train_loss=0.5258 train_acc=0.7815
# [minLSTM] step=  6200 train_loss=0.5003 train_acc=0.7921
#    -> val_loss=0.4945 val_acc=0.7969
# [minLSTM] step=  6300 train_loss=0.4835 train_acc=0.8020
# [minLSTM] step=  6400 train_loss=0.4503 train_acc=0.8165
# [minLSTM] step=  6500 train_loss=0.4403 train_acc=0.8216
#    -> val_loss=0.4465 val_acc=0.8201
# [minLSTM] step=  6600 train_loss=0.4146 train_acc=0.8341
# [minLSTM] step=  6700 train_loss=0.4017 train_acc=0.8379
#    -> val_loss=0.4149 val_acc=0.8340
# [minLSTM] step=  6800 train_loss=0.3787 train_acc=0.8492
# [minLSTM] step=  6900 train_loss=0.3476 train_acc=0.8621
# [minLSTM] step=  7000 train_loss=0.3316 train_acc=0.8692
#    -> val_loss=0.3683 val_acc=0.8517
# [minLSTM] step=  7100 train_loss=0.3018 train_acc=0.8827
# [minLSTM] step=  7200 train_loss=0.2782 train_acc=0.8934
#    -> val_loss=0.2744 val_acc=0.8916
# [minLSTM] step=  7300 train_loss=0.2569 train_acc=0.9012
# [minLSTM] step=  7400 train_loss=0.2351 train_acc=0.9111
# [minLSTM] step=  7500 train_loss=0.2035 train_acc=0.9256
#    -> val_loss=0.2106 val_acc=0.9212
# [minLSTM] step=  7600 train_loss=0.1966 train_acc=0.9284
# [minLSTM] step=  7700 train_loss=0.1732 train_acc=0.9373
#    -> val_loss=0.2011 val_acc=0.9242
# [minLSTM] step=  7800 train_loss=0.1571 train_acc=0.9436
# [minLSTM] step=  7900 train_loss=0.1423 train_acc=0.9501
# [minLSTM] step=  8000 train_loss=0.1172 train_acc=0.9588
#    -> val_loss=0.1366 val_acc=0.9541
#
# ===== Training minLSTM, seed=43 =====
# [minLSTM] step=   100 train_loss=2.6569 train_acc=0.0721
# [minLSTM] step=   200 train_loss=2.6385 train_acc=0.0790
#    -> val_loss=2.4539 val_acc=0.1786
# [minLSTM] step=   300 train_loss=2.4566 train_acc=0.1716
# [minLSTM] step=   400 train_loss=2.2769 train_acc=0.2150
# [minLSTM] step=   500 train_loss=2.1340 train_acc=0.2524
#    -> val_loss=2.0618 val_acc=0.2764
# [minLSTM] step=   600 train_loss=2.0010 train_acc=0.2936
# [minLSTM] step=   700 train_loss=1.9062 train_acc=0.3153
#    -> val_loss=1.8147 val_acc=0.3369
# [minLSTM] step=   800 train_loss=1.8162 train_acc=0.3348
# [minLSTM] step=   900 train_loss=1.7431 train_acc=0.3499
# [minLSTM] step=  1000 train_loss=1.6796 train_acc=0.3645
#    -> val_loss=1.6602 val_acc=0.3669
# [minLSTM] step=  1100 train_loss=1.6241 train_acc=0.3727
# [minLSTM] step=  1200 train_loss=1.5778 train_acc=0.3861
#    -> val_loss=1.5513 val_acc=0.3892
# [minLSTM] step=  1300 train_loss=1.5405 train_acc=0.3922
# [minLSTM] step=  1400 train_loss=1.5023 train_acc=0.3995
# [minLSTM] step=  1500 train_loss=1.4702 train_acc=0.4114
#    -> val_loss=1.4836 val_acc=0.4087
# [minLSTM] step=  1600 train_loss=1.4415 train_acc=0.4169
# [minLSTM] step=  1700 train_loss=1.4124 train_acc=0.4210
#    -> val_loss=1.3861 val_acc=0.4248
# [minLSTM] step=  1800 train_loss=1.3856 train_acc=0.4299
# [minLSTM] step=  1900 train_loss=1.3502 train_acc=0.4370
# [minLSTM] step=  2000 train_loss=1.3164 train_acc=0.4477
#    -> val_loss=1.3044 val_acc=0.4467
# [minLSTM] step=  2100 train_loss=1.2932 train_acc=0.4520
# [minLSTM] step=  2200 train_loss=1.2669 train_acc=0.4619
#    -> val_loss=1.2574 val_acc=0.4616
# [minLSTM] step=  2300 train_loss=1.2520 train_acc=0.4668
# [minLSTM] step=  2400 train_loss=1.2231 train_acc=0.4741
# [minLSTM] step=  2500 train_loss=1.1977 train_acc=0.4832
#    -> val_loss=1.1840 val_acc=0.4848
# [minLSTM] step=  2600 train_loss=1.1779 train_acc=0.4885
# [minLSTM] step=  2700 train_loss=1.1551 train_acc=0.4988
#    -> val_loss=1.1376 val_acc=0.5019
# [minLSTM] step=  2800 train_loss=1.1415 train_acc=0.5013
# [minLSTM] step=  2900 train_loss=1.1169 train_acc=0.5115
# [minLSTM] step=  3000 train_loss=1.0915 train_acc=0.5210
#    -> val_loss=1.0800 val_acc=0.5231
# [minLSTM] step=  3100 train_loss=1.0766 train_acc=0.5261
# [minLSTM] step=  3200 train_loss=1.0528 train_acc=0.5342
#    -> val_loss=1.0544 val_acc=0.5309
# [minLSTM] step=  3300 train_loss=1.0443 train_acc=0.5373
# [minLSTM] step=  3400 train_loss=1.0196 train_acc=0.5493
# [minLSTM] step=  3500 train_loss=0.9978 train_acc=0.5574
#    -> val_loss=1.0107 val_acc=0.5507
# [minLSTM] step=  3600 train_loss=0.9900 train_acc=0.5620
# [minLSTM] step=  3700 train_loss=0.9612 train_acc=0.5764
#    -> val_loss=0.9583 val_acc=0.5754
# [minLSTM] step=  3800 train_loss=0.9470 train_acc=0.5815
# [minLSTM] step=  3900 train_loss=0.9233 train_acc=0.5929
# [minLSTM] step=  4000 train_loss=0.9018 train_acc=0.6044
#    -> val_loss=0.9152 val_acc=0.5958
# [minLSTM] step=  4100 train_loss=0.8804 train_acc=0.6145
# [minLSTM] step=  4200 train_loss=0.8615 train_acc=0.6236
#    -> val_loss=0.8444 val_acc=0.6309
# [minLSTM] step=  4300 train_loss=0.8436 train_acc=0.6300
# [minLSTM] step=  4400 train_loss=0.8197 train_acc=0.6413
# [minLSTM] step=  4500 train_loss=0.7973 train_acc=0.6523
#    -> val_loss=0.8080 val_acc=0.6471
# [minLSTM] step=  4600 train_loss=0.7750 train_acc=0.6624
# [minLSTM] step=  4700 train_loss=0.7478 train_acc=0.6770
#    -> val_loss=0.7440 val_acc=0.6798
# [minLSTM] step=  4800 train_loss=0.7307 train_acc=0.6837
# [minLSTM] step=  4900 train_loss=0.7007 train_acc=0.7010
# [minLSTM] step=  5000 train_loss=0.6744 train_acc=0.7132
#    -> val_loss=0.6830 val_acc=0.7087
# [minLSTM] step=  5100 train_loss=0.6411 train_acc=0.7301
# [minLSTM] step=  5200 train_loss=0.6109 train_acc=0.7445
#    -> val_loss=0.6032 val_acc=0.7442
# [minLSTM] step=  5300 train_loss=0.5896 train_acc=0.7551
# [minLSTM] step=  5400 train_loss=0.5563 train_acc=0.7692
# [minLSTM] step=  5500 train_loss=0.5255 train_acc=0.7896
#    -> val_loss=0.5293 val_acc=0.7843
# [minLSTM] step=  5600 train_loss=0.4876 train_acc=0.8045
# [minLSTM] step=  5700 train_loss=0.4550 train_acc=0.8185
#    -> val_loss=0.4661 val_acc=0.8150
# [minLSTM] step=  5800 train_loss=0.4348 train_acc=0.8284
# [minLSTM] step=  5900 train_loss=0.3817 train_acc=0.8520
# [minLSTM] step=  6000 train_loss=0.3487 train_acc=0.8684
#    -> val_loss=0.3926 val_acc=0.8483
# [minLSTM] step=  6100 train_loss=0.3220 train_acc=0.8774
# [minLSTM] step=  6200 train_loss=0.2782 train_acc=0.8973
#    -> val_loss=0.2869 val_acc=0.8943
# [minLSTM] step=  6300 train_loss=0.2506 train_acc=0.9081
# [minLSTM] step=  6400 train_loss=0.2364 train_acc=0.9145
# [minLSTM] step=  6500 train_loss=0.2198 train_acc=0.9191
#    -> val_loss=0.1985 val_acc=0.9279
# [minLSTM] step=  6600 train_loss=0.1851 train_acc=0.9337
# [minLSTM] step=  6700 train_loss=0.1654 train_acc=0.9415
#    -> val_loss=0.2020 val_acc=0.9304
# [minLSTM] step=  6800 train_loss=0.1355 train_acc=0.9533
# [minLSTM] step=  6900 train_loss=0.1469 train_acc=0.9500
# [minLSTM] step=  7000 train_loss=0.1043 train_acc=0.9653
#    -> val_loss=0.1067 val_acc=0.9639
# [minLSTM] step=  7100 train_loss=0.0961 train_acc=0.9689
# [minLSTM] step=  7200 train_loss=0.0805 train_acc=0.9737
#    -> val_loss=0.1102 val_acc=0.9638
# [minLSTM] step=  7300 train_loss=0.0764 train_acc=0.9748
# [minLSTM] step=  7400 train_loss=0.0639 train_acc=0.9794
# [minLSTM] step=  7500 train_loss=0.0749 train_acc=0.9760
#    -> val_loss=0.0648 val_acc=0.9790
# [minLSTM] step=  7600 train_loss=0.0596 train_acc=0.9806
# [minLSTM] step=  7700 train_loss=0.0548 train_acc=0.9820
#    -> val_loss=0.0801 val_acc=0.9726
# [minLSTM] step=  7800 train_loss=0.0525 train_acc=0.9821
# [minLSTM] step=  7900 train_loss=0.0514 train_acc=0.9833
# [minLSTM] step=  8000 train_loss=0.0675 train_acc=0.9795
#    -> val_loss=0.0515 val_acc=0.9822
#
# ===== Training minLSTM, seed=44 =====
# [minLSTM] step=   100 train_loss=2.6597 train_acc=0.0704
# [minLSTM] step=   200 train_loss=2.6432 train_acc=0.0725
#    -> val_loss=2.5958 val_acc=0.0950
# [minLSTM] step=   300 train_loss=2.6011 train_acc=0.1003
# [minLSTM] step=   400 train_loss=2.4449 train_acc=0.1744
# [minLSTM] step=   500 train_loss=2.2932 train_acc=0.2129
#    -> val_loss=2.2689 val_acc=0.2177
# [minLSTM] step=   600 train_loss=2.2154 train_acc=0.2258
# [minLSTM] step=   700 train_loss=2.1486 train_acc=0.2370
#    -> val_loss=2.0864 val_acc=0.2493
# [minLSTM] step=   800 train_loss=2.0691 train_acc=0.2541
# [minLSTM] step=   900 train_loss=1.9046 train_acc=0.3086
# [minLSTM] step=  1000 train_loss=1.7857 train_acc=0.3333
#    -> val_loss=1.7302 val_acc=0.3442
# [minLSTM] step=  1100 train_loss=1.6806 train_acc=0.3494
# [minLSTM] step=  1200 train_loss=1.6105 train_acc=0.3662
#    -> val_loss=1.5378 val_acc=0.3766
# [minLSTM] step=  1300 train_loss=1.5520 train_acc=0.3759
# [minLSTM] step=  1400 train_loss=1.4961 train_acc=0.3907
# [minLSTM] step=  1500 train_loss=1.4570 train_acc=0.3976
#    -> val_loss=1.4266 val_acc=0.4058
# [minLSTM] step=  1600 train_loss=1.4081 train_acc=0.4100
# [minLSTM] step=  1700 train_loss=1.3707 train_acc=0.4214
#    -> val_loss=1.3463 val_acc=0.4246
# [minLSTM] step=  1800 train_loss=1.3407 train_acc=0.4309
# [minLSTM] step=  1900 train_loss=1.3076 train_acc=0.4422
# [minLSTM] step=  2000 train_loss=1.2807 train_acc=0.4489
#    -> val_loss=1.2639 val_acc=0.4516
# [minLSTM] step=  2100 train_loss=1.2545 train_acc=0.4574
# [minLSTM] step=  2200 train_loss=1.2338 train_acc=0.4648
#    -> val_loss=1.2220 val_acc=0.4724
# [minLSTM] step=  2300 train_loss=1.2135 train_acc=0.4730
# [minLSTM] step=  2400 train_loss=1.1861 train_acc=0.4804
# [minLSTM] step=  2500 train_loss=1.1693 train_acc=0.4849
#    -> val_loss=1.1665 val_acc=0.4907
# [minLSTM] step=  2600 train_loss=1.1458 train_acc=0.4929
# [minLSTM] step=  2700 train_loss=1.1247 train_acc=0.5015
#    -> val_loss=1.1092 val_acc=0.5107
# [minLSTM] step=  2800 train_loss=1.1079 train_acc=0.5055
# [minLSTM] step=  2900 train_loss=1.0882 train_acc=0.5121
# [minLSTM] step=  3000 train_loss=1.0734 train_acc=0.5193
#    -> val_loss=1.0887 val_acc=0.5201
# [minLSTM] step=  3100 train_loss=1.0490 train_acc=0.5293
# [minLSTM] step=  3200 train_loss=1.0320 train_acc=0.5376
#    -> val_loss=1.0221 val_acc=0.5468
# [minLSTM] step=  3300 train_loss=1.0121 train_acc=0.5466
# [minLSTM] step=  3400 train_loss=0.9908 train_acc=0.5578
# [minLSTM] step=  3500 train_loss=0.9703 train_acc=0.5665
#    -> val_loss=0.9750 val_acc=0.5700
# [minLSTM] step=  3600 train_loss=0.9521 train_acc=0.5741
# [minLSTM] step=  3700 train_loss=0.9249 train_acc=0.5867
#    -> val_loss=0.9277 val_acc=0.5914
# [minLSTM] step=  3800 train_loss=0.9102 train_acc=0.5965
# [minLSTM] step=  3900 train_loss=0.8778 train_acc=0.6105
# [minLSTM] step=  4000 train_loss=0.8563 train_acc=0.6214
#    -> val_loss=0.8612 val_acc=0.6228
# [minLSTM] step=  4100 train_loss=0.8308 train_acc=0.6331
# [minLSTM] step=  4200 train_loss=0.8039 train_acc=0.6470
#    -> val_loss=0.7945 val_acc=0.6561
# [minLSTM] step=  4300 train_loss=0.7904 train_acc=0.6540
# [minLSTM] step=  4400 train_loss=0.7518 train_acc=0.6709
# [minLSTM] step=  4500 train_loss=0.7306 train_acc=0.6831
#    -> val_loss=0.7265 val_acc=0.6911
# [minLSTM] step=  4600 train_loss=0.7045 train_acc=0.6946
# [minLSTM] step=  4700 train_loss=0.6820 train_acc=0.7065
#    -> val_loss=0.6849 val_acc=0.7098
# [minLSTM] step=  4800 train_loss=0.6562 train_acc=0.7191
# [minLSTM] step=  4900 train_loss=0.6292 train_acc=0.7316
# [minLSTM] step=  5000 train_loss=0.6015 train_acc=0.7471
#    -> val_loss=0.6055 val_acc=0.7462
# [minLSTM] step=  5100 train_loss=0.5783 train_acc=0.7572
# [minLSTM] step=  5200 train_loss=0.5527 train_acc=0.7695
#    -> val_loss=0.5435 val_acc=0.7745
# [minLSTM] step=  5300 train_loss=0.5234 train_acc=0.7856
# [minLSTM] step=  5400 train_loss=0.4998 train_acc=0.7947
# [minLSTM] step=  5500 train_loss=0.4631 train_acc=0.8135
#    -> val_loss=0.4677 val_acc=0.8124
# [minLSTM] step=  5600 train_loss=0.4413 train_acc=0.8218
# [minLSTM] step=  5700 train_loss=0.4190 train_acc=0.8307
#    -> val_loss=0.4003 val_acc=0.8429
# [minLSTM] step=  5800 train_loss=0.3767 train_acc=0.8505
# [minLSTM] step=  5900 train_loss=0.3498 train_acc=0.8638
# [minLSTM] step=  6000 train_loss=0.3126 train_acc=0.8793
#    -> val_loss=0.3287 val_acc=0.8742
# [minLSTM] step=  6100 train_loss=0.2821 train_acc=0.8926
# [minLSTM] step=  6200 train_loss=0.2538 train_acc=0.9058
#    -> val_loss=0.2403 val_acc=0.9095
# [minLSTM] step=  6300 train_loss=0.2246 train_acc=0.9168
# [minLSTM] step=  6400 train_loss=0.2001 train_acc=0.9271
# [minLSTM] step=  6500 train_loss=0.1708 train_acc=0.9399
#    -> val_loss=0.1764 val_acc=0.9363
# [minLSTM] step=  6600 train_loss=0.1542 train_acc=0.9449
# [minLSTM] step=  6700 train_loss=0.1293 train_acc=0.9565
#    -> val_loss=0.1549 val_acc=0.9473
# [minLSTM] step=  6800 train_loss=0.1203 train_acc=0.9577
# [minLSTM] step=  6900 train_loss=0.1044 train_acc=0.9637
# [minLSTM] step=  7000 train_loss=0.0903 train_acc=0.9699
#    -> val_loss=0.1192 val_acc=0.9601
# [minLSTM] step=  7100 train_loss=0.0831 train_acc=0.9713
# [minLSTM] step=  7200 train_loss=0.0685 train_acc=0.9777
#    -> val_loss=0.0707 val_acc=0.9773
# [minLSTM] step=  7300 train_loss=0.0612 train_acc=0.9788
# [minLSTM] step=  7400 train_loss=0.0577 train_acc=0.9801
# [minLSTM] step=  7500 train_loss=0.0462 train_acc=0.9857
#    -> val_loss=0.0501 val_acc=0.9846
# [minLSTM] step=  7600 train_loss=0.0491 train_acc=0.9837
# [minLSTM] step=  7700 train_loss=0.0379 train_acc=0.9879
#    -> val_loss=0.0512 val_acc=0.9834
# [minLSTM] step=  7800 train_loss=0.0342 train_acc=0.9890
# [minLSTM] step=  7900 train_loss=0.0302 train_acc=0.9901
# [minLSTM] step=  8000 train_loss=0.0270 train_acc=0.9918
#    -> val_loss=0.0338 val_acc=0.9889
#
# ===== Training GRU, seed=42 =====
# [GRU] step=   100 train_loss=2.6555 train_acc=0.0715
# [GRU] step=   200 train_loss=2.6447 train_acc=0.0726
#    -> val_loss=2.6446 val_acc=0.0689
# [GRU] step=   300 train_loss=2.6439 train_acc=0.0710
# [GRU] step=   400 train_loss=2.6207 train_acc=0.0978
# [GRU] step=   500 train_loss=2.4001 train_acc=0.1861
#    -> val_loss=2.2548 val_acc=0.2205
# [GRU] step=   600 train_loss=2.1091 train_acc=0.2633
# [GRU] step=   700 train_loss=1.7537 train_acc=0.3701
#    -> val_loss=1.3556 val_acc=0.5029
# [GRU] step=   800 train_loss=1.3646 train_acc=0.4991
# [GRU] step=   900 train_loss=1.0327 train_acc=0.6119
# [GRU] step=  1000 train_loss=0.7656 train_acc=0.7125
#    -> val_loss=0.6473 val_acc=0.7546
# [GRU] step=  1100 train_loss=0.5664 train_acc=0.7878
# [GRU] step=  1200 train_loss=0.4134 train_acc=0.8483
#    -> val_loss=0.3120 val_acc=0.8864
# [GRU] step=  1300 train_loss=0.3174 train_acc=0.8865
# [GRU] step=  1400 train_loss=0.2444 train_acc=0.9153
# [GRU] step=  1500 train_loss=0.1884 train_acc=0.9370
#    -> val_loss=0.1828 val_acc=0.9370
# [GRU] step=  1600 train_loss=0.1473 train_acc=0.9496
# [GRU] step=  1700 train_loss=0.1183 train_acc=0.9612
#    -> val_loss=0.1137 val_acc=0.9616
# [GRU] step=  1800 train_loss=0.0961 train_acc=0.9694
# [GRU] step=  1900 train_loss=0.0790 train_acc=0.9749
# [GRU] step=  2000 train_loss=0.0655 train_acc=0.9796
#    -> val_loss=0.0916 val_acc=0.9695
# [GRU] step=  2100 train_loss=0.0582 train_acc=0.9811
# [GRU] step=  2200 train_loss=0.0427 train_acc=0.9866
#    -> val_loss=0.0420 val_acc=0.9877
# [GRU] step=  2300 train_loss=0.0379 train_acc=0.9880
# [GRU] step=  2400 train_loss=0.0307 train_acc=0.9905
# [GRU] step=  2500 train_loss=0.0272 train_acc=0.9919
#    -> val_loss=0.0293 val_acc=0.9911
# [GRU] step=  2600 train_loss=0.0278 train_acc=0.9913
# [GRU] step=  2700 train_loss=0.0194 train_acc=0.9944
#    -> val_loss=0.0285 val_acc=0.9913
# [GRU] step=  2800 train_loss=0.0168 train_acc=0.9951
# [GRU] step=  2900 train_loss=0.0141 train_acc=0.9960
# [GRU] step=  3000 train_loss=0.0076 train_acc=0.9981
#    -> val_loss=0.0083 val_acc=0.9979
# [GRU] step=  3100 train_loss=0.0099 train_acc=0.9971
# [GRU] step=  3200 train_loss=0.0135 train_acc=0.9962
#    -> val_loss=0.0147 val_acc=0.9960
# [GRU] step=  3300 train_loss=0.0105 train_acc=0.9971
# [GRU] step=  3400 train_loss=0.0060 train_acc=0.9986
# [GRU] step=  3500 train_loss=0.0033 train_acc=0.9993
#    -> val_loss=0.0047 val_acc=0.9987
# [GRU] step=  3600 train_loss=0.0010 train_acc=1.0000
# [GRU] step=  3700 train_loss=0.0005 train_acc=1.0000
#    -> val_loss=0.0013 val_acc=0.9996
# [GRU] step=  3800 train_loss=0.0004 train_acc=1.0000
# [GRU] step=  3900 train_loss=0.0003 train_acc=1.0000
# [GRU] step=  4000 train_loss=0.0002 train_acc=1.0000
#    -> val_loss=0.0013 val_acc=0.9996
# [GRU] step=  4100 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  4200 train_loss=0.0002 train_acc=1.0000
#    -> val_loss=0.0013 val_acc=0.9996
# [GRU] step=  4300 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  4400 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  4500 train_loss=0.0002 train_acc=1.0000
#    -> val_loss=0.0014 val_acc=0.9996
# [GRU] step=  4600 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  4700 train_loss=0.0002 train_acc=1.0000
#    -> val_loss=0.0014 val_acc=0.9996
# [GRU] step=  4800 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  4900 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  5000 train_loss=0.0002 train_acc=1.0000
#    -> val_loss=0.0015 val_acc=0.9996
# [GRU] step=  5100 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  5200 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0016 val_acc=0.9995
# [GRU] step=  5300 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  5400 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  5500 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0016 val_acc=0.9994
# [GRU] step=  5600 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  5700 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0016 val_acc=0.9994
# [GRU] step=  5800 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  5900 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6000 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0017 val_acc=0.9994
# [GRU] step=  6100 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6200 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0017 val_acc=0.9994
# [GRU] step=  6300 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6400 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6500 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0017 val_acc=0.9995
# [GRU] step=  6600 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6700 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0017 val_acc=0.9994
# [GRU] step=  6800 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6900 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  7000 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0017 val_acc=0.9994
# [GRU] step=  7100 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  7200 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0018 val_acc=0.9994
# [GRU] step=  7300 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  7400 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  7500 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0018 val_acc=0.9994
# [GRU] step=  7600 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  7700 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0018 val_acc=0.9994
# [GRU] step=  7800 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  7900 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  8000 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0018 val_acc=0.9994
#
# ===== Training GRU, seed=43 =====
# [GRU] step=   100 train_loss=2.6548 train_acc=0.0714
# [GRU] step=   200 train_loss=2.6448 train_acc=0.0706
#    -> val_loss=2.6443 val_acc=0.0695
# [GRU] step=   300 train_loss=2.6433 train_acc=0.0711
# [GRU] step=   400 train_loss=2.6418 train_acc=0.0740
# [GRU] step=   500 train_loss=2.5490 train_acc=0.1277
#    -> val_loss=2.3312 val_acc=0.1896
# [GRU] step=   600 train_loss=2.1298 train_acc=0.2440
# [GRU] step=   700 train_loss=1.6601 train_acc=0.3829
#    -> val_loss=1.1472 val_acc=0.5519
# [GRU] step=   800 train_loss=1.1769 train_acc=0.5383
# [GRU] step=   900 train_loss=0.8244 train_acc=0.6737
# [GRU] step=  1000 train_loss=0.5877 train_acc=0.7698
#    -> val_loss=0.5604 val_acc=0.7807
# [GRU] step=  1100 train_loss=0.4223 train_acc=0.8382
# [GRU] step=  1200 train_loss=0.3030 train_acc=0.8868
#    -> val_loss=0.2637 val_acc=0.9055
# [GRU] step=  1300 train_loss=0.2370 train_acc=0.9139
# [GRU] step=  1400 train_loss=0.1720 train_acc=0.9399
# [GRU] step=  1500 train_loss=0.1282 train_acc=0.9559
#    -> val_loss=0.1258 val_acc=0.9576
# [GRU] step=  1600 train_loss=0.1033 train_acc=0.9653
# [GRU] step=  1700 train_loss=0.0795 train_acc=0.9738
#    -> val_loss=0.0968 val_acc=0.9674
# [GRU] step=  1800 train_loss=0.0745 train_acc=0.9744
# [GRU] step=  1900 train_loss=0.0606 train_acc=0.9799
# [GRU] step=  2000 train_loss=0.0551 train_acc=0.9815
#    -> val_loss=0.0624 val_acc=0.9796
# [GRU] step=  2100 train_loss=0.0468 train_acc=0.9854
# [GRU] step=  2200 train_loss=0.0377 train_acc=0.9878
#    -> val_loss=0.0773 val_acc=0.9734
# [GRU] step=  2300 train_loss=0.0313 train_acc=0.9901
# [GRU] step=  2400 train_loss=0.0291 train_acc=0.9915
# [GRU] step=  2500 train_loss=0.0329 train_acc=0.9892
#    -> val_loss=0.0279 val_acc=0.9913
# [GRU] step=  2600 train_loss=0.0220 train_acc=0.9930
# [GRU] step=  2700 train_loss=0.0238 train_acc=0.9925
#    -> val_loss=0.0375 val_acc=0.9877
# [GRU] step=  2800 train_loss=0.0190 train_acc=0.9939
# [GRU] step=  2900 train_loss=0.0243 train_acc=0.9922
# [GRU] step=  3000 train_loss=0.0194 train_acc=0.9943
#    -> val_loss=0.0243 val_acc=0.9915
# [GRU] step=  3100 train_loss=0.0177 train_acc=0.9945
# [GRU] step=  3200 train_loss=0.0154 train_acc=0.9953
#    -> val_loss=0.0136 val_acc=0.9959
# [GRU] step=  3300 train_loss=0.0178 train_acc=0.9946
# [GRU] step=  3400 train_loss=0.0084 train_acc=0.9978
# [GRU] step=  3500 train_loss=0.0034 train_acc=0.9992
#    -> val_loss=0.0115 val_acc=0.9962
# [GRU] step=  3600 train_loss=0.0040 train_acc=0.9989
# [GRU] step=  3700 train_loss=0.0087 train_acc=0.9974
#    -> val_loss=0.0108 val_acc=0.9966
# [GRU] step=  3800 train_loss=0.0101 train_acc=0.9969
# [GRU] step=  3900 train_loss=0.0140 train_acc=0.9959
# [GRU] step=  4000 train_loss=0.0114 train_acc=0.9965
#    -> val_loss=0.0250 val_acc=0.9918
# [GRU] step=  4100 train_loss=0.0130 train_acc=0.9962
# [GRU] step=  4200 train_loss=0.0098 train_acc=0.9970
#    -> val_loss=0.0222 val_acc=0.9925
# [GRU] step=  4300 train_loss=0.0118 train_acc=0.9960
# [GRU] step=  4400 train_loss=0.0110 train_acc=0.9966
# [GRU] step=  4500 train_loss=0.0083 train_acc=0.9974
#    -> val_loss=0.0077 val_acc=0.9977
# [GRU] step=  4600 train_loss=0.0019 train_acc=0.9995
# [GRU] step=  4700 train_loss=0.0040 train_acc=0.9989
#    -> val_loss=0.0083 val_acc=0.9977
# [GRU] step=  4800 train_loss=0.0048 train_acc=0.9988
# [GRU] step=  4900 train_loss=0.0194 train_acc=0.9940
# [GRU] step=  5000 train_loss=0.0119 train_acc=0.9965
#    -> val_loss=0.0111 val_acc=0.9966
# [GRU] step=  5100 train_loss=0.0088 train_acc=0.9974
# [GRU] step=  5200 train_loss=0.0064 train_acc=0.9981
#    -> val_loss=0.0045 val_acc=0.9988
# [GRU] step=  5300 train_loss=0.0030 train_acc=0.9992
# [GRU] step=  5400 train_loss=0.0043 train_acc=0.9987
# [GRU] step=  5500 train_loss=0.0093 train_acc=0.9971
#    -> val_loss=0.0115 val_acc=0.9963
# [GRU] step=  5600 train_loss=0.0119 train_acc=0.9962
# [GRU] step=  5700 train_loss=0.0053 train_acc=0.9984
#    -> val_loss=0.0033 val_acc=0.9990
# [GRU] step=  5800 train_loss=0.0039 train_acc=0.9989
# [GRU] step=  5900 train_loss=0.0064 train_acc=0.9981
# [GRU] step=  6000 train_loss=0.0019 train_acc=0.9996
#    -> val_loss=0.0020 val_acc=0.9996
# [GRU] step=  6100 train_loss=0.0008 train_acc=0.9998
# [GRU] step=  6200 train_loss=0.0002 train_acc=1.0000
#    -> val_loss=0.0011 val_acc=0.9997
# [GRU] step=  6300 train_loss=0.0003 train_acc=1.0000
# [GRU] step=  6400 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6500 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0004 val_acc=0.9999
# [GRU] step=  6600 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6700 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0004 val_acc=0.9999
# [GRU] step=  6800 train_loss=0.0001 train_acc=1.0000
# [GRU] step=  6900 train_loss=0.0000 train_acc=1.0000
# [GRU] step=  7000 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0004 val_acc=0.9999
# [GRU] step=  7100 train_loss=0.0000 train_acc=1.0000
# [GRU] step=  7200 train_loss=0.0000 train_acc=1.0000
#    -> val_loss=0.0004 val_acc=0.9999
# [GRU] step=  7300 train_loss=0.0000 train_acc=1.0000
# [GRU] step=  7400 train_loss=0.0000 train_acc=1.0000
# [GRU] step=  7500 train_loss=0.0000 train_acc=1.0000
#    -> val_loss=0.0004 val_acc=0.9999
# [GRU] step=  7600 train_loss=0.0000 train_acc=1.0000
# [GRU] step=  7700 train_loss=0.0000 train_acc=1.0000
#    -> val_loss=0.0004 val_acc=0.9999
# [GRU] step=  7800 train_loss=0.0000 train_acc=1.0000
# [GRU] step=  7900 train_loss=0.0000 train_acc=1.0000
# [GRU] step=  8000 train_loss=0.0000 train_acc=1.0000
#    -> val_loss=0.0004 val_acc=1.0000
#
# ===== Training GRU, seed=44 =====
# [GRU] step=   100 train_loss=2.6608 train_acc=0.0710
# [GRU] step=   200 train_loss=2.6450 train_acc=0.0708
#    -> val_loss=2.6392 val_acc=0.0730
# [GRU] step=   300 train_loss=2.6409 train_acc=0.0752
# [GRU] step=   400 train_loss=2.5916 train_acc=0.1191
# [GRU] step=   500 train_loss=2.3998 train_acc=0.1974
#    -> val_loss=2.1824 val_acc=0.2568
# [GRU] step=   600 train_loss=1.9488 train_acc=0.3162
# [GRU] step=   700 train_loss=1.4066 train_acc=0.4609
#    -> val_loss=0.9285 val_acc=0.6336
# [GRU] step=   800 train_loss=0.9331 train_acc=0.6372
# [GRU] step=   900 train_loss=0.5961 train_acc=0.7760
# [GRU] step=  1000 train_loss=0.3461 train_acc=0.8788
#    -> val_loss=0.2821 val_acc=0.9041
# [GRU] step=  1100 train_loss=0.2124 train_acc=0.9300
# [GRU] step=  1200 train_loss=0.1402 train_acc=0.9565
#    -> val_loss=0.0753 val_acc=0.9774
# [GRU] step=  1300 train_loss=0.0805 train_acc=0.9766
# [GRU] step=  1400 train_loss=0.0612 train_acc=0.9821
# [GRU] step=  1500 train_loss=0.0372 train_acc=0.9894
#    -> val_loss=0.0466 val_acc=0.9859
# [GRU] step=  1600 train_loss=0.0304 train_acc=0.9917
# [GRU] step=  1700 train_loss=0.0264 train_acc=0.9929
#    -> val_loss=0.0124 val_acc=0.9967
# [GRU] step=  1800 train_loss=0.0109 train_acc=0.9975
# [GRU] step=  1900 train_loss=0.0122 train_acc=0.9969
# [GRU] step=  2000 train_loss=0.0120 train_acc=0.9969
#    -> val_loss=0.0091 val_acc=0.9977
# [GRU] step=  2100 train_loss=0.0128 train_acc=0.9965
# [GRU] step=  2200 train_loss=0.0117 train_acc=0.9968
#    -> val_loss=0.0060 val_acc=0.9984
# [GRU] step=  2300 train_loss=0.0069 train_acc=0.9981
# [GRU] step=  2400 train_loss=0.0013 train_acc=0.9998
# [GRU] step=  2500 train_loss=0.0145 train_acc=0.9968
#    -> val_loss=0.0327 val_acc=0.9891
# [GRU] step=  2600 train_loss=0.0076 train_acc=0.9980
# [GRU] step=  2700 train_loss=0.0027 train_acc=0.9994
#    -> val_loss=0.0510 val_acc=0.9858
# [GRU] step=  2800 train_loss=0.0116 train_acc=0.9968
# [GRU] step=  2900 train_loss=0.0088 train_acc=0.9975
# [GRU] step=  3000 train_loss=0.0028 train_acc=0.9994
#    -> val_loss=0.0033 val_acc=0.9991
# [GRU] step=  3100 train_loss=0.0036 train_acc=0.9989
# [GRU] step=  3200 train_loss=0.0029 train_acc=0.9993
#    -> val_loss=0.0104 val_acc=0.9968
# [GRU] step=  3300 train_loss=0.0060 train_acc=0.9983
# [GRU] step=  3400 train_loss=0.0065 train_acc=0.9982
# [GRU] step=  3500 train_loss=0.0004 train_acc=1.0000
#    -> val_loss=0.0005 val_acc=0.9999
# [GRU] step=  3600 train_loss=0.0002 train_acc=1.0000
# [GRU] step=  3700 train_loss=0.0001 train_acc=1.0000
#    -> val_loss=0.0002 val_acc=1.0000
# [GRU] step=  3800 train_loss=0.0001 train_acc=1.0000
# ...
# [LSTM] step=  1000 train_loss=2.6421 train_acc=0.0711
#    -> val_loss=2.6417 val_acc=0.0736
# [LSTM] step=  1100 train_loss=2.6412 train_acc=0.0712
# [LSTM] step=  1200 train_loss=2.6413 train_acc=0.0720
#    -> val_loss=2.6414 val_acc=0.0736
# [LSTM] step=  1300 train_loss=2.6418 train_acc=0.0713
# [LSTM] step=  1400 train_loss=2.6408 train_acc=0.0715
# [LSTM] step=  1500 train_loss=2.6417 train_acc=0.0704
#    -> val_loss=2.6412 val_acc=0.0729
# [LSTM] step=  1600 train_loss=2.6409 train_acc=0.0710
# [LSTM] step=  1700 train_loss=2.6409 train_acc=0.0709
#    -> val_loss=2.6410 val_acc=0.0730
# [LSTM] step=  1800 train_loss=2.6415 train_acc=0.0709
# [LSTM] step=  1900 train_loss=2.6406 train_acc=0.0709
# [LSTM] step=  2000 train_loss=2.6414 train_acc=0.0703
#    -> val_loss=2.6408 val_acc=0.0737
# [LSTM] step=  2100 train_loss=2.6407 train_acc=0.0710
# [LSTM] step=  2200 train_loss=2.6407 train_acc=0.0711
#    -> val_loss=2.6407 val_acc=0.0737
# [LSTM] step=  2300 train_loss=2.6412 train_acc=0.0698
# [LSTM] step=  2400 train_loss=2.6404 train_acc=0.0710
# [LSTM] step=  2500 train_loss=2.6412 train_acc=0.0692
#    -> val_loss=2.6406 val_acc=0.0733
# [LSTM] step=  2600 train_loss=2.6405 train_acc=0.0701
# [LSTM] step=  2700 train_loss=2.6406 train_acc=0.0711
#    -> val_loss=2.6406 val_acc=0.0733
# [LSTM] step=  2800 train_loss=2.6410 train_acc=0.0698
# [LSTM] step=  2900 train_loss=2.6403 train_acc=0.0705
# [LSTM] step=  3000 train_loss=2.6410 train_acc=0.0699
#    -> val_loss=2.6405 val_acc=0.0733
# [LSTM] step=  3100 train_loss=2.6404 train_acc=0.0701
# [LSTM] step=  3200 train_loss=2.6404 train_acc=0.0713
#    -> val_loss=2.6404 val_acc=0.0733
# [LSTM] step=  3300 train_loss=2.6409 train_acc=0.0697
# [LSTM] step=  3400 train_loss=2.6402 train_acc=0.0706
# [LSTM] step=  3500 train_loss=2.6408 train_acc=0.0701
#    -> val_loss=2.6404 val_acc=0.0733
# [LSTM] step=  3600 train_loss=2.6403 train_acc=0.0703
# [LSTM] step=  3700 train_loss=2.6403 train_acc=0.0713
#    -> val_loss=2.6403 val_acc=0.0733
# [LSTM] step=  3800 train_loss=2.6407 train_acc=0.0700
# [LSTM] step=  3900 train_loss=2.6401 train_acc=0.0713
# [LSTM] step=  4000 train_loss=2.6406 train_acc=0.0704
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  4100 train_loss=2.6402 train_acc=0.0707
# [LSTM] step=  4200 train_loss=2.6402 train_acc=0.0714
#    -> val_loss=2.6401 val_acc=0.0733
# [LSTM] step=  4300 train_loss=2.6405 train_acc=0.0703
# [LSTM] step=  4400 train_loss=2.6400 train_acc=0.0719
# [LSTM] step=  4500 train_loss=2.6099 train_acc=0.0930
#    -> val_loss=2.5834 val_acc=0.1061
# [LSTM] step=  4600 train_loss=2.5803 train_acc=0.1071
# [LSTM] step=  4700 train_loss=2.5758 train_acc=0.1060
#    -> val_loss=2.5744 val_acc=0.1086
# [LSTM] step=  4800 train_loss=2.5743 train_acc=0.1061
# [LSTM] step=  4900 train_loss=2.5279 train_acc=0.1221
# [LSTM] step=  5000 train_loss=2.3600 train_acc=0.1445
#    -> val_loss=2.3144 val_acc=0.1455
# [LSTM] step=  5100 train_loss=2.3004 train_acc=0.1482
# [LSTM] step=  5200 train_loss=2.2815 train_acc=0.1512
#    -> val_loss=2.3140 val_acc=0.1568
# [LSTM] step=  5300 train_loss=2.2630 train_acc=0.1560
# [LSTM] step=  5400 train_loss=2.2561 train_acc=0.1590
# [LSTM] step=  5500 train_loss=2.2420 train_acc=0.1664
#    -> val_loss=2.2589 val_acc=0.1592
# [LSTM] step=  5600 train_loss=2.2393 train_acc=0.1660
# [LSTM] step=  5700 train_loss=2.2232 train_acc=0.1711
#    -> val_loss=2.2198 val_acc=0.1806
# [LSTM] step=  5800 train_loss=2.2127 train_acc=0.1813
# [LSTM] step=  5900 train_loss=2.1954 train_acc=0.1911
# [LSTM] step=  6000 train_loss=2.1266 train_acc=0.2193
#    -> val_loss=2.0996 val_acc=0.2327
# [LSTM] step=  6100 train_loss=2.0716 train_acc=0.2340
# [LSTM] step=  6200 train_loss=2.0475 train_acc=0.2437
#    -> val_loss=2.0394 val_acc=0.2456
# [LSTM] step=  6300 train_loss=2.0194 train_acc=0.2496
# [LSTM] step=  6400 train_loss=2.0107 train_acc=0.2511
# [LSTM] step=  6500 train_loss=2.0063 train_acc=0.2539
#    -> val_loss=2.0052 val_acc=0.2573
# [LSTM] step=  6600 train_loss=1.9941 train_acc=0.2588
# [LSTM] step=  6700 train_loss=1.9845 train_acc=0.2633
#    -> val_loss=1.9755 val_acc=0.2707
# [LSTM] step=  6800 train_loss=1.9701 train_acc=0.2712
# [LSTM] step=  6900 train_loss=1.9441 train_acc=0.2793
# [LSTM] step=  7000 train_loss=1.9298 train_acc=0.2847
#    -> val_loss=1.9197 val_acc=0.2896
# [LSTM] step=  7100 train_loss=1.8843 train_acc=0.2949
# [LSTM] step=  7200 train_loss=1.8681 train_acc=0.2942
#    -> val_loss=1.8502 val_acc=0.2999
# [LSTM] step=  7300 train_loss=1.8350 train_acc=0.3035
# [LSTM] step=  7400 train_loss=1.8103 train_acc=0.3088
# [LSTM] step=  7500 train_loss=1.7962 train_acc=0.3118
#    -> val_loss=1.8040 val_acc=0.3091
# [LSTM] step=  7600 train_loss=1.7762 train_acc=0.3167
# [LSTM] step=  7700 train_loss=1.7652 train_acc=0.3187
#    -> val_loss=1.7637 val_acc=0.3170
# [LSTM] step=  7800 train_loss=1.7444 train_acc=0.3246
# [LSTM] step=  7900 train_loss=1.7372 train_acc=0.3244
# [LSTM] step=  8000 train_loss=1.7290 train_acc=0.3289
#    -> val_loss=1.7356 val_acc=0.3253
#
# ===== Training LSTM, seed=43 =====
# [LSTM] step=   100 train_loss=2.6558 train_acc=0.0726
# [LSTM] step=   200 train_loss=2.6446 train_acc=0.0726
#    -> val_loss=2.6432 val_acc=0.0695
# [LSTM] step=   300 train_loss=2.6428 train_acc=0.0708
# [LSTM] step=   400 train_loss=2.6424 train_acc=0.0706
# [LSTM] step=   500 train_loss=2.6429 train_acc=0.0709
#    -> val_loss=2.6413 val_acc=0.0730
# [LSTM] step=   600 train_loss=2.6416 train_acc=0.0707
# [LSTM] step=   700 train_loss=2.6418 train_acc=0.0709
#    -> val_loss=2.6410 val_acc=0.0736
# [LSTM] step=   800 train_loss=2.6419 train_acc=0.0724
# [LSTM] step=   900 train_loss=2.6412 train_acc=0.0718
# [LSTM] step=  1000 train_loss=2.6419 train_acc=0.0715
#    -> val_loss=2.6407 val_acc=0.0715
# [LSTM] step=  1100 train_loss=2.6411 train_acc=0.0710
# [LSTM] step=  1200 train_loss=2.6412 train_acc=0.0720
#    -> val_loss=2.6405 val_acc=0.0728
# [LSTM] step=  1300 train_loss=2.6415 train_acc=0.0718
# [LSTM] step=  1400 train_loss=2.6408 train_acc=0.0710
# [LSTM] step=  1500 train_loss=2.6415 train_acc=0.0717
#    -> val_loss=2.6405 val_acc=0.0736
# [LSTM] step=  1600 train_loss=2.6408 train_acc=0.0712
# [LSTM] step=  1700 train_loss=2.6409 train_acc=0.0718
#    -> val_loss=2.6404 val_acc=0.0733
# [LSTM] step=  1800 train_loss=2.6413 train_acc=0.0710
# [LSTM] step=  1900 train_loss=2.6406 train_acc=0.0710
# [LSTM] step=  2000 train_loss=2.6412 train_acc=0.0709
#    -> val_loss=2.6403 val_acc=0.0733
# [LSTM] step=  2100 train_loss=2.6407 train_acc=0.0711
# [LSTM] step=  2200 train_loss=2.6407 train_acc=0.0716
#    -> val_loss=2.6403 val_acc=0.0733
# [LSTM] step=  2300 train_loss=2.6411 train_acc=0.0708
# [LSTM] step=  2400 train_loss=2.6405 train_acc=0.0707
# [LSTM] step=  2500 train_loss=2.6410 train_acc=0.0712
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  2600 train_loss=2.6405 train_acc=0.0710
# [LSTM] step=  2700 train_loss=2.6406 train_acc=0.0711
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  2800 train_loss=2.6410 train_acc=0.0702
# [LSTM] step=  2900 train_loss=2.6403 train_acc=0.0707
# [LSTM] step=  3000 train_loss=2.6409 train_acc=0.0706
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  3100 train_loss=2.6404 train_acc=0.0708
# [LSTM] step=  3200 train_loss=2.6405 train_acc=0.0712
#    -> val_loss=2.6401 val_acc=0.0733
# [LSTM] step=  3300 train_loss=2.6408 train_acc=0.0696
# [LSTM] step=  3400 train_loss=2.6402 train_acc=0.0710
# [LSTM] step=  3500 train_loss=2.6408 train_acc=0.0699
#    -> val_loss=2.6401 val_acc=0.0733
# [LSTM] step=  3600 train_loss=2.6403 train_acc=0.0707
# [LSTM] step=  3700 train_loss=2.6404 train_acc=0.0709
#    -> val_loss=2.6399 val_acc=0.0733
# [LSTM] step=  3800 train_loss=2.6404 train_acc=0.0706
# [LSTM] step=  3900 train_loss=2.6177 train_acc=0.0850
# [LSTM] step=  4000 train_loss=2.5586 train_acc=0.0943
#    -> val_loss=2.4613 val_acc=0.0952
# [LSTM] step=  4100 train_loss=2.5202 train_acc=0.0971
# [LSTM] step=  4200 train_loss=2.4430 train_acc=0.1032
#    -> val_loss=2.4052 val_acc=0.1181
# [LSTM] step=  4300 train_loss=2.4073 train_acc=0.1184
# [LSTM] step=  4400 train_loss=2.4207 train_acc=0.1217
# [LSTM] step=  4500 train_loss=2.4155 train_acc=0.1273
#    -> val_loss=2.3749 val_acc=0.1302
# [LSTM] step=  4600 train_loss=2.3754 train_acc=0.1304
# [LSTM] step=  4700 train_loss=2.3701 train_acc=0.1344
#    -> val_loss=2.3343 val_acc=0.1452
# [LSTM] step=  4800 train_loss=2.3723 train_acc=0.1387
# [LSTM] step=  4900 train_loss=2.3221 train_acc=0.1605
# [LSTM] step=  5000 train_loss=2.3105 train_acc=0.1672
#    -> val_loss=2.2772 val_acc=0.1786
# [LSTM] step=  5100 train_loss=2.2857 train_acc=0.1816
# [LSTM] step=  5200 train_loss=2.2874 train_acc=0.1887
#    -> val_loss=2.2985 val_acc=0.1949
# [LSTM] step=  5300 train_loss=2.2664 train_acc=0.1967
# [LSTM] step=  5400 train_loss=2.2307 train_acc=0.2093
# [LSTM] step=  5500 train_loss=2.2260 train_acc=0.2179
#    -> val_loss=2.1948 val_acc=0.2237
# [LSTM] step=  5600 train_loss=2.1678 train_acc=0.2346
# [LSTM] step=  5700 train_loss=2.1647 train_acc=0.2303
#    -> val_loss=2.1405 val_acc=0.2384
# [LSTM] step=  5800 train_loss=2.1499 train_acc=0.2381
# [LSTM] step=  5900 train_loss=2.1498 train_acc=0.2381
# [LSTM] step=  6000 train_loss=2.0900 train_acc=0.2552
#    -> val_loss=2.0468 val_acc=0.2662
# [LSTM] step=  6100 train_loss=2.0460 train_acc=0.2619
# [LSTM] step=  6200 train_loss=2.0256 train_acc=0.2639
#    -> val_loss=1.9639 val_acc=0.2795
# [LSTM] step=  6300 train_loss=2.0490 train_acc=0.2592
# [LSTM] step=  6400 train_loss=1.9949 train_acc=0.2675
# [LSTM] step=  6500 train_loss=1.9585 train_acc=0.2797
#    -> val_loss=1.9290 val_acc=0.2850
# [LSTM] step=  6600 train_loss=1.9466 train_acc=0.2798
# [LSTM] step=  6700 train_loss=2.0160 train_acc=0.2635
#    -> val_loss=1.9200 val_acc=0.2857
# [LSTM] step=  6800 train_loss=1.9212 train_acc=0.2858
# [LSTM] step=  6900 train_loss=1.9589 train_acc=0.2772
# [LSTM] step=  7000 train_loss=1.9088 train_acc=0.2848
#    -> val_loss=1.9611 val_acc=0.2719
# [LSTM] step=  7100 train_loss=1.9282 train_acc=0.2825
# [LSTM] step=  7200 train_loss=1.8858 train_acc=0.2895
#    -> val_loss=1.8604 val_acc=0.2938
# [LSTM] step=  7300 train_loss=1.9186 train_acc=0.2825
# [LSTM] step=  7400 train_loss=1.8669 train_acc=0.2913
# [LSTM] step=  7500 train_loss=1.8385 train_acc=0.2962
#    -> val_loss=1.8281 val_acc=0.2971
# [LSTM] step=  7600 train_loss=1.8165 train_acc=0.3012
# [LSTM] step=  7700 train_loss=1.7893 train_acc=0.3065
#    -> val_loss=1.7872 val_acc=0.3005
# [LSTM] step=  7800 train_loss=1.7612 train_acc=0.3062
# [LSTM] step=  7900 train_loss=1.7472 train_acc=0.3081
# [LSTM] step=  8000 train_loss=1.7484 train_acc=0.3077
#    -> val_loss=1.8199 val_acc=0.2950
#
# ===== Training LSTM, seed=44 =====
# [LSTM] step=   100 train_loss=2.6585 train_acc=0.0716
# [LSTM] step=   200 train_loss=2.6440 train_acc=0.0713
#    -> val_loss=2.6419 val_acc=0.0730
# [LSTM] step=   300 train_loss=2.6429 train_acc=0.0714
# [LSTM] step=   400 train_loss=2.6422 train_acc=0.0725
# [LSTM] step=   500 train_loss=2.6430 train_acc=0.0697
#    -> val_loss=2.6420 val_acc=0.0730
# [LSTM] step=   600 train_loss=2.6417 train_acc=0.0723
# [LSTM] step=   700 train_loss=2.6420 train_acc=0.0730
#    -> val_loss=2.6410 val_acc=0.0730
# [LSTM] step=   800 train_loss=2.6420 train_acc=0.0708
# [LSTM] step=   900 train_loss=2.6412 train_acc=0.0724
# [LSTM] step=  1000 train_loss=2.6421 train_acc=0.0705
#    -> val_loss=2.6406 val_acc=0.0735
# [LSTM] step=  1100 train_loss=2.6411 train_acc=0.0716
# [LSTM] step=  1200 train_loss=2.6414 train_acc=0.0716
#    -> val_loss=2.6404 val_acc=0.0735
# [LSTM] step=  1300 train_loss=2.6416 train_acc=0.0713
# [LSTM] step=  1400 train_loss=2.6408 train_acc=0.0715
# [LSTM] step=  1500 train_loss=2.6417 train_acc=0.0710
#    -> val_loss=2.6403 val_acc=0.0733
# [LSTM] step=  1600 train_loss=2.6408 train_acc=0.0712
# [LSTM] step=  1700 train_loss=2.6410 train_acc=0.0712
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  1800 train_loss=2.6413 train_acc=0.0720
# [LSTM] step=  1900 train_loss=2.6406 train_acc=0.0714
# [LSTM] step=  2000 train_loss=2.6414 train_acc=0.0710
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  2100 train_loss=2.6406 train_acc=0.0706
# [LSTM] step=  2200 train_loss=2.6408 train_acc=0.0710
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  2300 train_loss=2.6411 train_acc=0.0710
# [LSTM] step=  2400 train_loss=2.6404 train_acc=0.0706
# [LSTM] step=  2500 train_loss=2.6412 train_acc=0.0713
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  2600 train_loss=2.6405 train_acc=0.0701
# [LSTM] step=  2700 train_loss=2.6406 train_acc=0.0706
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  2800 train_loss=2.6409 train_acc=0.0701
# [LSTM] step=  2900 train_loss=2.6403 train_acc=0.0706
# [LSTM] step=  3000 train_loss=2.6410 train_acc=0.0709
#    -> val_loss=2.6402 val_acc=0.0733
# [LSTM] step=  3100 train_loss=2.6404 train_acc=0.0702
# [LSTM] step=  3200 train_loss=2.6405 train_acc=0.0708
#    -> val_loss=2.6401 val_acc=0.0733
# [LSTM] step=  3300 train_loss=2.6408 train_acc=0.0696
# [LSTM] step=  3400 train_loss=2.6402 train_acc=0.0714
# [LSTM] step=  3500 train_loss=2.6408 train_acc=0.0708
#    -> val_loss=2.6401 val_acc=0.0733
# [LSTM] step=  3600 train_loss=2.6403 train_acc=0.0704
# [LSTM] step=  3700 train_loss=2.6404 train_acc=0.0705
#    -> val_loss=2.6401 val_acc=0.0733
# [LSTM] step=  3800 train_loss=2.6406 train_acc=0.0693
# [LSTM] step=  3900 train_loss=2.6401 train_acc=0.0718
# [LSTM] step=  4000 train_loss=2.6406 train_acc=0.0702
#    -> val_loss=2.6400 val_acc=0.0733
# [LSTM] step=  4100 train_loss=2.6402 train_acc=0.0704
# [LSTM] step=  4200 train_loss=2.6403 train_acc=0.0707
#    -> val_loss=2.6399 val_acc=0.0733
# [LSTM] step=  4300 train_loss=2.6405 train_acc=0.0695
# [LSTM] step=  4400 train_loss=2.6400 train_acc=0.0724
# [LSTM] step=  4500 train_loss=2.6405 train_acc=0.0703
#    -> val_loss=2.6399 val_acc=0.0733
# [LSTM] step=  4600 train_loss=2.6401 train_acc=0.0711
# [LSTM] step=  4700 train_loss=2.6402 train_acc=0.0714
#    -> val_loss=2.6399 val_acc=0.0733
# [LSTM] step=  4800 train_loss=2.6404 train_acc=0.0697
# [LSTM] step=  4900 train_loss=2.6399 train_acc=0.0727
# [LSTM] step=  5000 train_loss=2.6404 train_acc=0.0706
#    -> val_loss=2.6398 val_acc=0.0733
# [LSTM] step=  5100 train_loss=2.6400 train_acc=0.0707
# [LSTM] step=  5200 train_loss=2.6401 train_acc=0.0713
#    -> val_loss=2.6398 val_acc=0.0733
# [LSTM] step=  5300 train_loss=2.6403 train_acc=0.0695
# [LSTM] step=  5400 train_loss=2.6398 train_acc=0.0729
# [LSTM] step=  5500 train_loss=2.6403 train_acc=0.0706
#    -> val_loss=2.6398 val_acc=0.0733
# [LSTM] step=  5600 train_loss=2.6399 train_acc=0.0709
# [LSTM] step=  5700 train_loss=2.6400 train_acc=0.0716
#    -> val_loss=2.6398 val_acc=0.0733
# [LSTM] step=  5800 train_loss=2.6402 train_acc=0.0694
# [LSTM] step=  5900 train_loss=2.6397 train_acc=0.0729
# [LSTM] step=  6000 train_loss=2.6402 train_acc=0.0701
#    -> val_loss=2.6398 val_acc=0.0733
# [LSTM] step=  6100 train_loss=2.6397 train_acc=0.0715
# [LSTM] step=  6200 train_loss=2.6204 train_acc=0.0851
#    -> val_loss=2.5731 val_acc=0.0968
# [LSTM] step=  6300 train_loss=2.5695 train_acc=0.0966
# [LSTM] step=  6400 train_loss=2.4826 train_acc=0.1079
# [LSTM] step=  6500 train_loss=2.4095 train_acc=0.1271
#    -> val_loss=2.3573 val_acc=0.1368
# [LSTM] step=  6600 train_loss=2.3806 train_acc=0.1391
# [LSTM] step=  6700 train_loss=2.4062 train_acc=0.1437
#    -> val_loss=2.3851 val_acc=0.1316
# [LSTM] step=  6800 train_loss=2.3679 train_acc=0.1533
# [LSTM] step=  6900 train_loss=2.3381 train_acc=0.1647
# [LSTM] step=  7000 train_loss=2.3084 train_acc=0.1765
#    -> val_loss=2.3338 val_acc=0.1704
# [LSTM] step=  7100 train_loss=2.3352 train_acc=0.1720
# [LSTM] step=  7200 train_loss=2.2877 train_acc=0.1850
#    -> val_loss=2.2671 val_acc=0.1948
# [LSTM] step=  7300 train_loss=2.2723 train_acc=0.1897
# [LSTM] step=  7400 train_loss=2.2322 train_acc=0.1992
# [LSTM] step=  7500 train_loss=2.2077 train_acc=0.2063
#    -> val_loss=2.2134 val_acc=0.2008
# [LSTM] step=  7600 train_loss=2.1768 train_acc=0.2141
# [LSTM] step=  7700 train_loss=2.1613 train_acc=0.2200
#    -> val_loss=2.1737 val_acc=0.2168
# [LSTM] step=  7800 train_loss=2.1695 train_acc=0.2156
# [LSTM] step=  7900 train_loss=2.1454 train_acc=0.2213
# [LSTM] step=  8000 train_loss=2.1284 train_acc=0.2231
#    -> val_loss=2.1122 val_acc=0.2280

# %% [markdown]
# # Aggregate results

# %%
rows = []
for r in all_results:
    rows.append({
        "model": r["model_name"],
        "seed": r["seed"],
        "params": r["params"],
        "best_val_acc": r["best_val_acc"],
        "test_acc": r["test_acc"],
        "test_loss": r["test_loss"],
        "train_time_sec": r["train_time_sec"],
    })

results_df = pd.DataFrame(rows)
results_df.sort_values(["model", "seed"])
# Out:
#       model  seed   params  best_val_acc  test_acc  test_loss  train_time_sec
# 6       GRU    42   793728      0.999648  0.999609   0.001625      379.593863
# 7       GRU    43   793728      0.999961  0.999902   0.000337      379.696209
# 8       GRU    44   793728      1.000000  0.999883   0.000321      380.341853
# 9      LSTM    42  1041024      0.325313  0.325586   1.734374      388.854273
# 10     LSTM    43  1041024      0.300508  0.303027   1.781015      390.336725
# 11     LSTM    44  1041024      0.227969  0.225586   2.115157      388.970655
# 0    minGRU    42   152448      0.992656  0.992480   0.022170      367.201500
# 1    minGRU    43   152448      0.995977  0.996445   0.012554      373.862570
# 2    minGRU    44   152448      0.989570  0.988906   0.033710      374.199594
# 3   minLSTM    42   202368      0.954102  0.954668   0.135659      389.617193
# 4   minLSTM    43   202368      0.982187  0.983203   0.052122      389.951323
# 5   minLSTM    44   202368      0.988906  0.990176   0.031662      389.523819

# %% [markdown]
# # Summary Table

# %%
summary_df = (
    results_df.groupby("model")
    .agg(
        params=("params", "mean"),
        test_acc_mean=("test_acc", "mean"),
        test_acc_std=("test_acc", "std"),
        test_loss_mean=("test_loss", "mean"),
        test_loss_std=("test_loss", "std"),
        train_time_mean_sec=("train_time_sec", "mean"),
    )
    .reset_index()
)

summary_df["test_acc_mean_std"] = summary_df.apply(
    lambda r: f"{100*r['test_acc_mean']:.2f} ± {100*(0 if pd.isna(r['test_acc_std']) else r['test_acc_std']):.2f}",
    axis=1
)

summary_df["test_loss_mean_std"] = summary_df.apply(
    lambda r: f"{r['test_loss_mean']:.4f} ± {(0 if pd.isna(r['test_loss_std']) else r['test_loss_std']):.4f}",
    axis=1
)

summary_df[["model", "params", "test_acc_mean_std", "test_loss_mean_std", "train_time_mean_sec"]]
# Out:
#      model     params test_acc_mean_std test_loss_mean_std  \
# 0      GRU   793728.0      99.98 ± 0.02    0.0008 ± 0.0007
# 1     LSTM  1041024.0      28.47 ± 5.25    1.8768 ± 0.2077
# 2   minGRU   152448.0      99.26 ± 0.38    0.0228 ± 0.0106
# 3  minLSTM   202368.0      97.60 ± 1.88    0.0731 ± 0.0551
#
#    train_time_mean_sec
# 0           379.877309
# 1           389.387218
# 2           371.754555
# 3           389.697445

# %% [markdown]
# # Plot accuracy comparison

# %%
plot_df = summary_df.copy()

plt.figure(figsize=(8, 5))
plt.bar(plot_df["model"], 100 * plot_df["test_acc_mean"])
plt.ylabel("test accuracy (%)")
plt.title("Selective Copy replication: final accuracy")
plt.show()

plt.figure(figsize=(8, 5))
plt.bar(plot_df["model"], plot_df["train_time_mean_sec"])
plt.ylabel("mean train time (sec)")
plt.title("Selective Copy replication: mean training time")
plt.show()

# %% [markdown]
# # Extension: Generalization to longer sequences

# %%
# pick the best seed per model
best_model_objects = {}
for model_name in MODELS:
    subset = [r for r in all_results if r["model_name"] == model_name]
    best_r = max(subset, key=lambda x: x["test_acc"])
    best_model_objects[model_name] = best_r["model"]

lengths = [CFG.sequence_length, CFG.sequence_length * 2, CFG.sequence_length * 4]
generalization_rows = []

for model_name, model in best_model_objects.items():
    for L in lengths:
        metrics = evaluate_model(model, CFG, seed=1, num_batches=50, sequence_length=L)
        generalization_rows.append({
            "model": model_name,
            "sequence_length": L,
            "test_acc": metrics["acc"],
            "test_loss": metrics["loss"],
        })

generalization_df = pd.DataFrame(generalization_rows)
generalization_df
# Out:
#       model  sequence_length  test_acc  test_loss
# 0    minGRU              512  0.996797   0.012350
# 1    minGRU             1024  0.996289   0.013482
# 2    minGRU             2048  0.991172   0.031355
# 3   minLSTM              512  0.989883   0.033403
# 4   minLSTM             1024  0.976406   0.075129
# 5   minLSTM             2048  0.767656   1.189968
# 6       GRU              512  0.999961   0.000278
# 7       GRU             1024  0.999570   0.001323
# 8       GRU             2048  0.976406   0.090365
# 9      LSTM              512  0.324258   1.736229
# 10     LSTM             1024  0.313477   1.787950
# 11     LSTM             2048  0.286523   2.023137

# %% [markdown]
# # Plot length generalization

# %%
plt.figure(figsize=(8, 5))
for model_name in generalization_df["model"].unique():
    sub = generalization_df[generalization_df["model"] == model_name]
    plt.plot(sub["sequence_length"], 100 * sub["test_acc"], marker="o", label=model_name)

plt.xlabel("evaluation sequence length")
plt.ylabel("test accuracy (%)")
plt.title("Generalization to longer Selective Copy sequences")
plt.legend()
plt.xscale("log", base=2)
plt.show()

# %% [markdown]
# # Compare with original work's reported numbers

# %%
""" paper_df = pd.DataFrame([
    {"model": "minGRU", "paper_selective_copy_acc_mean": 99.5, "paper_selective_copy_acc_std": 0.2},
    {"model": "minLSTM", "paper_selective_copy_acc_mean": 96.0, "paper_selective_copy_acc_std": 2.8},
])

compare_df = summary_df.merge(paper_df, on="model", how="left")
compare_df["ours_acc_mean_pct"] = 100 * compare_df["test_acc_mean"]
compare_df["support_gap_pct_points"] = compare_df["ours_acc_mean_pct"] - compare_df["paper_selective_copy_acc_mean"]

compare_df[[
    "model",
    "params",
    "ours_acc_mean_pct",
    "paper_selective_copy_acc_mean",
    "paper_selective_copy_acc_std",
    "support_gap_pct_points",
]] """
# Out:
# ' paper_df = pd.DataFrame([\n    {"model": "minGRU", "paper_selective_copy_acc_mean": 99.5, "paper_selective_copy_acc_std": 0.2},\n    {"model": "minLSTM", "paper_selective_copy_acc_mean": 96.0, "paper_selective_copy_acc_std": 2.8},\n])\n\ncompare_df = summary_df.merge(paper_df, on="model", how="left")\ncompare_df["ours_acc_mean_pct"] = 100 * compare_df["test_acc_mean"]\ncompare_df["support_gap_pct_points"] = compare_df["ours_acc_mean_pct"] - compare_df["paper_selective_copy_acc_mean"]\n\ncompare_df[[\n    "model",\n    "params",\n    "ours_acc_mean_pct",\n    "paper_selective_copy_acc_mean",\n    "paper_selective_copy_acc_std",\n    "support_gap_pct_points",\n]] '
